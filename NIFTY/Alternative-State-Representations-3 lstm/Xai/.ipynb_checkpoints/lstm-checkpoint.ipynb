# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import datetime
import pandas as pd
import random
import pandas_ta as ta
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('nifty.csv', index_col=0, low_memory=False)

# %%
df.head(2)
# Out:
#      Close         High          Low         Open  Volume        date  \
# 0  5993.25  6006.049805  5982.000000  5982.600098       0  02-01-2013
# 1  6009.50  6017.000000  5986.549805  6015.799805       0  03-01-2013
#
#    weekday  month
# 0        2      1
# 1        3      1

# %%
df.tail(2)
# Out:
#             Close         High          Low         Open  Volume        date  \
# 2943  23813.40039  23938.84961  23800.59961  23801.40039  176800  27-12-2024
# 2944  23644.90039  23915.34961  23599.30078  23796.90039  364900  30-12-2024
#
#       weekday  month
# 2943        4     12
# 2944        0     12

# %%
# Fix: Assign the modified values directly to df['Volume']
df['Volume'] = df['Volume'].replace(0, np.nan)  # Convert 0 to NaN
df['Volume'] = df['Volume'].ffill()  # Forward fill NaN (alternative to fillna with method)

# %%
# Compute percentage change in tomorrow's Open price relative to today's Close
df["p_co"] = ((df["Open"].shift(-1)-df["Close"]) / df["Close"]) * 100

# %%
df["p_co"].describe()
# Out:
# count    2944.000000
# mean        0.121685
# std         0.610568
# min        -9.144755
# 25%        -0.082979
# 50%         0.150933
# 75%         0.381853
# max         4.484277
# Name: p_co, dtype: float64

# %%
# Compute MACD (Default: Fast=12, Slow=26, Signal=9)
macd_df = df.ta.macd(close="Close", fast=12, slow=26, signal=9)

# Add MACD values to the main DataFrame
df = pd.concat([df, macd_df], axis=1)

# %%
# Compute RSI (Default length = 14)
df["RSI"] = df.ta.rsi(close="Close", length=14)

# %%
df['SMA_10'] = ta.sma(df['Close'], length=10)  # 10-day SMA
df['SMA_50'] = ta.sma(df['Close'], length=50)  # 50-day SMA

# %%
df['EMA_10'] = ta.ema(df['Close'], length=10)  # 10-day EMA
df['EMA_50'] = ta.ema(df['Close'], length=50)  # 50-day EMA

# %%
# Convert 'Date' column to datetime (Modify column name if needed)
df["date"] = pd.to_datetime(df["date"], format="%d-%m-%Y")

# Set 'Date' as index (Required for VWAP)
df.set_index("date", inplace=True)

# Compute VWAP
df["VWAP"] = df.ta.vwap(high="High", low="Low", close="Close", volume="Volume")

# %%
#df.head()

# %%
# Compute percentage change in tomorrow's Open price relative to today's Close
df["oc"] = ((df["Open"]- df["Close"]) / df["Open"]) * 100

# %%
# Compute Bollinger Bands with a 20-day window
df.ta.bbands(close='close', length=20, append=True)
# Out:
#               BBL_20_2.0    BBM_20_2.0    BBU_20_2.0  BBB_20_2.0  BBP_20_2.0
# date
# 2013-01-02           NaN           NaN           NaN         NaN         NaN
# 2013-01-03           NaN           NaN           NaN         NaN         NaN
# 2013-01-04           NaN           NaN           NaN         NaN         NaN
# 2013-01-07           NaN           NaN           NaN         NaN         NaN
# 2013-01-08           NaN           NaN           NaN         NaN         NaN
# ...                  ...           ...           ...         ...         ...
# 2024-12-23  23677.155127  24339.255078  25001.355029    5.440593    0.057615
# 2024-12-24  23604.001008  24315.912597  25027.824187    5.855520    0.086843
# 2024-12-26  23536.195672  24289.677539  25043.159406    6.204132    0.142010
# 2024-12-27  23519.919649  24284.640039  25049.360429    6.297976    0.191888
# 2024-12-30  23448.189814  24260.330078  25072.470342    6.695212    0.121106
#
# [2945 rows x 5 columns]

# %%
# Compute 14-period ATR (default)
df.ta.atr(length=14, append=True)
# Out:
# date
# 2013-01-02           NaN
# 2013-01-03           NaN
# 2013-01-04           NaN
# 2013-01-07           NaN
# 2013-01-08           NaN
#                  ...
# 2024-12-23    301.432105
# 2024-12-24    292.936955
# 2024-12-26    286.362914
# 2024-12-27    279.383448
# 2024-12-30    282.002404
# Name: ATRr_14, Length: 2945, dtype: float64

# %%
df.tail()
# Out:
#                   Close         High          Low         Open    Volume  \
# date
# 2024-12-23  23753.44922  23869.55078  23647.19922  23738.19922  189800.0
# 2024-12-24  23727.65039  23867.65039  23685.15039  23769.09961  177700.0
# 2024-12-26  23750.19922  23854.50000  23653.59961  23775.80078  177700.0
# 2024-12-27  23813.40039  23938.84961  23800.59961  23801.40039  176800.0
# 2024-12-30  23644.90039  23915.34961  23599.30078  23796.90039  364900.0
#
#             weekday  month      p_co  MACD_12_26_9  MACDh_12_26_9  ...  \
# date                                                               ...
# 2024-12-23        0     12  0.065887    -82.033871     -91.560957  ...
# 2024-12-24        1     12  0.202929   -111.759222     -97.029046  ...
# 2024-12-26        3     12  0.215582   -131.975939     -93.796610  ...
# 2024-12-27        4     12 -0.069289   -141.269558     -82.472184  ...
# 2024-12-30        0     12       NaN   -160.382570     -81.268156  ...
#
#                   EMA_10        EMA_50          VWAP        oc    BBL_20_2.0  \
# date
# 2024-12-23  24141.552135  24359.181654  23756.733073 -0.064242  23677.155127
# 2024-12-24  24066.297272  24334.415722  23760.150390  0.174383  23604.001008
# 2024-12-26  24008.824899  24311.505271  23752.766277  0.107679  23536.195672
# 2024-12-27  23973.293170  24291.971746  23850.949870 -0.050417  23519.919649
# 2024-12-30  23913.585392  24266.596399  23719.850260  0.638739  23448.189814
#
#               BBM_20_2.0    BBU_20_2.0  BBB_20_2.0  BBP_20_2.0     ATRr_14
# date
# 2024-12-23  24339.255078  25001.355029    5.440593    0.057615  301.432105
# 2024-12-24  24315.912597  25027.824187    5.855520    0.086843  292.936955
# 2024-12-26  24289.677539  25043.159406    6.204132    0.142010  286.362914
# 2024-12-27  24284.640039  25049.360429    6.297976    0.191888  279.383448
# 2024-12-30  24260.330078  25072.470342    6.695212    0.121106  282.002404
#
# [5 rows x 24 columns]

# %%
print(df[55:].isna().sum())  # Count of NaN values per column
# Out:
# Close            0
# High             0
# Low              0
# Open             0
# Volume           0
# weekday          0
# month            0
# p_co             1
# MACD_12_26_9     0
# MACDh_12_26_9    0
# MACDs_12_26_9    0
# RSI              0
# SMA_10           0
# SMA_50           0
# EMA_10           0
# EMA_50           0
# VWAP             0
# oc               0
# BBL_20_2.0       0
# BBM_20_2.0       0
# BBU_20_2.0       0
# BBB_20_2.0       0
# BBP_20_2.0       0
# ATRr_14          0
# dtype: int64

# %%
df_subset = df.iloc[55:-1]  # Select rows from index 35 onwards
print(df_subset[df_subset.isna().any(axis=1)])
# Out:
# Empty DataFrame
# Columns: [Close, High, Low, Open, Volume, weekday, month, p_co, MACD_12_26_9, MACDh_12_26_9, MACDs_12_26_9, RSI, SMA_10, SMA_50, EMA_10, EMA_50, VWAP, oc, BBL_20_2.0, BBM_20_2.0, BBU_20_2.0, BBB_20_2.0, BBP_20_2.0, ATRr_14]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Check for Inf values
print(np.isinf(df_subset).sum())  # Count of Inf values per column
# Out:
# Close            0
# High             0
# Low              0
# Open             0
# Volume           0
# weekday          0
# month            0
# p_co             0
# MACD_12_26_9     0
# MACDh_12_26_9    0
# MACDs_12_26_9    0
# RSI              0
# SMA_10           0
# SMA_50           0
# EMA_10           0
# EMA_50           0
# VWAP             0
# oc               0
# BBL_20_2.0       0
# BBM_20_2.0       0
# BBU_20_2.0       0
# BBB_20_2.0       0
# BBP_20_2.0       0
# ATRr_14          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Close', 'High', 'Low', 'Open', 'Volume', 'weekday', 'month', 'p_co',
#        'MACD_12_26_9', 'MACDh_12_26_9', 'MACDs_12_26_9', 'RSI', 'SMA_10',
#        'SMA_50', 'EMA_10', 'EMA_50', 'VWAP', 'oc', 'BBL_20_2.0', 'BBM_20_2.0',
#        'BBU_20_2.0', 'BBB_20_2.0', 'BBP_20_2.0', 'ATRr_14'],
#       dtype='object')

# %%
# Generate target labels (1 if price increases, 0 otherwise)
#df['Target'] = (df['Close'].shift(-1) > df['Open'].shift(-1)).astype(int)

# %%
df['Target']=np.where(df['oc'].values<-0.15,0,np.where(df['oc'].values<0.15,1,2))
df['Target']=df['Target'].shift(-1)

# %%
 df["lstmstate"] = None

# %%
df.columns
# Out:
# Index(['Close', 'High', 'Low', 'Open', 'Volume', 'weekday', 'month', 'p_co',
#        'MACD_12_26_9', 'MACDh_12_26_9', 'MACDs_12_26_9', 'RSI', 'SMA_10',
#        'SMA_50', 'EMA_10', 'EMA_50', 'VWAP', 'oc', 'BBL_20_2.0', 'BBM_20_2.0',
#        'BBU_20_2.0', 'BBB_20_2.0', 'BBP_20_2.0', 'ATRr_14', 'Target',
#        'lstmstate'],
#       dtype='object')

# %%
# Drop the last row (as it has no next-day price)
df = df[:-1]

# %%
df = df[54:].reset_index(drop=False)  # Drop first 55 rows and reset index

# %%
df.head()
# Out:
#         date        Close         High          Low         Open    Volume  \
# 0 2013-03-19  5745.950195  5863.600098  5724.299805  5859.500000  182300.0
# 1 2013-03-20  5694.399902  5745.299805  5682.299805  5740.549805  187600.0
# 2 2013-03-21  5658.750000  5757.750000  5647.950195  5705.899902  179200.0
# 3 2013-03-22  5651.350098  5691.450195  5631.799805  5659.799805  165300.0
# 4 2013-03-25  5633.850098  5718.399902  5624.399902  5707.299805  150400.0
#
#    weekday  month      p_co  MACD_12_26_9  ...         VWAP        oc  \
# 0        1      3 -0.093986    -20.919208  ...  5777.950033  1.937875
# 1        2      3  0.201953    -31.332167  ...  5707.333171  0.803928
# 2        3      3  0.018552    -41.977273  ...  5688.150065  0.826336
# 3        4      3  0.990024    -50.429388  ...  5658.200033  0.149293
# 4        0      3 -0.356774    -57.872733  ...  5658.883301  1.286943
#
#     BBL_20_2.0   BBM_20_2.0   BBU_20_2.0  BBB_20_2.0  BBP_20_2.0    ATRr_14  \
# 0  5677.563483  5832.605029  5987.646576    5.316374    0.220543  75.372734
# 1  5662.691947  5820.172534  5977.653121    5.411544    0.100673  74.520964
# 2  5638.941809  5810.497534  5982.053259    5.905027    0.057731  77.081241
# 3  5616.745005  5800.550049  5984.355093    6.337504    0.094135  75.817684
# 4  5593.886613  5789.505054  5985.123494    6.757691    0.102147  77.134317
#
#    Target  lstmstate
# 0     2.0       None
# 1     2.0       None
# 2     1.0       None
# 3     2.0       None
# 4     0.0       None
#
# [5 rows x 27 columns]

# %% [raw]
# #df.index = pd.to_datetime(df.index)
# df = df.reset_index(drop=False)
# df.to_csv('temp.csv', index=True)

# %%
df.tail(1)
# Out:
#            date        Close         High          Low         Open    Volume  \
# 2889 2024-12-27  23813.40039  23938.84961  23800.59961  23801.40039  176800.0
#
#       weekday  month      p_co  MACD_12_26_9  ...      VWAP        oc  \
# 2889      1.0     12  0.665892      0.593421  ...  0.887816  0.574039
#
#       BBL_20_2.0  BBM_20_2.0  BBU_20_2.0  BBB_20_2.0  BBP_20_2.0   ATRr_14  \
# 2889    0.935936    0.938935    0.935962    0.097099    0.361328  0.458448
#
#       Target  lstmstate
# 2889     2.0       None
#
# [1 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['date', 'Close', 'High', 'Low', 'Open', 'Volume', 'weekday', 'month',
#        'p_co', 'MACD_12_26_9', 'MACDh_12_26_9', 'MACDs_12_26_9', 'RSI',
#        'SMA_10', 'SMA_50', 'EMA_10', 'EMA_50', 'VWAP', 'oc', 'BBL_20_2.0',
#        'BBM_20_2.0', 'BBU_20_2.0', 'BBB_20_2.0', 'BBP_20_2.0', 'ATRr_14',
#        'Target', 'lstmstate'],
#       dtype='object')

# %%
# Select features (5 indicators)
features = ['weekday', 'MACD_12_26_9', 'MACDh_12_26_9', 'MACDs_12_26_9', 'RSI', 'VWAP', 'p_co', 'oc',
       'BBL_20_2.0', 'BBM_20_2.0', 'BBU_20_2.0', 'BBB_20_2.0', 'BBP_20_2.0','ATRr_14','SMA_10','SMA_50', 'EMA_10', 'EMA_50']
target = 'Target'

# %%
# Normalize data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[features] = scaler.fit_transform(df[features])

# %%
# Convert data into sequences for LSTM
sequence_length = 60  # Use past 60 days to predict next day

def create_sequences(data, features, target, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[features].iloc[i:i+seq_length].values)
        y.append(data[target].iloc[i+seq_length])
    return np.array(X), np.array(y)

#X, y = create_sequences(df.iloc[55:], features, target, sequence_length)
X, y = create_sequences(df, features, target, sequence_length)

# %%
len(X)
# Out:
# 2830

# %%
X.shape
# Out:
# (2830, 60, 18)

# %%
X[0].shape
# Out:
# (60, 18)

# %%
y.shape
# Out:
# (2830,)

# %%
len(y)
# Out:
# 2830

# %%
df.shape
# Out:
# (2890, 27)

# %%
print(df.iloc[2152])
# Out:
# date             2021-12-31 00:00:00
# Close                    17354.05078
# High                     17400.80078
# Low                          17238.5
# Open                         17244.5
# Volume                      167000.0
# weekday                          1.0
# month                             12
# p_co                        0.684971
# MACD_12_26_9                0.639273
# MACDh_12_26_9               0.679468
# MACDs_12_26_9                0.57152
# RSI                         0.553953
# SMA_10                      0.569953
# SMA_50                      0.608322
# EMA_10                      0.575713
# EMA_50                      0.602155
# VWAP                        0.576785
# oc                          0.537767
# BBL_20_2.0                  0.588646
# BBM_20_2.0                  0.583436
# BBU_20_2.0                  0.576779
# BBB_20_2.0                  0.081404
# BBP_20_2.0                  0.656543
# ATRr_14                     0.365584
# Target                           0.0
# lstmstate                       None
# Name: 2152, dtype: object

# %%
# Define train-test split index
#split_idx = int(len(X) * 0.8)  # 80% training, 20% testing
split_idx = 2153 
# Split without shuffling
X_train, X_test = X[:split_idx], X[split_idx:]
y_train, y_test = y[:split_idx], y[split_idx:]

print(f"Train size: {len(X_train)}, Test size: {len(X_test)}")
# Out:
# Train size: 2153, Test size: 677

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer,Input, LSTM, Dense, RepeatVector, TimeDistributed, Attention, Multiply
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.optimizers import SGD

# Define Attention Layer
class AttentionLayer(Layer):
    def __init__(self):
        super(AttentionLayer, self).__init__()
        self.dense = tf.keras.layers.Dense(1, activation="tanh")  # Moved here
        self.softmax = tf.keras.layers.Softmax(axis=1)

    def call(self, lstm_output):
        attention = self.dense(lstm_output)  # Uses pre-defined layer
        attention = self.softmax(attention)
        context_vector = Multiply()([lstm_output, attention])
        return tf.reduce_sum(context_vector, axis=1)  # Context vector output

# Build Attention LSTM Model
def build_model(input_shape, lstm_units=[256, 128], dense_units=[64]):
    inputs = Input(shape=input_shape)
    
    # LSTM layers
    lstm_out = LSTM(lstm_units[0], return_sequences=True)(inputs)  # First LSTM layer
    lstm_out = Dropout(0.2)(lstm_out)
    lstm_out = BatchNormalization()(lstm_out)
    lstm_out = LSTM(lstm_units[1], return_sequences=True)(lstm_out)  # Second LSTM layer
    lstm_out = Dropout(0.2)(lstm_out)
    lstm_out = BatchNormalization()(lstm_out)

    # Attention layer
    attention_out = AttentionLayer()(lstm_out)

    # Dense layers
    dense_out = attention_out
    for units in dense_units:
        dense_out = Dense(units)(dense_out)  # Add hidden dense layers
        dense_out = BatchNormalization()(dense_out) 
        dense_out = LeakyReLU(alpha=0.01)(dense_out)

    output = Dense(3, activation='softmax')(dense_out)  # Output layer
    
    model = Model(inputs, output)
    #model.compile(optimizer=AdamW(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])
    optimizer = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# Example: Using 2 LSTM layers (64 and 32 neurons), 2 Dense layers (16 and 8 neurons)
input_shape = (sequence_length, len(features))  # 10 time steps, 5 indicators
model = build_model(input_shape, lstm_units=[256, 128], dense_units=[64, 64])
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\IIITNAGPUR\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:216: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# C:\Users\IIITNAGPUR\anaconda3\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 60, 18)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 60, 256)             │         281,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 60, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 60, 256)             │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 60, 128)             │         197,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 60, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 60, 128)             │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ attention_layer (AttentionLayer)     │ (None, 128)                 │             129 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu (LeakyReLU)              │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)            │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 3)                   │             195 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 493,508 (1.88 MB)
#  Trainable params: 492,484 (1.88 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
history = model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 16s 143ms/step - accuracy: 0.4158 - loss: 1.0894 - val_accuracy: 0.3767 - val_loss: 1.0783
# Epoch 2/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 150ms/step - accuracy: 0.4488 - loss: 1.0547 - val_accuracy: 0.3767 - val_loss: 1.0732
# Epoch 3/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 140ms/step - accuracy: 0.4221 - loss: 1.0465 - val_accuracy: 0.4032 - val_loss: 1.0794
# Epoch 4/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.4575 - loss: 1.0407 - val_accuracy: 0.3781 - val_loss: 1.1082
# Epoch 5/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 169ms/step - accuracy: 0.4345 - loss: 1.0438 - val_accuracy: 0.3767 - val_loss: 1.1661
# Epoch 6/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 165ms/step - accuracy: 0.4288 - loss: 1.0477 - val_accuracy: 0.3826 - val_loss: 1.0807
# Epoch 7/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 146ms/step - accuracy: 0.4169 - loss: 1.0452 - val_accuracy: 0.4032 - val_loss: 1.2254
# Epoch 8/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 174ms/step - accuracy: 0.4248 - loss: 1.0469 - val_accuracy: 0.4032 - val_loss: 1.0940
# Epoch 9/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 179ms/step - accuracy: 0.4358 - loss: 1.0365 - val_accuracy: 0.3767 - val_loss: 1.1256
# Epoch 10/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 187ms/step - accuracy: 0.4540 - loss: 1.0318 - val_accuracy: 0.3767 - val_loss: 1.1090
# Epoch 11/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 184ms/step - accuracy: 0.4207 - loss: 1.0497 - val_accuracy: 0.4032 - val_loss: 1.2507
# Epoch 12/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 149ms/step - accuracy: 0.4198 - loss: 1.0608 - val_accuracy: 0.3840 - val_loss: 1.0804
# Epoch 13/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 197ms/step - accuracy: 0.4267 - loss: 1.0389 - val_accuracy: 0.3767 - val_loss: 1.1318
# Epoch 14/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 201ms/step - accuracy: 0.4325 - loss: 1.0402 - val_accuracy: 0.3767 - val_loss: 1.2497
# Epoch 15/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 201ms/step - accuracy: 0.4185 - loss: 1.0400 - val_accuracy: 0.3767 - val_loss: 1.1672
# Epoch 16/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 193ms/step - accuracy: 0.4341 - loss: 1.0391 - val_accuracy: 0.3855 - val_loss: 1.0903
# Epoch 17/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 191ms/step - accuracy: 0.4413 - loss: 1.0348 - val_accuracy: 0.3767 - val_loss: 1.1991
# Epoch 18/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 189ms/step - accuracy: 0.4252 - loss: 1.0485 - val_accuracy: 0.3767 - val_loss: 1.2408
# Epoch 19/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 200ms/step - accuracy: 0.4328 - loss: 1.0422 - val_accuracy: 0.3826 - val_loss: 1.1293
# Epoch 20/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 203ms/step - accuracy: 0.4292 - loss: 1.0475 - val_accuracy: 0.3767 - val_loss: 1.1254
# Epoch 21/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 194ms/step - accuracy: 0.4326 - loss: 1.0362 - val_accuracy: 0.3767 - val_loss: 1.1227
# Epoch 22/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.4496 - loss: 1.0184 - val_accuracy: 0.3767 - val_loss: 1.1379
# Epoch 23/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 144ms/step - accuracy: 0.4447 - loss: 1.0258 - val_accuracy: 0.3767 - val_loss: 1.1247
# Epoch 24/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 133ms/step - accuracy: 0.4421 - loss: 1.0289 - val_accuracy: 0.4032 - val_loss: 1.0851
# Epoch 25/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.4390 - loss: 1.0418 - val_accuracy: 0.4032 - val_loss: 1.0856
# Epoch 26/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 193ms/step - accuracy: 0.4566 - loss: 1.0271 - val_accuracy: 0.3973 - val_loss: 1.0781
# Epoch 27/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 186ms/step - accuracy: 0.4310 - loss: 1.0232 - val_accuracy: 0.3767 - val_loss: 1.1687
# Epoch 28/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 180ms/step - accuracy: 0.4539 - loss: 1.0279 - val_accuracy: 0.3708 - val_loss: 1.1316
# Epoch 29/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.4374 - loss: 1.0407 - val_accuracy: 0.3826 - val_loss: 1.0825
# Epoch 30/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 136ms/step - accuracy: 0.4361 - loss: 1.0297 - val_accuracy: 0.3767 - val_loss: 1.1377
# Epoch 31/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 172ms/step - accuracy: 0.4309 - loss: 1.0272 - val_accuracy: 0.3767 - val_loss: 1.1087
# Epoch 32/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 180ms/step - accuracy: 0.4365 - loss: 1.0343 - val_accuracy: 0.3767 - val_loss: 1.1591
# Epoch 33/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 192ms/step - accuracy: 0.4380 - loss: 1.0211 - val_accuracy: 0.3840 - val_loss: 1.1129
# Epoch 34/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 190ms/step - accuracy: 0.4424 - loss: 1.0378 - val_accuracy: 0.3988 - val_loss: 1.1256
# Epoch 35/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 190ms/step - accuracy: 0.4202 - loss: 1.0481 - val_accuracy: 0.4032 - val_loss: 1.0952
# Epoch 36/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 192ms/step - accuracy: 0.4360 - loss: 1.0439 - val_accuracy: 0.3855 - val_loss: 1.1227
# Epoch 37/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 195ms/step - accuracy: 0.4497 - loss: 1.0212 - val_accuracy: 0.3811 - val_loss: 1.0874
# Epoch 38/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 177ms/step - accuracy: 0.4527 - loss: 1.0272 - val_accuracy: 0.4032 - val_loss: 1.0826
# Epoch 39/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 153ms/step - accuracy: 0.4253 - loss: 1.0312 - val_accuracy: 0.3737 - val_loss: 1.1039
# Epoch 40/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 144ms/step - accuracy: 0.4395 - loss: 1.0284 - val_accuracy: 0.3855 - val_loss: 1.1199
# Epoch 41/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 143ms/step - accuracy: 0.4430 - loss: 1.0351 - val_accuracy: 0.3767 - val_loss: 1.1791
# Epoch 42/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 180ms/step - accuracy: 0.4433 - loss: 1.0257 - val_accuracy: 0.3796 - val_loss: 1.1670
# Epoch 43/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 177ms/step - accuracy: 0.4918 - loss: 1.0194 - val_accuracy: 0.4032 - val_loss: 1.1971
# Epoch 44/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.4567 - loss: 1.0250 - val_accuracy: 0.3767 - val_loss: 1.1417
# Epoch 45/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 161ms/step - accuracy: 0.4323 - loss: 1.0387 - val_accuracy: 0.3767 - val_loss: 1.1201
# Epoch 46/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 140ms/step - accuracy: 0.4489 - loss: 1.0301 - val_accuracy: 0.3796 - val_loss: 1.1006
# Epoch 47/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 140ms/step - accuracy: 0.4480 - loss: 1.0246 - val_accuracy: 0.4032 - val_loss: 1.1483
# Epoch 48/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 141ms/step - accuracy: 0.4411 - loss: 1.0346 - val_accuracy: 0.4032 - val_loss: 1.0929
# Epoch 49/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 152ms/step - accuracy: 0.4653 - loss: 1.0174 - val_accuracy: 0.4032 - val_loss: 1.0913
# Epoch 50/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 162ms/step - accuracy: 0.4445 - loss: 1.0243 - val_accuracy: 0.4032 - val_loss: 1.1147
# Epoch 51/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 169ms/step - accuracy: 0.4486 - loss: 1.0210 - val_accuracy: 0.3781 - val_loss: 1.1617
# Epoch 52/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 189ms/step - accuracy: 0.4541 - loss: 1.0259 - val_accuracy: 0.3767 - val_loss: 1.3430
# Epoch 53/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 191ms/step - accuracy: 0.4446 - loss: 1.0250 - val_accuracy: 0.3811 - val_loss: 1.1203
# Epoch 54/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 178ms/step - accuracy: 0.4577 - loss: 1.0144 - val_accuracy: 0.3767 - val_loss: 1.1087
# Epoch 55/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 194ms/step - accuracy: 0.4736 - loss: 1.0083 - val_accuracy: 0.4003 - val_loss: 1.0804
# Epoch 56/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 180ms/step - accuracy: 0.4494 - loss: 1.0172 - val_accuracy: 0.4032 - val_loss: 1.1086
# Epoch 57/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 149ms/step - accuracy: 0.4405 - loss: 1.0213 - val_accuracy: 0.3767 - val_loss: 1.2052
# Epoch 58/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 159ms/step - accuracy: 0.4468 - loss: 1.0161 - val_accuracy: 0.3767 - val_loss: 1.1386
# Epoch 59/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 160ms/step - accuracy: 0.4477 - loss: 1.0293 - val_accuracy: 0.3767 - val_loss: 1.1200
# Epoch 60/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 145ms/step - accuracy: 0.4593 - loss: 1.0080 - val_accuracy: 0.3781 - val_loss: 1.1741
# Epoch 61/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 131ms/step - accuracy: 0.4563 - loss: 1.0275 - val_accuracy: 0.3752 - val_loss: 1.1040
# Epoch 62/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 164ms/step - accuracy: 0.4557 - loss: 1.0253 - val_accuracy: 0.3678 - val_loss: 1.1860
# Epoch 63/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 131ms/step - accuracy: 0.4592 - loss: 1.0107 - val_accuracy: 0.3693 - val_loss: 1.1347
# Epoch 64/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 171ms/step - accuracy: 0.4641 - loss: 1.0177 - val_accuracy: 0.3840 - val_loss: 1.0974
# Epoch 65/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 173ms/step - accuracy: 0.4619 - loss: 1.0206 - val_accuracy: 0.3767 - val_loss: 1.1708
# Epoch 66/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 150ms/step - accuracy: 0.4561 - loss: 1.0195 - val_accuracy: 0.4151 - val_loss: 1.0874
# Epoch 67/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - accuracy: 0.4471 - loss: 1.0182 - val_accuracy: 0.3693 - val_loss: 1.1043
# Epoch 68/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 153ms/step - accuracy: 0.4546 - loss: 1.0374 - val_accuracy: 0.4062 - val_loss: 1.1893
# Epoch 69/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 155ms/step - accuracy: 0.4504 - loss: 1.0247 - val_accuracy: 0.3781 - val_loss: 1.1597
# Epoch 70/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 123ms/step - accuracy: 0.4802 - loss: 1.0101 - val_accuracy: 0.3604 - val_loss: 1.1031
# Epoch 71/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.4437 - loss: 1.0280 - val_accuracy: 0.4062 - val_loss: 1.0726
# Epoch 72/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 160ms/step - accuracy: 0.4694 - loss: 1.0044 - val_accuracy: 0.2880 - val_loss: 1.1221
# Epoch 73/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 139ms/step - accuracy: 0.4416 - loss: 1.0291 - val_accuracy: 0.3767 - val_loss: 1.2482
# Epoch 74/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 155ms/step - accuracy: 0.4709 - loss: 1.0063 - val_accuracy: 0.3604 - val_loss: 1.0918
# Epoch 75/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 182ms/step - accuracy: 0.4591 - loss: 1.0105 - val_accuracy: 0.3722 - val_loss: 1.1162
# Epoch 76/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 144ms/step - accuracy: 0.4583 - loss: 1.0098 - val_accuracy: 0.3870 - val_loss: 1.1060
# Epoch 77/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 159ms/step - accuracy: 0.4485 - loss: 1.0234 - val_accuracy: 0.3855 - val_loss: 1.1177
# Epoch 78/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 155ms/step - accuracy: 0.5061 - loss: 0.9996 - val_accuracy: 0.3826 - val_loss: 1.0781
# Epoch 79/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 20s 151ms/step - accuracy: 0.4532 - loss: 1.0115 - val_accuracy: 0.3811 - val_loss: 1.1036
# Epoch 80/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 155ms/step - accuracy: 0.4520 - loss: 1.0082 - val_accuracy: 0.3885 - val_loss: 1.1372
# Epoch 81/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 171ms/step - accuracy: 0.4548 - loss: 1.0140 - val_accuracy: 0.3796 - val_loss: 1.1552
# Epoch 82/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 176ms/step - accuracy: 0.4784 - loss: 1.0003 - val_accuracy: 0.3648 - val_loss: 1.1284
# Epoch 83/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 181ms/step - accuracy: 0.4673 - loss: 1.0094 - val_accuracy: 0.3988 - val_loss: 1.1090
# Epoch 84/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 169ms/step - accuracy: 0.4544 - loss: 1.0104 - val_accuracy: 0.3693 - val_loss: 1.1199
# Epoch 85/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 187ms/step - accuracy: 0.4726 - loss: 1.0004 - val_accuracy: 0.3767 - val_loss: 1.1812
# Epoch 86/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 172ms/step - accuracy: 0.4507 - loss: 1.0073 - val_accuracy: 0.3708 - val_loss: 1.0982
# Epoch 87/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 168ms/step - accuracy: 0.4831 - loss: 0.9991 - val_accuracy: 0.3767 - val_loss: 1.1536
# Epoch 88/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 188ms/step - accuracy: 0.4543 - loss: 1.0023 - val_accuracy: 0.3885 - val_loss: 1.1948
# Epoch 89/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.4389 - loss: 1.0134 - val_accuracy: 0.3767 - val_loss: 1.0783
# Epoch 90/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 158ms/step - accuracy: 0.4751 - loss: 1.0078 - val_accuracy: 0.3678 - val_loss: 1.1140
# Epoch 91/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 186ms/step - accuracy: 0.4860 - loss: 0.9951 - val_accuracy: 0.3796 - val_loss: 1.1132
# Epoch 92/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 184ms/step - accuracy: 0.4748 - loss: 1.0015 - val_accuracy: 0.3929 - val_loss: 1.1335
# Epoch 93/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 175ms/step - accuracy: 0.4670 - loss: 1.0149 - val_accuracy: 0.3722 - val_loss: 1.1396
# Epoch 94/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.4670 - loss: 1.0011 - val_accuracy: 0.3708 - val_loss: 1.0993
# Epoch 95/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 190ms/step - accuracy: 0.4483 - loss: 1.0231 - val_accuracy: 0.3781 - val_loss: 1.1724
# Epoch 96/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 180ms/step - accuracy: 0.4610 - loss: 1.0178 - val_accuracy: 0.3693 - val_loss: 1.0957
# Epoch 97/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 185ms/step - accuracy: 0.4688 - loss: 1.0091 - val_accuracy: 0.3737 - val_loss: 1.1129
# Epoch 98/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 188ms/step - accuracy: 0.4796 - loss: 0.9928 - val_accuracy: 0.3826 - val_loss: 1.1014
# Epoch 99/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 186ms/step - accuracy: 0.4773 - loss: 1.0030 - val_accuracy: 0.3855 - val_loss: 1.1481
# Epoch 100/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 187ms/step - accuracy: 0.4615 - loss: 1.0156 - val_accuracy: 0.3811 - val_loss: 1.1185
# Epoch 101/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 137ms/step - accuracy: 0.4645 - loss: 1.0077 - val_accuracy: 0.3929 - val_loss: 1.0869
# Epoch 102/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 166ms/step - accuracy: 0.4655 - loss: 1.0055 - val_accuracy: 0.3796 - val_loss: 1.1071
# Epoch 103/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 176ms/step - accuracy: 0.4781 - loss: 0.9935 - val_accuracy: 0.3663 - val_loss: 1.1252
# Epoch 104/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 172ms/step - accuracy: 0.4678 - loss: 1.0075 - val_accuracy: 0.3796 - val_loss: 1.1072
# Epoch 105/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 172ms/step - accuracy: 0.4835 - loss: 0.9998 - val_accuracy: 0.3752 - val_loss: 1.1274
# Epoch 106/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.4811 - loss: 0.9990 - val_accuracy: 0.3944 - val_loss: 1.0720
# Epoch 107/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 161ms/step - accuracy: 0.4914 - loss: 1.0016 - val_accuracy: 0.3767 - val_loss: 1.2011
# Epoch 108/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 194ms/step - accuracy: 0.4664 - loss: 0.9871 - val_accuracy: 0.3840 - val_loss: 1.1125
# Epoch 109/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 172ms/step - accuracy: 0.4746 - loss: 0.9988 - val_accuracy: 0.3767 - val_loss: 1.1468
# Epoch 110/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 177ms/step - accuracy: 0.4706 - loss: 0.9950 - val_accuracy: 0.3767 - val_loss: 1.1063
# Epoch 111/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 195ms/step - accuracy: 0.4836 - loss: 1.0077 - val_accuracy: 0.3767 - val_loss: 1.1443
# Epoch 112/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 203ms/step - accuracy: 0.4793 - loss: 0.9893 - val_accuracy: 0.3678 - val_loss: 1.1650
# Epoch 113/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 181ms/step - accuracy: 0.4671 - loss: 1.0015 - val_accuracy: 0.3146 - val_loss: 1.1216
# Epoch 114/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 202ms/step - accuracy: 0.4787 - loss: 0.9982 - val_accuracy: 0.3722 - val_loss: 1.1258
# Epoch 115/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 199ms/step - accuracy: 0.4708 - loss: 1.0204 - val_accuracy: 0.3752 - val_loss: 1.3301
# Epoch 116/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 201ms/step - accuracy: 0.4851 - loss: 0.9791 - val_accuracy: 0.3767 - val_loss: 1.3846
# Epoch 117/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 201ms/step - accuracy: 0.4789 - loss: 0.9877 - val_accuracy: 0.3456 - val_loss: 1.1240
# Epoch 118/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 199ms/step - accuracy: 0.4676 - loss: 0.9927 - val_accuracy: 0.3840 - val_loss: 1.1085
# Epoch 119/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 202ms/step - accuracy: 0.4752 - loss: 0.9908 - val_accuracy: 0.3737 - val_loss: 1.1140
# Epoch 120/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 208ms/step - accuracy: 0.4816 - loss: 0.9944 - val_accuracy: 0.3708 - val_loss: 1.2566
# Epoch 121/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 196ms/step - accuracy: 0.4773 - loss: 0.9929 - val_accuracy: 0.3781 - val_loss: 1.1158
# Epoch 122/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 203ms/step - accuracy: 0.4936 - loss: 0.9716 - val_accuracy: 0.3781 - val_loss: 1.1690
# Epoch 123/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 189ms/step - accuracy: 0.4780 - loss: 0.9863 - val_accuracy: 0.3959 - val_loss: 1.1389
# Epoch 124/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 155ms/step - accuracy: 0.4911 - loss: 0.9795 - val_accuracy: 0.3752 - val_loss: 1.2114
# Epoch 125/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 178ms/step - accuracy: 0.4686 - loss: 0.9870 - val_accuracy: 0.3767 - val_loss: 1.1719
# Epoch 126/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.4676 - loss: 0.9860 - val_accuracy: 0.3900 - val_loss: 1.1479
# Epoch 127/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 193ms/step - accuracy: 0.4986 - loss: 0.9818 - val_accuracy: 0.3737 - val_loss: 1.1062
# Epoch 128/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 185ms/step - accuracy: 0.4969 - loss: 0.9788 - val_accuracy: 0.3914 - val_loss: 1.0962
# Epoch 129/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 200ms/step - accuracy: 0.4916 - loss: 0.9865 - val_accuracy: 0.3796 - val_loss: 1.1798
# Epoch 130/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 198ms/step - accuracy: 0.4943 - loss: 0.9757 - val_accuracy: 0.3678 - val_loss: 1.1311
# Epoch 131/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 204ms/step - accuracy: 0.4885 - loss: 0.9873 - val_accuracy: 0.3855 - val_loss: 1.0879
# Epoch 132/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 207ms/step - accuracy: 0.5046 - loss: 0.9761 - val_accuracy: 0.3796 - val_loss: 1.1696
# Epoch 133/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 193ms/step - accuracy: 0.4923 - loss: 0.9914 - val_accuracy: 0.3855 - val_loss: 1.1089
# Epoch 134/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 193ms/step - accuracy: 0.5018 - loss: 0.9639 - val_accuracy: 0.4047 - val_loss: 1.1101
# Epoch 135/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 202ms/step - accuracy: 0.4909 - loss: 0.9861 - val_accuracy: 0.3678 - val_loss: 1.1701
# Epoch 136/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 202ms/step - accuracy: 0.5155 - loss: 0.9737 - val_accuracy: 0.3752 - val_loss: 1.1429
# Epoch 137/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 197ms/step - accuracy: 0.4978 - loss: 0.9782 - val_accuracy: 0.3826 - val_loss: 1.2234
# Epoch 138/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 207ms/step - accuracy: 0.4983 - loss: 0.9675 - val_accuracy: 0.3811 - val_loss: 1.3050
# Epoch 139/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 201ms/step - accuracy: 0.4929 - loss: 0.9708 - val_accuracy: 0.3885 - val_loss: 1.0976
# Epoch 140/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 195ms/step - accuracy: 0.5231 - loss: 0.9698 - val_accuracy: 0.3781 - val_loss: 1.1186
# Epoch 141/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 204ms/step - accuracy: 0.4867 - loss: 0.9832 - val_accuracy: 0.3885 - val_loss: 1.1101
# Epoch 142/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 195ms/step - accuracy: 0.4974 - loss: 0.9825 - val_accuracy: 0.3900 - val_loss: 1.1332
# Epoch 143/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 204ms/step - accuracy: 0.4639 - loss: 0.9888 - val_accuracy: 0.3767 - val_loss: 1.1259
# Epoch 144/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 199ms/step - accuracy: 0.4997 - loss: 0.9592 - val_accuracy: 0.3663 - val_loss: 1.1449
# Epoch 145/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 195ms/step - accuracy: 0.4877 - loss: 0.9707 - val_accuracy: 0.3781 - val_loss: 1.1567
# Epoch 146/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 188ms/step - accuracy: 0.5074 - loss: 0.9679 - val_accuracy: 0.3826 - val_loss: 1.1235
# Epoch 147/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 199ms/step - accuracy: 0.4804 - loss: 0.9724 - val_accuracy: 0.3988 - val_loss: 1.1354
# Epoch 148/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 201ms/step - accuracy: 0.4996 - loss: 0.9733 - val_accuracy: 0.3840 - val_loss: 1.1005
# Epoch 149/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 195ms/step - accuracy: 0.4920 - loss: 0.9777 - val_accuracy: 0.3870 - val_loss: 1.1718
# Epoch 150/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 193ms/step - accuracy: 0.4981 - loss: 0.9761 - val_accuracy: 0.3885 - val_loss: 1.1266
# Epoch 151/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 197ms/step - accuracy: 0.4882 - loss: 0.9673 - val_accuracy: 0.3796 - val_loss: 1.1314
# Epoch 152/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 198ms/step - accuracy: 0.4987 - loss: 0.9618 - val_accuracy: 0.3914 - val_loss: 1.1002
# Epoch 153/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 203ms/step - accuracy: 0.5279 - loss: 0.9462 - val_accuracy: 0.4077 - val_loss: 1.0970
# Epoch 154/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 191ms/step - accuracy: 0.5153 - loss: 0.9554 - val_accuracy: 0.3840 - val_loss: 1.1299
# Epoch 155/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 186ms/step - accuracy: 0.5021 - loss: 0.9646 - val_accuracy: 0.4018 - val_loss: 1.1246
# Epoch 156/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 194ms/step - accuracy: 0.5006 - loss: 0.9707 - val_accuracy: 0.4003 - val_loss: 1.1034
# Epoch 157/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 196ms/step - accuracy: 0.4865 - loss: 0.9748 - val_accuracy: 0.3708 - val_loss: 1.1370
# Epoch 158/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 202ms/step - accuracy: 0.4763 - loss: 0.9693 - val_accuracy: 0.3737 - val_loss: 1.1116
# Epoch 159/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 203ms/step - accuracy: 0.5310 - loss: 0.9434 - val_accuracy: 0.3988 - val_loss: 1.1201
# Epoch 160/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 204ms/step - accuracy: 0.5118 - loss: 0.9556 - val_accuracy: 0.3959 - val_loss: 1.1151
# Epoch 161/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 202ms/step - accuracy: 0.5104 - loss: 0.9508 - val_accuracy: 0.4225 - val_loss: 1.0982
# Epoch 162/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 196ms/step - accuracy: 0.5156 - loss: 0.9618 - val_accuracy: 0.3914 - val_loss: 1.1339
# Epoch 163/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 204ms/step - accuracy: 0.4966 - loss: 0.9645 - val_accuracy: 0.3767 - val_loss: 1.1066
# Epoch 164/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 203ms/step - accuracy: 0.5145 - loss: 0.9642 - val_accuracy: 0.3944 - val_loss: 1.1265
# Epoch 165/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 202ms/step - accuracy: 0.5172 - loss: 0.9613 - val_accuracy: 0.3737 - val_loss: 1.1083
# Epoch 166/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 202ms/step - accuracy: 0.5016 - loss: 0.9606 - val_accuracy: 0.3870 - val_loss: 1.1267
# Epoch 167/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 196ms/step - accuracy: 0.5241 - loss: 0.9472 - val_accuracy: 0.4032 - val_loss: 1.1321
# Epoch 168/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 201ms/step - accuracy: 0.4966 - loss: 0.9577 - val_accuracy: 0.3781 - val_loss: 1.1752
# Epoch 169/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 196ms/step - accuracy: 0.5223 - loss: 0.9556 - val_accuracy: 0.3959 - val_loss: 1.1195
# Epoch 170/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 203ms/step - accuracy: 0.5167 - loss: 0.9533 - val_accuracy: 0.4018 - val_loss: 1.1726
# Epoch 171/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 189ms/step - accuracy: 0.5386 - loss: 0.9208 - val_accuracy: 0.3737 - val_loss: 1.1067
# Epoch 172/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 200ms/step - accuracy: 0.4965 - loss: 0.9676 - val_accuracy: 0.3959 - val_loss: 1.1135
# Epoch 173/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 180ms/step - accuracy: 0.5136 - loss: 0.9519 - val_accuracy: 0.3944 - val_loss: 1.1493
# Epoch 174/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 186ms/step - accuracy: 0.5262 - loss: 0.9385 - val_accuracy: 0.3737 - val_loss: 1.1155
# Epoch 175/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 168ms/step - accuracy: 0.5153 - loss: 0.9581 - val_accuracy: 0.3826 - val_loss: 1.1369
# Epoch 176/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 192ms/step - accuracy: 0.5120 - loss: 0.9463 - val_accuracy: 0.3914 - val_loss: 1.1132
# Epoch 177/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 200ms/step - accuracy: 0.5309 - loss: 0.9341 - val_accuracy: 0.3973 - val_loss: 1.1224
# Epoch 178/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 186ms/step - accuracy: 0.5211 - loss: 0.9447 - val_accuracy: 0.4077 - val_loss: 1.1080
# Epoch 179/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 202ms/step - accuracy: 0.5231 - loss: 0.9376 - val_accuracy: 0.4047 - val_loss: 1.1340
# Epoch 180/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 201ms/step - accuracy: 0.5394 - loss: 0.9317 - val_accuracy: 0.3944 - val_loss: 1.1173
# Epoch 181/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 196ms/step - accuracy: 0.5013 - loss: 0.9616 - val_accuracy: 0.3900 - val_loss: 1.1542
# Epoch 182/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 200ms/step - accuracy: 0.5639 - loss: 0.9314 - val_accuracy: 0.3929 - val_loss: 1.1403
# Epoch 183/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 192ms/step - accuracy: 0.5303 - loss: 0.9243 - val_accuracy: 0.4047 - val_loss: 1.1311
# Epoch 184/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 195ms/step - accuracy: 0.5376 - loss: 0.9345 - val_accuracy: 0.3973 - val_loss: 1.1130
# Epoch 185/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 192ms/step - accuracy: 0.5428 - loss: 0.9362 - val_accuracy: 0.3959 - val_loss: 1.1345
# Epoch 186/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 201ms/step - accuracy: 0.5400 - loss: 0.9053 - val_accuracy: 0.3826 - val_loss: 1.1255
# Epoch 187/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 196ms/step - accuracy: 0.5512 - loss: 0.9275 - val_accuracy: 0.4092 - val_loss: 1.1411
# Epoch 188/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 194ms/step - accuracy: 0.5522 - loss: 0.9141 - val_accuracy: 0.4003 - val_loss: 1.1300
# Epoch 189/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 142ms/step - accuracy: 0.5627 - loss: 0.9073 - val_accuracy: 0.4062 - val_loss: 1.1941
# Epoch 190/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.5253 - loss: 0.9367 - val_accuracy: 0.4032 - val_loss: 1.1110
# Epoch 191/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 128ms/step - accuracy: 0.5385 - loss: 0.9334 - val_accuracy: 0.3944 - val_loss: 1.1619
# Epoch 192/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 133ms/step - accuracy: 0.5290 - loss: 0.9251 - val_accuracy: 0.3796 - val_loss: 1.1679
# Epoch 193/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step - accuracy: 0.5473 - loss: 0.9243 - val_accuracy: 0.3781 - val_loss: 1.1500
# Epoch 194/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.5517 - loss: 0.9231 - val_accuracy: 0.3811 - val_loss: 1.1472
# Epoch 195/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 124ms/step - accuracy: 0.5333 - loss: 0.9255 - val_accuracy: 0.4003 - val_loss: 1.1507
# Epoch 196/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 128ms/step - accuracy: 0.5455 - loss: 0.9287 - val_accuracy: 0.3870 - val_loss: 1.1643
# Epoch 197/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 144ms/step - accuracy: 0.5157 - loss: 0.9328 - val_accuracy: 0.3914 - val_loss: 1.2053
# Epoch 198/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 123ms/step - accuracy: 0.5466 - loss: 0.9235 - val_accuracy: 0.3752 - val_loss: 1.2140
# Epoch 199/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 133ms/step - accuracy: 0.5473 - loss: 0.9095 - val_accuracy: 0.3722 - val_loss: 1.1820
# Epoch 200/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 142ms/step - accuracy: 0.5240 - loss: 0.9279 - val_accuracy: 0.3781 - val_loss: 1.1316

# %%
# Evaluate model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.2f}")
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.4033 - loss: 1.0813
# Test Accuracy: 0.38

# %%
# Plot Training History
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.legend()
plt.show()

# %%
# Make a prediction
predicted = model.predict(X)
print(predicted)
#print("Predicted Trend:", "UP" if predicted[0] > 0.5 else "DOWN")
# Out:
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step
# [[0.5218894  0.06307708 0.4150335 ]
#  [0.5389251  0.05904228 0.4020326 ]
#  [0.5211432  0.06069747 0.4181593 ]
#  ...
#  [0.4865602  0.11854219 0.39489764]
#  [0.41790938 0.09814236 0.48394832]
#  [0.3237806  0.08367994 0.5925394 ]]

# %%
# Convert probabilities to class labels
predicted_classes = np.argmax(predicted, axis=1)  # Get the index of the max value per row

# %%
type(predicted_classes)
# Out:
# numpy.ndarray

# %%
predicted_classes.shape
# Out:
# (2830,)

# %%
# Get unique elements and their frequencies
unique_elements, counts = np.unique(predicted_classes, return_counts=True)

# Display results
for element, count in zip(unique_elements, counts):
    print(f"Element: {element}, Frequency: {count}")
# Out:
# Element: 0, Frequency: 1017
# Element: 1, Frequency: 190
# Element: 2, Frequency: 1623

# %%
df.shape
# Out:
# (2890, 27)

# %%
df.iloc[60:, df.columns.get_loc("lstmstate")] = predicted_classes

# %%
# Compute percentage change in tomorrow's Open price relative to today's Close
df["p_co"] = ((df["Open"].shift(-1)-df["Close"]) / df["Close"]) * 100

# %%
# Apply condition, keeping NaNs unchanged
df['state'] = np.where(df['p_co'] > 0, df['lstmstate'] + 3, df['lstmstate'])

# %%
df['state'].describe()
# Out:
# count     2830
# unique       6
# top          5
# freq      1108
# Name: state, dtype: int64

# %%
# Plot histogram for categorical data
df['state'].value_counts().plot(kind='bar', figsize=(10, 5), color='skyblue', edgecolor='black')

plt.xlabel('State')
plt.ylabel('Frequency')
plt.title('Histogram of States')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#df.index = pd.to_datetime(df.index)
df = df.reset_index(drop=True)
df.to_csv('temp.csv', index=True)

# %%
len(df)
# Out:
# 2890

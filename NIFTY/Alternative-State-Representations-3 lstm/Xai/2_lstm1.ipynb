# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import datetime
import pandas as pd
import random
import pandas_ta as ta
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('input2lstm.csv', index_col=0, low_memory=False)

# %%
df.head(2)
# Out:
#      Close         High          Low         Open  Volume        date  \
# 0  5993.25  6006.049805  5982.000000  5982.600098       0  02-01-2013
# 1  6009.50  6017.000000  5986.549805  6015.799805       0  03-01-2013
#
#    weekday  month        oc        hl  ...  GK_Vol_10  GK_Vol_20  OBV  \
# 0        2      1  0.178015  0.402036  ...        NaN        NaN    0
# 1        3      1 -0.104721  0.508643  ...        NaN        NaN    0
#
#         MFM  MFV   AD  CMF_20  FI_13  VROC_10  PVT
# 0 -0.064441  0.0  0.0     NaN    NaN      NaN  NaN
# 1  0.507392  0.0  0.0     NaN    0.0      NaN  0.0
#
# [2 rows x 58 columns]

# %%
df.tail(2)
# Out:
#             Close         High          Low         Open  Volume        date  \
# 2943  23813.40039  23938.84961  23800.59961  23801.40039  176800  27-12-2024
# 2944  23644.90039  23915.34961  23599.30078  23796.90039  364900  30-12-2024
#
#       weekday  month        oc        hl  ...  GK_Vol_10  GK_Vol_20       OBV  \
# 2943        4     12  0.050417  0.580868  ...   0.129435   0.119717  72722400
# 2944        0     12 -0.638739  1.339230  ...   0.109060   0.121880  72357500
#
#            MFM          MFV           AD    CMF_20        FI_13    VROC_10  \
# 2943 -0.814817 -144059.6325  39740968.86 -0.030988  11173966.86 -33.558812
# 2944 -0.711439 -259604.2602  39481364.60 -0.109986 -61485650.00  17.671719
#
#               PVT
# 2943  333137.2665
# 2944  330555.2896
#
# [2 rows x 58 columns]

# %%
df.columns
# Out:
# Index(['Close', 'High', 'Low', 'Open', 'Volume', 'date', 'weekday', 'month',
#        'oc', 'hl', 'oh', 'ol', 'co', 'SMA_10', 'SMA_50', 'SMA_100', 'EMA_5',
#        'EMA_10', 'EMA_20', 'MACD_12_26_9', 'MACDh_12_26_9', 'MACDs_12_26_9',
#        'KAMA', 'TMA_20', 'RSI_7', 'RSI_14', '%D', 'ROC_5', 'ROC_10', 'ROC_20',
#        'CCI_14', 'CCI_50', 'MOM_10', 'UO', 'KST', 'KST_Signal', 'BB_Upper',
#        'BB_Middle', 'BB_Lower', 'BB_PercentB', 'HL_Range', 'HL_EMA', 'CVI',
#        'STDDEV_10', 'STDDEV_20', 'Log_Returns', 'HV_10', 'HV_20', 'GK_Vol_10',
#        'GK_Vol_20', 'OBV', 'MFM', 'MFV', 'AD', 'CMF_20', 'FI_13', 'VROC_10',
#        'PVT'],
#       dtype='object')

# %%
df['Target']=np.where(df['oc'].values<-0.15,0,np.where(df['oc'].values<0.15,1,2))
#df['Target']=df['Target'].shift(-1)

# %%
 df["lstmstate"] = None

# %%
 df.columns
# Out:
# Index(['Close', 'High', 'Low', 'Open', 'Volume', 'date', 'weekday', 'month',
#        'oc', 'hl', 'oh', 'ol', 'co', 'SMA_10', 'SMA_50', 'SMA_100', 'EMA_5',
#        'EMA_10', 'EMA_20', 'MACD_12_26_9', 'MACDh_12_26_9', 'MACDs_12_26_9',
#        'KAMA', 'TMA_20', 'RSI_7', 'RSI_14', '%D', 'ROC_5', 'ROC_10', 'ROC_20',
#        'CCI_14', 'CCI_50', 'MOM_10', 'UO', 'KST', 'KST_Signal', 'BB_Upper',
#        'BB_Middle', 'BB_Lower', 'BB_PercentB', 'HL_Range', 'HL_EMA', 'CVI',
#        'STDDEV_10', 'STDDEV_20', 'Log_Returns', 'HV_10', 'HV_20', 'GK_Vol_10',
#        'GK_Vol_20', 'OBV', 'MFM', 'MFV', 'AD', 'CMF_20', 'FI_13', 'VROC_10',
#        'PVT', 'Target', 'lstmstate'],
#       dtype='object')

# %%
df.tail()
# Out:
#             Close         High          Low         Open  Volume        date  \
# 2940  23753.44922  23869.55078  23647.19922  23738.19922  189800  23-12-2024
# 2941  23727.65039  23867.65039  23685.15039  23769.09961  177700  24-12-2024
# 2942  23750.19922  23854.50000  23653.59961  23775.80078  177700  26-12-2024
# 2943  23813.40039  23938.84961  23800.59961  23801.40039  176800  27-12-2024
# 2944  23644.90039  23915.34961  23599.30078  23796.90039  364900  30-12-2024
#
#       weekday  month        oc        hl  ...       OBV       MFM  \
# 2940        0     12  0.064242  0.940287  ...  72545600 -0.044306
# 2941        1     12 -0.174383  0.770525  ...  72367900 -0.534247
# 2942        3     12 -0.107679  0.849344  ...  72545600 -0.038333
# 2943        4     12  0.050417  0.580868  ...  72722400 -0.814817
# 2944        0     12 -0.638739  1.339230  ...  72357500 -0.711439
#
#                 MFV           AD    CMF_20         FI_13    VROC_10  \
# 2940   -8409.323002  39986775.93 -0.041960  3.149716e+07 -23.498589
# 2941  -94935.616440  39891840.31 -0.044291 -4.584452e+06 -31.915709
# 2942   -6811.823058  39885028.49 -0.059586  4.006927e+06  -5.125467
# 2943 -144059.632500  39740968.86 -0.030988  1.117397e+07 -33.558812
# 2944 -259604.260200  39481364.60 -0.109986 -6.148565e+07  17.671719
#
#               PVT  Target  lstmstate
# 2940  332690.9176       1       None
# 2941  332497.9160       0       None
# 2942  332666.7877       1       None
# 2943  333137.2665       1       None
# 2944  330555.2896       0       None
#
# [5 rows x 60 columns]

# %%
# Drop the last row (as it has no next-day price)
#df = df[:-1]

# %%
df = df[100:].reset_index(drop=False)  # Drop first 55 rows and reset index

# %%
df.head(2)
# Out:
#    index        Close         High          Low         Open  Volume  \
# 0    100  6104.299805  6125.049805  6069.799805  6120.450195  120200
# 1    101  6124.049805  6133.750000  6072.149902  6072.149902  194100
#
#          date  weekday  month        oc  ...    OBV       MFM           MFV  \
# 0  29-05-2013        2      5 -0.263876  ... -94800  0.248869   29914.02715
# 1  30-05-2013        3      5  0.854720  ...  99300  0.685059  132969.97230
#
#             AD    CMF_20        FI_13    VROC_10          PVT  Target  \
# 0 -330473.0473  0.097321  -835413.439 -21.897336 -3061.705179       0
# 1 -197503.0750  0.107417  3833475.000  22.383354 -2433.709319       2
#
#    lstmstate
# 0       None
# 1       None
#
# [2 rows x 61 columns]

# %%
df.columns
# Out:
# Index(['index', 'Close', 'High', 'Low', 'Open', 'Volume', 'date', 'weekday',
#        'month', 'oc', 'hl', 'oh', 'ol', 'co', 'SMA_10', 'SMA_50', 'SMA_100',
#        'EMA_5', 'EMA_10', 'EMA_20', 'MACD_12_26_9', 'MACDh_12_26_9',
#        'MACDs_12_26_9', 'KAMA', 'TMA_20', 'RSI_7', 'RSI_14', '%D', 'ROC_5',
#        'ROC_10', 'ROC_20', 'CCI_14', 'CCI_50', 'MOM_10', 'UO', 'KST',
#        'KST_Signal', 'BB_Upper', 'BB_Middle', 'BB_Lower', 'BB_PercentB',
#        'HL_Range', 'HL_EMA', 'CVI', 'STDDEV_10', 'STDDEV_20', 'Log_Returns',
#        'HV_10', 'HV_20', 'GK_Vol_10', 'GK_Vol_20', 'OBV', 'MFM', 'MFV', 'AD',
#        'CMF_20', 'FI_13', 'VROC_10', 'PVT', 'Target', 'lstmstate'],
#       dtype='object')

# %%
# Select features (5 indicators)
features = ['weekday',
       'month', 'oc', 'hl', 'oh', 'ol', 'co', 'SMA_10', 'SMA_50', 'SMA_100',
       'EMA_5', 'EMA_10', 'EMA_20', 'MACD_12_26_9', 'MACDh_12_26_9',
       'MACDs_12_26_9', 'KAMA', 'TMA_20', 'RSI_7', 'RSI_14', '%D', 'ROC_5',
       'ROC_10', 'ROC_20', 'CCI_14', 'CCI_50', 'MOM_10', 'UO', 'KST',
       'KST_Signal', 'BB_Upper', 'BB_Middle', 'BB_Lower', 'BB_PercentB',
       'HL_Range', 'HL_EMA', 'CVI', 'STDDEV_10', 'STDDEV_20', 'Log_Returns',
       'HV_10', 'HV_20', 'GK_Vol_10', 'GK_Vol_20', 'OBV', 'MFM', 'MFV', 'AD',
       'CMF_20', 'FI_13', 'VROC_10', 'PVT']
target = 'Target'

# %%
# Normalize data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[features] = scaler.fit_transform(df[features])

# %%
# Convert data into sequences for LSTM
sequence_length = 60  # Use past 60 days to predict next day

def create_sequences(data, features, target, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[features].iloc[i:i+seq_length].values)
        y.append(data[target].iloc[i+seq_length])
    return np.array(X), np.array(y)

#X, y = create_sequences(df.iloc[55:], features, target, sequence_length)
X, y = create_sequences(df, features, target, sequence_length)

# %%
len(X)
# Out:
# 2785

# %%
X.shape
# Out:
# (2785, 60, 52)

# %%
X[0].shape
# Out:
# (60, 52)

# %%
len(y)
# Out:
# 2785

# %%
df.shape
# Out:
# (2845, 61)

# %%
print(df.iloc[2152])
# Out:
# index               2252
# Close        16345.34961
# High         16418.05078
# Low              15990.0
# Open             16078.0
#                 ...
# FI_13           0.713403
# VROC_10         0.000332
# PVT             0.819998
# Target                 2
# lstmstate           None
# Name: 2152, Length: 61, dtype: object

# %%
# Define train-test split index
#split_idx = int(len(X) * 0.8)  # 80% training, 20% testing
split_idx = 2153 
# Split without shuffling
X_train, X_test = X[:split_idx], X[split_idx:]
y_train, y_test = y[:split_idx], y[split_idx:]

print(f"Train size: {len(X_train)}, Test size: {len(X_test)}")
# Out:
# Train size: 2153, Test size: 632

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer,Input, LSTM, Dense, RepeatVector, TimeDistributed, Attention, Multiply
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.optimizers import SGD

# Define Attention Layer
class AttentionLayer(Layer):
    def __init__(self):
        super(AttentionLayer, self).__init__()
        self.dense = tf.keras.layers.Dense(1, activation="tanh")  # Moved here
        self.softmax = tf.keras.layers.Softmax(axis=1)

    def call(self, lstm_output):
        attention = self.dense(lstm_output)  # Uses pre-defined layer
        attention = self.softmax(attention)
        context_vector = Multiply()([lstm_output, attention])
        return tf.reduce_sum(context_vector, axis=1)  # Context vector output

# Build Attention LSTM Model
def build_model(input_shape, lstm_units=[256, 128], dense_units=[64]):
    inputs = Input(shape=input_shape)
    
    # LSTM layers
    lstm_out = LSTM(lstm_units[0], return_sequences=True)(inputs)  # First LSTM layer
    lstm_out = Dropout(0.2)(lstm_out)
    lstm_out = BatchNormalization()(lstm_out)
    lstm_out = LSTM(lstm_units[1], return_sequences=True)(lstm_out)  # Second LSTM layer
    lstm_out = Dropout(0.2)(lstm_out)
    lstm_out = BatchNormalization()(lstm_out)

    # Attention layer
    attention_out = AttentionLayer()(lstm_out)

    # Dense layers
    dense_out = attention_out
    for units in dense_units:
        dense_out = Dense(units)(dense_out)  # Add hidden dense layers
        dense_out = BatchNormalization()(dense_out) 
        dense_out = LeakyReLU(alpha=0.01)(dense_out)

    output = Dense(3, activation='softmax')(dense_out)  # Output layer
    
    model = Model(inputs, output)
    #model.compile(optimizer=AdamW(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])
    optimizer = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# Example: Using 2 LSTM layers (64 and 32 neurons), 2 Dense layers (16 and 8 neurons)
input_shape = (sequence_length, len(features))  # 60 time steps, 52 indicators
model = build_model(input_shape, lstm_units=[256, 128], dense_units=[64, 64])
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\IIITNAGPUR\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:216: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# C:\Users\IIITNAGPUR\anaconda3\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 60, 52)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 60, 256)             │         316,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 60, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 60, 256)             │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 60, 128)             │         197,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 60, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 60, 128)             │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ attention_layer (AttentionLayer)     │ (None, 128)                 │             129 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu (LeakyReLU)              │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)            │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 3)                   │             195 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 528,324 (2.02 MB)
#  Trainable params: 527,300 (2.01 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
history = model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 17s 163ms/step - accuracy: 0.3786 - loss: 1.1359 - val_accuracy: 0.3940 - val_loss: 1.1253
# Epoch 2/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 137ms/step - accuracy: 0.4202 - loss: 1.0717 - val_accuracy: 0.3766 - val_loss: 1.0745
# Epoch 3/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 170ms/step - accuracy: 0.4278 - loss: 1.0525 - val_accuracy: 0.3782 - val_loss: 1.0935
# Epoch 4/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 158ms/step - accuracy: 0.4235 - loss: 1.0444 - val_accuracy: 0.3782 - val_loss: 1.0746
# Epoch 5/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 157ms/step - accuracy: 0.4136 - loss: 1.0484 - val_accuracy: 0.3782 - val_loss: 1.1034
# Epoch 6/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 172ms/step - accuracy: 0.4400 - loss: 1.0503 - val_accuracy: 0.3782 - val_loss: 1.1360
# Epoch 7/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.4434 - loss: 1.0403 - val_accuracy: 0.3782 - val_loss: 1.1080
# Epoch 8/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 173ms/step - accuracy: 0.4512 - loss: 1.0445 - val_accuracy: 0.3940 - val_loss: 1.0934
# Epoch 9/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.4239 - loss: 1.0536 - val_accuracy: 0.3940 - val_loss: 1.3543
# Epoch 10/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 174ms/step - accuracy: 0.4304 - loss: 1.0405 - val_accuracy: 0.3782 - val_loss: 1.2133
# Epoch 11/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 176ms/step - accuracy: 0.4385 - loss: 1.0458 - val_accuracy: 0.2278 - val_loss: 1.1551
# Epoch 12/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.4415 - loss: 1.0268 - val_accuracy: 0.3940 - val_loss: 1.0843
# Epoch 13/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 125ms/step - accuracy: 0.4420 - loss: 1.0323 - val_accuracy: 0.3829 - val_loss: 1.0949
# Epoch 14/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 190ms/step - accuracy: 0.4268 - loss: 1.0472 - val_accuracy: 0.3924 - val_loss: 1.1211
# Epoch 15/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 184ms/step - accuracy: 0.4516 - loss: 1.0266 - val_accuracy: 0.3940 - val_loss: 1.0974
# Epoch 16/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 151ms/step - accuracy: 0.4287 - loss: 1.0356 - val_accuracy: 0.3782 - val_loss: 1.0834
# Epoch 17/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 168ms/step - accuracy: 0.4239 - loss: 1.0313 - val_accuracy: 0.3782 - val_loss: 1.1323
# Epoch 18/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 186ms/step - accuracy: 0.4353 - loss: 1.0451 - val_accuracy: 0.3766 - val_loss: 1.2516
# Epoch 19/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 171ms/step - accuracy: 0.4493 - loss: 1.0384 - val_accuracy: 0.3940 - val_loss: 1.1572
# Epoch 20/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 185ms/step - accuracy: 0.4455 - loss: 1.0285 - val_accuracy: 0.4003 - val_loss: 1.1424
# Epoch 21/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 179ms/step - accuracy: 0.4367 - loss: 1.0367 - val_accuracy: 0.3544 - val_loss: 1.1234
# Epoch 22/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 180ms/step - accuracy: 0.4423 - loss: 1.0350 - val_accuracy: 0.4003 - val_loss: 1.1417
# Epoch 23/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 182ms/step - accuracy: 0.4424 - loss: 1.0252 - val_accuracy: 0.3782 - val_loss: 1.1229
# Epoch 24/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 155ms/step - accuracy: 0.4331 - loss: 1.0287 - val_accuracy: 0.3940 - val_loss: 1.1198
# Epoch 25/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 181ms/step - accuracy: 0.4359 - loss: 1.0253 - val_accuracy: 0.4082 - val_loss: 1.1456
# Epoch 26/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 187ms/step - accuracy: 0.4472 - loss: 1.0186 - val_accuracy: 0.2373 - val_loss: 1.3286
# Epoch 27/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 184ms/step - accuracy: 0.4323 - loss: 1.0325 - val_accuracy: 0.3940 - val_loss: 1.2776
# Epoch 28/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 189ms/step - accuracy: 0.4717 - loss: 1.0176 - val_accuracy: 0.3797 - val_loss: 1.2477
# Epoch 29/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 186ms/step - accuracy: 0.4365 - loss: 1.0331 - val_accuracy: 0.3750 - val_loss: 1.1121
# Epoch 30/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.4412 - loss: 1.0384 - val_accuracy: 0.3829 - val_loss: 1.1313
# Epoch 31/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 171ms/step - accuracy: 0.4405 - loss: 1.0451 - val_accuracy: 0.4146 - val_loss: 1.1069
# Epoch 32/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 151ms/step - accuracy: 0.4466 - loss: 1.0362 - val_accuracy: 0.3940 - val_loss: 1.2547
# Epoch 33/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 164ms/step - accuracy: 0.4651 - loss: 1.0225 - val_accuracy: 0.3940 - val_loss: 1.1914
# Epoch 34/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 156ms/step - accuracy: 0.4326 - loss: 1.0251 - val_accuracy: 0.3987 - val_loss: 1.1166
# Epoch 35/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 141ms/step - accuracy: 0.4655 - loss: 1.0122 - val_accuracy: 0.3940 - val_loss: 1.2235
# Epoch 36/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 185ms/step - accuracy: 0.4379 - loss: 1.0242 - val_accuracy: 0.3940 - val_loss: 1.2583
# Epoch 37/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 177ms/step - accuracy: 0.4621 - loss: 1.0210 - val_accuracy: 0.3892 - val_loss: 1.0903
# Epoch 38/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 176ms/step - accuracy: 0.4716 - loss: 1.0112 - val_accuracy: 0.3940 - val_loss: 1.2507
# Epoch 39/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 185ms/step - accuracy: 0.4690 - loss: 1.0209 - val_accuracy: 0.4082 - val_loss: 1.1059
# Epoch 40/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 170ms/step - accuracy: 0.4678 - loss: 1.0191 - val_accuracy: 0.3829 - val_loss: 1.1069
# Epoch 41/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 156ms/step - accuracy: 0.4696 - loss: 1.0253 - val_accuracy: 0.3940 - val_loss: 1.2862
# Epoch 42/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 162ms/step - accuracy: 0.4816 - loss: 1.0135 - val_accuracy: 0.3813 - val_loss: 1.1212
# Epoch 43/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 154ms/step - accuracy: 0.4793 - loss: 1.0081 - val_accuracy: 0.3940 - val_loss: 1.2472
# Epoch 44/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 166ms/step - accuracy: 0.4711 - loss: 1.0106 - val_accuracy: 0.3940 - val_loss: 1.1242
# Epoch 45/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 176ms/step - accuracy: 0.4614 - loss: 1.0249 - val_accuracy: 0.2674 - val_loss: 1.1864
# Epoch 46/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 138ms/step - accuracy: 0.4506 - loss: 1.0216 - val_accuracy: 0.3940 - val_loss: 1.2887
# Epoch 47/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 7s 105ms/step - accuracy: 0.4746 - loss: 1.0010 - val_accuracy: 0.3734 - val_loss: 1.0934
# Epoch 48/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 167ms/step - accuracy: 0.4580 - loss: 1.0212 - val_accuracy: 0.4161 - val_loss: 1.1818
# Epoch 49/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 138ms/step - accuracy: 0.4723 - loss: 1.0184 - val_accuracy: 0.3924 - val_loss: 1.0879
# Epoch 50/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 139ms/step - accuracy: 0.4714 - loss: 1.0025 - val_accuracy: 0.4066 - val_loss: 1.1231
# Epoch 51/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 160ms/step - accuracy: 0.4549 - loss: 1.0150 - val_accuracy: 0.3782 - val_loss: 1.2259
# Epoch 52/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 136ms/step - accuracy: 0.4721 - loss: 1.0234 - val_accuracy: 0.3782 - val_loss: 1.1337
# Epoch 53/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 146ms/step - accuracy: 0.4643 - loss: 1.0103 - val_accuracy: 0.3940 - val_loss: 1.3613
# Epoch 54/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 176ms/step - accuracy: 0.4668 - loss: 1.0079 - val_accuracy: 0.3892 - val_loss: 1.0768
# Epoch 55/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.4781 - loss: 1.0113 - val_accuracy: 0.3972 - val_loss: 1.2093
# Epoch 56/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 142ms/step - accuracy: 0.4586 - loss: 1.0098 - val_accuracy: 0.3940 - val_loss: 1.1662
# Epoch 57/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 152ms/step - accuracy: 0.4976 - loss: 0.9972 - val_accuracy: 0.3940 - val_loss: 1.2599
# Epoch 58/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.4457 - loss: 1.0170 - val_accuracy: 0.4035 - val_loss: 1.0859
# Epoch 59/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 129ms/step - accuracy: 0.4615 - loss: 1.0058 - val_accuracy: 0.3877 - val_loss: 1.0836
# Epoch 60/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 133ms/step - accuracy: 0.4731 - loss: 1.0131 - val_accuracy: 0.3908 - val_loss: 1.2486
# Epoch 61/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 134ms/step - accuracy: 0.4736 - loss: 1.0104 - val_accuracy: 0.3718 - val_loss: 1.1017
# Epoch 62/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 152ms/step - accuracy: 0.4590 - loss: 1.0074 - val_accuracy: 0.3940 - val_loss: 1.1905
# Epoch 63/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 172ms/step - accuracy: 0.4633 - loss: 1.0200 - val_accuracy: 0.4035 - val_loss: 1.1657
# Epoch 64/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 201ms/step - accuracy: 0.4614 - loss: 1.0200 - val_accuracy: 0.3940 - val_loss: 1.1269
# Epoch 65/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 172ms/step - accuracy: 0.4641 - loss: 1.0085 - val_accuracy: 0.4066 - val_loss: 1.0868
# Epoch 66/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 143ms/step - accuracy: 0.4797 - loss: 1.0068 - val_accuracy: 0.3940 - val_loss: 1.2367
# Epoch 67/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 129ms/step - accuracy: 0.4716 - loss: 1.0022 - val_accuracy: 0.4082 - val_loss: 1.1469
# Epoch 68/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 138ms/step - accuracy: 0.4835 - loss: 0.9954 - val_accuracy: 0.3750 - val_loss: 1.1286
# Epoch 69/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 112ms/step - accuracy: 0.4923 - loss: 0.9990 - val_accuracy: 0.4146 - val_loss: 1.1264
# Epoch 70/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 137ms/step - accuracy: 0.4878 - loss: 0.9947 - val_accuracy: 0.3940 - val_loss: 1.2128
# Epoch 71/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.4786 - loss: 1.0049 - val_accuracy: 0.4256 - val_loss: 1.1014
# Epoch 72/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 171ms/step - accuracy: 0.4656 - loss: 1.0103 - val_accuracy: 0.4019 - val_loss: 1.1102
# Epoch 73/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 182ms/step - accuracy: 0.5074 - loss: 0.9844 - val_accuracy: 0.4035 - val_loss: 1.1025
# Epoch 74/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 180ms/step - accuracy: 0.4902 - loss: 1.0072 - val_accuracy: 0.3987 - val_loss: 1.0935
# Epoch 75/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 195ms/step - accuracy: 0.4616 - loss: 0.9926 - val_accuracy: 0.3940 - val_loss: 1.1097
# Epoch 76/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 194ms/step - accuracy: 0.4795 - loss: 0.9989 - val_accuracy: 0.3845 - val_loss: 1.0997
# Epoch 77/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 192ms/step - accuracy: 0.4674 - loss: 1.0111 - val_accuracy: 0.3956 - val_loss: 1.1052
# Epoch 78/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 188ms/step - accuracy: 0.4767 - loss: 0.9959 - val_accuracy: 0.4066 - val_loss: 1.1784
# Epoch 79/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 179ms/step - accuracy: 0.4935 - loss: 0.9832 - val_accuracy: 0.3940 - val_loss: 1.2316
# Epoch 80/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 194ms/step - accuracy: 0.5058 - loss: 0.9888 - val_accuracy: 0.3782 - val_loss: 1.1704
# Epoch 81/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 195ms/step - accuracy: 0.4943 - loss: 0.9840 - val_accuracy: 0.3734 - val_loss: 1.1260
# Epoch 82/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 200ms/step - accuracy: 0.4808 - loss: 0.9945 - val_accuracy: 0.3718 - val_loss: 1.1017
# Epoch 83/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 191ms/step - accuracy: 0.4819 - loss: 0.9935 - val_accuracy: 0.3940 - val_loss: 1.1183
# Epoch 84/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 14s 200ms/step - accuracy: 0.4970 - loss: 0.9915 - val_accuracy: 0.3908 - val_loss: 1.1327
# Epoch 85/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 194ms/step - accuracy: 0.4714 - loss: 0.9966 - val_accuracy: 0.3987 - val_loss: 1.0874
# Epoch 86/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 174ms/step - accuracy: 0.4998 - loss: 0.9701 - val_accuracy: 0.3940 - val_loss: 1.0980
# Epoch 87/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 182ms/step - accuracy: 0.4868 - loss: 1.0006 - val_accuracy: 0.3782 - val_loss: 1.0851
# Epoch 88/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 195ms/step - accuracy: 0.4916 - loss: 0.9826 - val_accuracy: 0.3877 - val_loss: 1.1052
# Epoch 89/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 177ms/step - accuracy: 0.4773 - loss: 0.9992 - val_accuracy: 0.3829 - val_loss: 1.1365
# Epoch 90/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 185ms/step - accuracy: 0.5058 - loss: 0.9712 - val_accuracy: 0.3924 - val_loss: 1.2469
# Epoch 91/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 175ms/step - accuracy: 0.4992 - loss: 0.9732 - val_accuracy: 0.3671 - val_loss: 1.1056
# Epoch 92/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 187ms/step - accuracy: 0.4952 - loss: 0.9751 - val_accuracy: 0.3845 - val_loss: 1.1085
# Epoch 93/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 177ms/step - accuracy: 0.4812 - loss: 0.9815 - val_accuracy: 0.3291 - val_loss: 1.2015
# Epoch 94/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 184ms/step - accuracy: 0.4831 - loss: 0.9755 - val_accuracy: 0.3956 - val_loss: 1.1137
# Epoch 95/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 189ms/step - accuracy: 0.4974 - loss: 0.9757 - val_accuracy: 0.3465 - val_loss: 1.1104
# Epoch 96/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 190ms/step - accuracy: 0.4875 - loss: 0.9827 - val_accuracy: 0.3987 - val_loss: 1.1198
# Epoch 97/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 180ms/step - accuracy: 0.5240 - loss: 0.9521 - val_accuracy: 0.4019 - val_loss: 1.1075
# Epoch 98/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 175ms/step - accuracy: 0.5032 - loss: 0.9600 - val_accuracy: 0.4051 - val_loss: 1.0937
# Epoch 99/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 185ms/step - accuracy: 0.4893 - loss: 0.9832 - val_accuracy: 0.3940 - val_loss: 1.1249
# Epoch 100/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 191ms/step - accuracy: 0.5048 - loss: 0.9616 - val_accuracy: 0.3940 - val_loss: 1.1822
# Epoch 101/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 186ms/step - accuracy: 0.5177 - loss: 0.9613 - val_accuracy: 0.3513 - val_loss: 1.1054
# Epoch 102/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 179ms/step - accuracy: 0.5050 - loss: 0.9729 - val_accuracy: 0.3940 - val_loss: 1.2004
# Epoch 103/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 182ms/step - accuracy: 0.5044 - loss: 0.9561 - val_accuracy: 0.3924 - val_loss: 1.1116
# Epoch 104/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 191ms/step - accuracy: 0.5050 - loss: 0.9692 - val_accuracy: 0.3987 - val_loss: 1.0988
# Epoch 105/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 188ms/step - accuracy: 0.5058 - loss: 0.9572 - val_accuracy: 0.4019 - val_loss: 1.1654
# Epoch 106/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 160ms/step - accuracy: 0.5179 - loss: 0.9532 - val_accuracy: 0.3940 - val_loss: 1.2248
# Epoch 107/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 190ms/step - accuracy: 0.5120 - loss: 0.9595 - val_accuracy: 0.4098 - val_loss: 1.1469
# Epoch 108/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 177ms/step - accuracy: 0.5195 - loss: 0.9490 - val_accuracy: 0.3829 - val_loss: 1.1089
# Epoch 109/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 180ms/step - accuracy: 0.5019 - loss: 0.9581 - val_accuracy: 0.3956 - val_loss: 1.0960
# Epoch 110/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 186ms/step - accuracy: 0.5055 - loss: 0.9442 - val_accuracy: 0.3924 - val_loss: 1.1108
# Epoch 111/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 179ms/step - accuracy: 0.4936 - loss: 0.9532 - val_accuracy: 0.4019 - val_loss: 1.1121
# Epoch 112/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 195ms/step - accuracy: 0.5193 - loss: 0.9474 - val_accuracy: 0.3940 - val_loss: 1.3365
# Epoch 113/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 176ms/step - accuracy: 0.5229 - loss: 0.9620 - val_accuracy: 0.3972 - val_loss: 1.1464
# Epoch 114/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 185ms/step - accuracy: 0.5072 - loss: 0.9476 - val_accuracy: 0.4177 - val_loss: 1.1601
# Epoch 115/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 150ms/step - accuracy: 0.5334 - loss: 0.9393 - val_accuracy: 0.3940 - val_loss: 1.1637
# Epoch 116/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 156ms/step - accuracy: 0.5247 - loss: 0.9431 - val_accuracy: 0.3940 - val_loss: 1.1318
# Epoch 117/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 111ms/step - accuracy: 0.5214 - loss: 0.9533 - val_accuracy: 0.3940 - val_loss: 1.2481
# Epoch 118/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 132ms/step - accuracy: 0.5211 - loss: 0.9553 - val_accuracy: 0.3908 - val_loss: 1.2087
# Epoch 119/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 137ms/step - accuracy: 0.5119 - loss: 0.9589 - val_accuracy: 0.3924 - val_loss: 1.1572
# Epoch 120/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 136ms/step - accuracy: 0.5069 - loss: 0.9382 - val_accuracy: 0.4003 - val_loss: 1.1583
# Epoch 121/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 159ms/step - accuracy: 0.5134 - loss: 0.9447 - val_accuracy: 0.3972 - val_loss: 1.1230
# Epoch 122/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 150ms/step - accuracy: 0.5452 - loss: 0.9274 - val_accuracy: 0.3908 - val_loss: 1.1508
# Epoch 123/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 154ms/step - accuracy: 0.5402 - loss: 0.9250 - val_accuracy: 0.4082 - val_loss: 1.1452
# Epoch 124/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 170ms/step - accuracy: 0.5174 - loss: 0.9515 - val_accuracy: 0.4082 - val_loss: 1.1391
# Epoch 125/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 170ms/step - accuracy: 0.5377 - loss: 0.9364 - val_accuracy: 0.4003 - val_loss: 1.1392
# Epoch 126/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 161ms/step - accuracy: 0.5379 - loss: 0.9270 - val_accuracy: 0.3671 - val_loss: 1.1309
# Epoch 127/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 185ms/step - accuracy: 0.5321 - loss: 0.9401 - val_accuracy: 0.3972 - val_loss: 1.4231
# Epoch 128/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 174ms/step - accuracy: 0.5161 - loss: 0.9497 - val_accuracy: 0.3861 - val_loss: 1.1275
# Epoch 129/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 185ms/step - accuracy: 0.5136 - loss: 0.9510 - val_accuracy: 0.3782 - val_loss: 1.1469
# Epoch 130/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 189ms/step - accuracy: 0.5270 - loss: 0.9334 - val_accuracy: 0.3956 - val_loss: 1.1301
# Epoch 131/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 167ms/step - accuracy: 0.5179 - loss: 0.9391 - val_accuracy: 0.3972 - val_loss: 1.1157
# Epoch 132/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 170ms/step - accuracy: 0.5331 - loss: 0.9374 - val_accuracy: 0.3940 - val_loss: 1.2915
# Epoch 133/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 194ms/step - accuracy: 0.5279 - loss: 0.9352 - val_accuracy: 0.4130 - val_loss: 1.1622
# Epoch 134/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 186ms/step - accuracy: 0.5226 - loss: 0.9293 - val_accuracy: 0.3687 - val_loss: 1.0969
# Epoch 135/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 189ms/step - accuracy: 0.5347 - loss: 0.9221 - val_accuracy: 0.3956 - val_loss: 1.1415
# Epoch 136/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 153ms/step - accuracy: 0.5546 - loss: 0.9099 - val_accuracy: 0.3766 - val_loss: 1.1290
# Epoch 137/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 193ms/step - accuracy: 0.5025 - loss: 0.9524 - val_accuracy: 0.4003 - val_loss: 1.2205
# Epoch 138/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 159ms/step - accuracy: 0.5297 - loss: 0.9204 - val_accuracy: 0.3544 - val_loss: 1.0988
# Epoch 139/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 169ms/step - accuracy: 0.5315 - loss: 0.9087 - val_accuracy: 0.3940 - val_loss: 1.1598
# Epoch 140/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 166ms/step - accuracy: 0.5365 - loss: 0.9145 - val_accuracy: 0.4114 - val_loss: 1.1749
# Epoch 141/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 190ms/step - accuracy: 0.5445 - loss: 0.9242 - val_accuracy: 0.3497 - val_loss: 1.1345
# Epoch 142/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 172ms/step - accuracy: 0.5313 - loss: 0.9182 - val_accuracy: 0.3972 - val_loss: 1.2413
# Epoch 143/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 159ms/step - accuracy: 0.5326 - loss: 0.9149 - val_accuracy: 0.4003 - val_loss: 1.1633
# Epoch 144/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 151ms/step - accuracy: 0.5234 - loss: 0.9282 - val_accuracy: 0.4130 - val_loss: 1.1446
# Epoch 145/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 184ms/step - accuracy: 0.5399 - loss: 0.9183 - val_accuracy: 0.3956 - val_loss: 1.3568
# Epoch 146/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 180ms/step - accuracy: 0.5469 - loss: 0.9047 - val_accuracy: 0.4130 - val_loss: 1.1326
# Epoch 147/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 173ms/step - accuracy: 0.5339 - loss: 0.9177 - val_accuracy: 0.4130 - val_loss: 1.0931
# Epoch 148/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 165ms/step - accuracy: 0.5465 - loss: 0.9201 - val_accuracy: 0.3544 - val_loss: 1.1371
# Epoch 149/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 145ms/step - accuracy: 0.5526 - loss: 0.9078 - val_accuracy: 0.3861 - val_loss: 1.1979
# Epoch 150/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 179ms/step - accuracy: 0.5346 - loss: 0.9187 - val_accuracy: 0.3829 - val_loss: 1.1068
# Epoch 151/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 195ms/step - accuracy: 0.5550 - loss: 0.8975 - val_accuracy: 0.4051 - val_loss: 1.1364
# Epoch 152/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 197ms/step - accuracy: 0.5333 - loss: 0.9047 - val_accuracy: 0.3845 - val_loss: 1.1856
# Epoch 153/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 189ms/step - accuracy: 0.5353 - loss: 0.8992 - val_accuracy: 0.4146 - val_loss: 1.1252
# Epoch 154/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 188ms/step - accuracy: 0.5407 - loss: 0.9117 - val_accuracy: 0.3956 - val_loss: 1.1569
# Epoch 155/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 196ms/step - accuracy: 0.5446 - loss: 0.9040 - val_accuracy: 0.4161 - val_loss: 1.1220
# Epoch 156/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 185ms/step - accuracy: 0.5431 - loss: 0.9003 - val_accuracy: 0.4051 - val_loss: 1.2059
# Epoch 157/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 193ms/step - accuracy: 0.5427 - loss: 0.8991 - val_accuracy: 0.4019 - val_loss: 1.1321
# Epoch 158/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 194ms/step - accuracy: 0.5556 - loss: 0.9072 - val_accuracy: 0.3877 - val_loss: 1.1150
# Epoch 159/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 184ms/step - accuracy: 0.5725 - loss: 0.8785 - val_accuracy: 0.4193 - val_loss: 1.1621
# Epoch 160/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 187ms/step - accuracy: 0.5590 - loss: 0.8839 - val_accuracy: 0.3766 - val_loss: 1.1107
# Epoch 161/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 197ms/step - accuracy: 0.5424 - loss: 0.8965 - val_accuracy: 0.3908 - val_loss: 1.2124
# Epoch 162/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 189ms/step - accuracy: 0.5790 - loss: 0.8702 - val_accuracy: 0.3576 - val_loss: 1.1461
# Epoch 163/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 176ms/step - accuracy: 0.5312 - loss: 0.9242 - val_accuracy: 0.4130 - val_loss: 1.2877
# Epoch 164/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 173ms/step - accuracy: 0.5514 - loss: 0.9006 - val_accuracy: 0.3924 - val_loss: 1.4744
# Epoch 165/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 188ms/step - accuracy: 0.5515 - loss: 0.8865 - val_accuracy: 0.3877 - val_loss: 1.1652
# Epoch 166/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 174ms/step - accuracy: 0.5623 - loss: 0.8732 - val_accuracy: 0.3750 - val_loss: 1.1777
# Epoch 167/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 168ms/step - accuracy: 0.5508 - loss: 0.8993 - val_accuracy: 0.3987 - val_loss: 1.1766
# Epoch 168/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.5547 - loss: 0.8789 - val_accuracy: 0.4019 - val_loss: 1.2008
# Epoch 169/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.5508 - loss: 0.8994 - val_accuracy: 0.3750 - val_loss: 1.1333
# Epoch 170/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 183ms/step - accuracy: 0.5672 - loss: 0.8764 - val_accuracy: 0.3655 - val_loss: 1.1206
# Epoch 171/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 166ms/step - accuracy: 0.5622 - loss: 0.8922 - val_accuracy: 0.3766 - val_loss: 1.1727
# Epoch 172/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 186ms/step - accuracy: 0.5659 - loss: 0.8735 - val_accuracy: 0.3892 - val_loss: 1.2831
# Epoch 173/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 167ms/step - accuracy: 0.5653 - loss: 0.8715 - val_accuracy: 0.3908 - val_loss: 1.1617
# Epoch 174/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 155ms/step - accuracy: 0.5833 - loss: 0.8574 - val_accuracy: 0.3813 - val_loss: 1.2896
# Epoch 175/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 189ms/step - accuracy: 0.5670 - loss: 0.8708 - val_accuracy: 0.3940 - val_loss: 1.4630
# Epoch 176/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 187ms/step - accuracy: 0.5552 - loss: 0.8861 - val_accuracy: 0.3829 - val_loss: 1.1332
# Epoch 177/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 188ms/step - accuracy: 0.5625 - loss: 0.8529 - val_accuracy: 0.4114 - val_loss: 1.1772
# Epoch 178/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 134ms/step - accuracy: 0.5926 - loss: 0.8440 - val_accuracy: 0.3528 - val_loss: 1.1405
# Epoch 179/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.5815 - loss: 0.8672 - val_accuracy: 0.3940 - val_loss: 1.1638
# Epoch 180/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 170ms/step - accuracy: 0.5667 - loss: 0.8527 - val_accuracy: 0.4272 - val_loss: 1.2028
# Epoch 181/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 143ms/step - accuracy: 0.5665 - loss: 0.8537 - val_accuracy: 0.4003 - val_loss: 1.2460
# Epoch 182/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 8s 118ms/step - accuracy: 0.5602 - loss: 0.8468 - val_accuracy: 0.3924 - val_loss: 1.5638
# Epoch 183/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 160ms/step - accuracy: 0.5840 - loss: 0.8491 - val_accuracy: 0.4114 - val_loss: 1.3627
# Epoch 184/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 128ms/step - accuracy: 0.5959 - loss: 0.8373 - val_accuracy: 0.3892 - val_loss: 1.2374
# Epoch 185/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.5831 - loss: 0.8342 - val_accuracy: 0.3829 - val_loss: 1.2197
# Epoch 186/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 10s 140ms/step - accuracy: 0.5647 - loss: 0.8635 - val_accuracy: 0.3370 - val_loss: 1.2564
# Epoch 187/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 177ms/step - accuracy: 0.5890 - loss: 0.8510 - val_accuracy: 0.3797 - val_loss: 1.2905
# Epoch 188/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 173ms/step - accuracy: 0.5879 - loss: 0.8545 - val_accuracy: 0.3750 - val_loss: 1.2992
# Epoch 189/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 181ms/step - accuracy: 0.5874 - loss: 0.8398 - val_accuracy: 0.3987 - val_loss: 1.3562
# Epoch 190/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 169ms/step - accuracy: 0.5938 - loss: 0.8219 - val_accuracy: 0.3972 - val_loss: 1.2989
# Epoch 191/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 165ms/step - accuracy: 0.6006 - loss: 0.8160 - val_accuracy: 0.3718 - val_loss: 1.1987
# Epoch 192/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 181ms/step - accuracy: 0.5942 - loss: 0.8148 - val_accuracy: 0.3734 - val_loss: 1.2761
# Epoch 193/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 176ms/step - accuracy: 0.5882 - loss: 0.8380 - val_accuracy: 0.3877 - val_loss: 1.2009
# Epoch 194/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 174ms/step - accuracy: 0.5992 - loss: 0.8191 - val_accuracy: 0.3940 - val_loss: 1.4132
# Epoch 195/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 181ms/step - accuracy: 0.5823 - loss: 0.8359 - val_accuracy: 0.3845 - val_loss: 1.1677
# Epoch 196/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 11s 168ms/step - accuracy: 0.5838 - loss: 0.8410 - val_accuracy: 0.3908 - val_loss: 1.1561
# Epoch 197/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 176ms/step - accuracy: 0.6067 - loss: 0.8144 - val_accuracy: 0.4161 - val_loss: 1.1666
# Epoch 198/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 171ms/step - accuracy: 0.5914 - loss: 0.8124 - val_accuracy: 0.3528 - val_loss: 1.2037
# Epoch 199/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 12s 176ms/step - accuracy: 0.6116 - loss: 0.7954 - val_accuracy: 0.4003 - val_loss: 1.2244
# Epoch 200/200
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 13s 186ms/step - accuracy: 0.6111 - loss: 0.8224 - val_accuracy: 0.4019 - val_loss: 1.1734

# %%
# Evaluate model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.2f}")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.4144 - loss: 1.1069
# Test Accuracy: 0.40

# %%
# Plot Training History
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.legend()
plt.show()

# %%
# Make a prediction
predicted = model.predict(X)
print(predicted)
#print("Predicted Trend:", "UP" if predicted[0] > 0.5 else "DOWN")
# Out:
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step
# [[0.27293596 0.03738177 0.68968225]
#  [0.39391553 0.0877608  0.51832366]
#  [0.29151282 0.1286324  0.5798547 ]
#  ...
#  [0.06385864 0.42801568 0.50812566]
#  [0.10813166 0.44821063 0.44365764]
#  [0.17844146 0.32327583 0.49828276]]

# %%
# Convert probabilities to class labels
predicted_classes = np.argmax(predicted, axis=1)  # Get the index of the max value per row

# %%
predicted_classes.shape
# Out:
# (2785,)

# %%
# Get unique elements and their frequencies
unique_elements, counts = np.unique(predicted_classes, return_counts=True)

# Display results
for element, count in zip(unique_elements, counts):
    print(f"Element: {element}, Frequency: {count}")
# Out:
# Element: 0, Frequency: 1059
# Element: 1, Frequency: 313
# Element: 2, Frequency: 1413

# %%
df.shape
# Out:
# (2845, 61)

# %%
df.iloc[59:len(df)-1, df.columns.get_loc("lstmstate")] = predicted_classes

# %%
# Compute percentage change in tomorrow's Open price relative to today's Close
df["p_co"] = ((df["Open"].shift(-1)-df["Close"]) / df["Close"]) * 100

# %%
# Apply condition, keeping NaNs unchanged
df['state'] = np.where(df['p_co'] > 0, df['lstmstate'] + 3, df['lstmstate'])

# %%
df['state'].describe()
# Out:
# count     2785
# unique       6
# top          5
# freq       993
# Name: state, dtype: int64

# %%
# Plot histogram for categorical data
df['state'].value_counts().plot(kind='bar', figsize=(10, 5), color='skyblue', edgecolor='black')

plt.xlabel('State')
plt.ylabel('Frequency')
plt.title('Histogram of States')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#df.index = pd.to_datetime(df.index)
df = df.reset_index(drop=True)
df.to_csv('temp.csv', index=True)

# %%
len(df)
# Out:
# 2845

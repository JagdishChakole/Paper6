# %%
import numpy as np
import datetime
import pandas as pd
import random

# %%
def data1():
    X=pd.read_csv('state_after_kmeans.csv')
    X = X.iloc[100:]  # Keep rows from index 19 onwards (0-based index)
    # Ensure 'Open' and 'Close' are treated as numeric
    X['cashopen']=0
    X['cash']=0
    # Ensure columns have float dtype before assignment
    X['cashopen'] = X['cashopen'].astype(float)
    X['cash'] = X['cash'].astype(float)
    X['action']=""
    X['diff']=""
    X['quantity']=""
    return X

# %%
X=data1()

# %%
print(len(X))
# Out:
# 2845

# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure()
ax=X.loc[100:2207,'Close'].plot(grid="True",figsize=(10,5), title='Nifty')
ax.set_xlabel("Trading Days")
ax.set_ylabel("Close Price")
plt.show()
#fig.savefig('nifty_close.png')

# %%
X.head()
# Out:
#      Unnamed: 0        Close         High          Low         Open  Volume  \
# 100         100  6104.299805  6125.049805  6069.799805  6120.450195  120200
# 101         101  6124.049805  6133.750000  6072.149902  6072.149902  194100
# 102         102  5985.950195  6106.250000  5975.549805  6098.700195  175300
# 103         103  5939.299805  6011.000000  5916.350098  5997.350098  112100
# 104         104  5919.450195  5981.600098  5910.250000  5941.100098  114500
#
#            date  weekday  month       SMA_10  ...    CMF_20         FI_13  \
# 100  29-05-2013        2      5  6097.199902  ...  0.097321 -8.354134e+05
# 101  30-05-2013        3      5  6092.614893  ...  0.107417  3.833475e+06
# 102  31-05-2013        4      5  6072.479932  ...  0.084902 -2.420886e+07
# 103  03-06-2013        0      6  6050.719922  ...  0.033256 -5.229509e+06
# 104  04-06-2013        1      6  6031.254932  ... -0.036799 -2.272780e+06
#
#        VROC_10          PVT  Cluster  cashopen  cash  action  diff  quantity
# 100 -21.897336 -3061.705179      0.0       0.0   0.0
# 101  22.383354 -2433.709319      0.0       0.0   0.0
# 102  19.008826 -6386.789782      0.0       0.0   0.0
# 103  -8.340147 -7260.420291      0.0       0.0   0.0
# 104 -12.327718 -7643.088353      0.0       0.0   0.0
#
# [5 rows x 60 columns]

# %%
X['Cluster'].value_counts()
# Out:
# Cluster
# 0.0    1648
# 1.0     736
# 4.0     276
# 3.0     168
# 5.0       9
# 2.0       8
# Name: count, dtype: int64

# %%
#X.head()

# %%
def getState(t):
    t = int(t)
    return(X['Cluster'][t])

# %%
class Agent:
    def __init__(self):
        self.epsilon = 1.0
        self.gamma = 0.618
        self.epsilon_decay = 0.999
        self.epsilon_min = 0.01
        self.Q = np.matrix(np.zeros([6,3]))
        self.learning_rate=0.03
        
    def getAction(self,state):
        state = int(state)
        a=[1,0,2]
        if np.random.rand() <= self.epsilon:
            return random.choice(a)
        return np.argmax(self.Q[state,])  
    
    # Update Q(s,a):= Q(s,a) + lr [R(s,a) + gamma * max Q(s',a') - Q(s,a)]
    def update(self,state,action,reward,next_state,next_action):
        state = int(state)
        action = int(action)
        next_state = int(next_state)
        self.Q[state,action]= self.Q[state,action] + self.learning_rate * (reward + self.gamma * np.max(self.Q[next_state, :])
                                                                - self.Q[state,action])

# %%
episode_count=100
agent=Agent()
agent.Q
m1=0
m2=0
for e in range(1,episode_count+1):
    X=data1()
    
    data_length_start=101
    data_length=2355
    state = getState(data_length_start-1)
    action = agent.getAction(state)
    
  
    capital=X.loc[data_length_start,'Open']*10
    margin=X.loc[data_length_start,'Open']*10
    #X.loc[2,'cashopen']=margin 
    X.loc[2, 'cashopen'] = float(margin)
    brok_rate=0.0000
    #brok_rate=0.0
    
    print("Episod {}/{}".format(e,episode_count))
    count=0
    for t in range(data_length_start,data_length):
                
        reward=0                        
         
        if action == 1:
            X.loc[t,'cashopen']=float(margin)
            quantity=margin//X.loc[t,'Open']
            X.loc[t,'quantity']=quantity
            margin=margin%X.loc[t,'Open']
            tbrokerage=(X.loc[t,'Open']+X.loc[t,'Close'])*brok_rate
            tprofit=(X.loc[t,'Close']-X.loc[t,'Open']-tbrokerage)*quantity
            margin=margin+tprofit+X.loc[t,'Open']*quantity
            X.loc[t,'cash']=float(margin)         
            
            #print('Long: open price @',X.loc[t,'Open'],'Close price @',X.loc[t,'Close'], 'profit=',tprofit)
            X.loc[t,'action']="long"
            X.loc[t,'diff']=(X.loc[t,'Close']-X.loc[t,'Open']-tbrokerage)*quantity
            count=count+1
            reward= max((np.log(X.loc[t,'Close'])-np.log(X.loc[t,'Open']+tbrokerage)),0)
            
       
        elif action == 2:
            X.loc[t,'cashopen']=float(margin) 
            quantity=margin//X.loc[t,'Open']
            X.loc[t,'quantity']=(-quantity)
            margin=margin%X.loc[t,'Open']
            tbrokerage=(X.loc[t,'Open']+X.loc[t,'Close'])*brok_rate
            tprofit=(X.loc[t,'Open']-X.loc[t,'Close']-tbrokerage)*quantity
            #print('in Short')
            margin=margin+tprofit+X.loc[t,'Open']*quantity
            X.loc[t,'cash']=float(margin)         
            last_action='Short'
            #print('Short: Close price @',X.loc[t,'Close'],'Open price @',X.loc[t,'Open'], 'profit=',tprofit)
            X.loc[t,'action']="short"
            X.loc[t,'diff']=(X.loc[t,'Open']-X.loc[t,'Close']-tbrokerage)*quantity
            count=count+1
            reward= max((np.log(X.loc[t,'Open'])-np.log(X.loc[t,'Close']+tbrokerage)),0)
           
        else:
            X.loc[t,'cash']=margin
            X.loc[t,'action']="Hold"
            X.loc[t,'diff']=0
            reward=0                                  
        #print(f"getState({t+1}) = '{getState(t+1)}' (Type: {type(getState(t+1))})")    
        next_state=int(getState(t))
        next_action=agent.getAction(next_state)
        agent.update(state,action,reward,next_state,next_action)
        state=next_state
        action=next_action
        
        if t==data_length-1:
                print("\n***********************\n",t)
                print("Profit is ",(margin-capital))
                print("Initial Capital is ",capital)    
                print("Current Capital is ",margin)
                roi=((margin-capital)/capital)*100
                print("%ROI is ",roi)
                bnh=((X.loc[t,'Close']-X.loc[data_length_start,'Open'])/X.loc[data_length_start,'Open'])*100
                print("% Buy and Hold=",bnh)
                print("count",count)
                print("qtable",agent.Q)
                print("epsilon",agent.epsilon)
                print("--------------------------------")
                       
        if (agent.epsilon > agent.epsilon_min) and e>1:
                       agent.epsilon *= agent.epsilon_decay
                       
    
    m3=roi
    if m3>m2:
        m1=e
        m2=m3
    #To save model  
    if e%20==0:
        np.save('rl/Qtable'+ str(e)+str('.npy'), agent.Q)
        np.save('rl/epsilon'+ str(e)+str('.npy'), agent.epsilon)
        np.save('rl/gamma'+ str(e)+str('.npy'), agent.gamma)
        np.save('rl/learning_rate'+ str(e)+str('.npy'), agent.learning_rate)
        X.to_csv('csv1/AfterTrain'+str(e)+str('.csv'))
print("e={},roi={}".format(m1,m2))
# Out:
# Episod 1/100
#
# ***********************
#  2206
# Profit is  5872.44397800033
# Initial Capital is  60721.49902
# Current Capital is  66593.94299800033
# %ROI is  9.671111670128743
# % Buy and Hold= 185.79746976081816
# count 1376
# qtable [[3.56623429e-03 6.18176600e-03 7.72009814e-03]
#  [1.69971256e-03 2.73222352e-03 3.04352863e-03]
#  [3.92508434e-05 3.14185554e-03 1.17497972e-03]
#  [1.84462591e-03 5.75660183e-03 6.08973893e-03]
#  [2.34869183e-03 6.15029648e-03 5.91728820e-03]
#  [2.50164741e-04 2.29094182e-04 1.25407505e-04]]
# epsilon 1.0
# --------------------------------
# Episod 2/100
#
# ***********************
#  2206
# Profit is  34389.82412800004
# Initial Capital is  60721.49902
# Current Capital is  95111.32314800004
# %ROI is  56.63533457346461
# % Buy and Hold= 185.79746976081816
# count 1785
# qtable [[0.00489876 0.00746934 0.01181693]
#  [0.00237001 0.0035122  0.00789708]
#  [0.00018473 0.00574012 0.00131682]
#  [0.002425   0.00596763 0.00990014]
#  [0.00328116 0.00711674 0.00726798]
#  [0.00099208 0.00058156 0.00012541]]
# epsilon 0.1217174136917078
# --------------------------------
# Episod 3/100
#
# ***********************
#  2206
# Profit is  156828.75029300014
# Initial Capital is  60721.49902
# Current Capital is  217550.24931300012
# %ROI is  258.27549191653685
# % Buy and Hold= 185.79746976081816
# count 2058
# qtable [[0.00516688 0.00596189 0.01195032]
#  [0.0024402  0.0035122  0.00928304]
#  [0.00018473 0.00907705 0.00131682]
#  [0.00270812 0.00596763 0.01095323]
#  [0.00355518 0.00701589 0.00831214]
#  [0.00173869 0.00058156 0.00012541]]
# epsilon 0.014800313667002565
# --------------------------------
# Episod 4/100
#
# ***********************
#  2206
# Profit is  210816.8057809996
# Initial Capital is  60721.49902
# Current Capital is  271538.3048009996
# %ROI is  347.18643179668913
# % Buy and Hold= 185.79746976081816
# count 2095
# qtable [[0.00522848 0.00519883 0.01215139]
#  [0.0024402  0.0035122  0.00945229]
#  [0.00018473 0.01187396 0.00131682]
#  [0.00270812 0.00596763 0.01158058]
#  [0.00355518 0.00701589 0.00859145]
#  [0.00248358 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 5/100
#
# ***********************
#  2206
# Profit is  245547.7449099999
# Initial Capital is  60721.49902
# Current Capital is  306269.2439299999
# %ROI is  404.3835360999951
# % Buy and Hold= 185.79746976081816
# count 2093
# qtable [[0.00530618 0.00540207 0.01224282]
#  [0.0024402  0.0035122  0.00948827]
#  [0.00018473 0.01420567 0.00131682]
#  [0.00280443 0.00596763 0.01169559]
#  [0.00361585 0.00701589 0.00865468]
#  [0.00318663 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 6/100
#
# ***********************
#  2206
# Profit is  235865.79197200015
# Initial Capital is  60721.49902
# Current Capital is  296587.29099200014
# %ROI is  388.4386844506464
# % Buy and Hold= 185.79746976081816
# count 2093
# qtable [[0.00547306 0.00547876 0.01202597]
#  [0.00253374 0.0035122  0.00946504]
#  [0.00018473 0.01614217 0.00131682]
#  [0.00280443 0.00596763 0.01173385]
#  [0.00361585 0.00701589 0.00867338]
#  [0.00384253 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 7/100
#
# ***********************
#  2206
# Profit is  208716.93695199955
# Initial Capital is  60721.49902
# Current Capital is  269438.43597199954
# %ROI is  343.72823517293915
# % Buy and Hold= 185.79746976081816
# count 2082
# qtable [[0.00506701 0.00507928 0.01232958]
#  [0.0026697  0.0035122  0.00946798]
#  [0.00018473 0.01775118 0.00131682]
#  [0.00280443 0.00596763 0.01176721]
#  [0.00361585 0.00701589 0.00870314]
#  [0.0044434  0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 8/100
#
# ***********************
#  2206
# Profit is  252507.9786879997
# Initial Capital is  60721.49902
# Current Capital is  313229.4777079997
# %ROI is  415.8460887219377
# % Buy and Hold= 185.79746976081816
# count 2095
# qtable [[0.00508871 0.00548763 0.01233908]
#  [0.0026697  0.0035122  0.00951607]
#  [0.00018473 0.01908632 0.00131682]
#  [0.00280443 0.00618605 0.01197347]
#  [0.00361585 0.00701589 0.00871971]
#  [0.00498687 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 9/100
#
# ***********************
#  2206
# Profit is  237450.3914129997
# Initial Capital is  60721.49902
# Current Capital is  298171.8904329997
# %ROI is  391.0483028997523
# % Buy and Hold= 185.79746976081816
# count 2094
# qtable [[0.00520961 0.00552697 0.01246383]
#  [0.0026697  0.00358883 0.00954484]
#  [0.00018473 0.02019861 0.00131682]
#  [0.00280443 0.00633356 0.0118933 ]
#  [0.00361585 0.00701589 0.00876349]
#  [0.00547635 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 10/100
#
# ***********************
#  2206
# Profit is  225231.54214899958
# Initial Capital is  60721.49902
# Current Capital is  285953.04116899957
# %ROI is  370.92553014018057
# % Buy and Hold= 185.79746976081816
# count 2091
# qtable [[0.00517301 0.0050614  0.01242895]
#  [0.0026697  0.00358883 0.00953127]
#  [0.00018473 0.02112235 0.00131682]
#  [0.00280443 0.00633356 0.01184682]
#  [0.00361585 0.00695164 0.00874013]
#  [0.00591372 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 11/100
#
# ***********************
#  2206
# Profit is  238043.11871200008
# Initial Capital is  60721.49902
# Current Capital is  298764.6177320001
# %ROI is  392.0244436547839
# % Buy and Hold= 185.79746976081816
# count 2091
# qtable [[0.00512313 0.00526985 0.01237369]
#  [0.0026697  0.00365277 0.0095556 ]
#  [0.00018473 0.02188344 0.00131682]
#  [0.00293934 0.00633356 0.01181379]
#  [0.00361585 0.00689201 0.00876177]
#  [0.00630031 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 12/100
#
# ***********************
#  2206
# Profit is  255585.44174399972
# Initial Capital is  60721.49902
# Current Capital is  316306.9407639997
# %ROI is  420.91424926749073
# % Buy and Hold= 185.79746976081816
# count 2094
# qtable [[0.00514647 0.00556349 0.01249811]
#  [0.00272973 0.00380616 0.00949549]
#  [0.00018473 0.02252636 0.00131682]
#  [0.00293934 0.00633356 0.01187781]
#  [0.00366866 0.00689201 0.00886418]
#  [0.00664606 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 13/100
#
# ***********************
#  2206
# Profit is  228938.34431300033
# Initial Capital is  60721.49902
# Current Capital is  289659.8433330003
# %ROI is  377.0301260803761
# % Buy and Hold= 185.79746976081816
# count 2095
# qtable [[0.00511748 0.00554947 0.01244282]
#  [0.00281985 0.00386352 0.00953997]
#  [0.00018473 0.02306456 0.00131682]
#  [0.00293934 0.00633356 0.01188541]
#  [0.00366866 0.00689201 0.00877496]
#  [0.00695289 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 14/100
#
# ***********************
#  2206
# Profit is  224004.4211819995
# Initial Capital is  60721.49902
# Current Capital is  284725.9202019995
# %ROI is  368.90462982183385
# % Buy and Hold= 185.79746976081816
# count 2083
# qtable [[0.00498752 0.00497937 0.01254378]
#  [0.00312713 0.00386352 0.00957203]
#  [0.00018473 0.02351667 0.00131682]
#  [0.0030365  0.00633356 0.01204325]
#  [0.00378281 0.00704783 0.00885747]
#  [0.00722702 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 15/100
#
# ***********************
#  2206
# Profit is  230041.37724200042
# Initial Capital is  60721.49902
# Current Capital is  290762.8762620004
# %ROI is  378.84667037984536
# % Buy and Hold= 185.79746976081816
# count 2093
# qtable [[0.00500987 0.00532367 0.01181756]
#  [0.00312713 0.00419249 0.00955231]
#  [0.00042421 0.02367034 0.00131682]
#  [0.0030365  0.00640578 0.01199615]
#  [0.00378281 0.00704783 0.00881449]
#  [0.00745877 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 16/100
#
# ***********************
#  2206
# Profit is  217129.92263899947
# Initial Capital is  60721.49902
# Current Capital is  277851.42165899946
# %ROI is  357.583271400271
# % Buy and Hold= 185.79746976081816
# count 2081
# qtable [[0.00505914 0.00507768 0.01254219]
#  [0.00329554 0.00419249 0.00958383]
#  [0.00042421 0.02401633 0.00131682]
#  [0.00308617 0.00640578 0.01191074]
#  [0.00395327 0.00701297 0.00896024]
#  [0.00765625 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 17/100
#
# ***********************
#  2206
# Profit is  229907.045147
# Initial Capital is  60721.49902
# Current Capital is  290628.544167
# %ROI is  378.62544380084375
# % Buy and Hold= 185.79746976081816
# count 2092
# qtable [[0.00510797 0.00545554 0.01250703]
#  [0.00337147 0.00419249 0.00957158]
#  [0.00042421 0.02431048 0.00131682]
#  [0.00308617 0.00640578 0.01194772]
#  [0.0040395  0.00701297 0.0088308 ]
#  [0.0078324  0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 18/100
#
# ***********************
#  2206
# Profit is  208581.7061659994
# Initial Capital is  60721.49902
# Current Capital is  269303.2051859994
# %ROI is  343.5055285728343
# % Buy and Hold= 185.79746976081816
# count 2094
# qtable [[0.00498183 0.00496042 0.01245372]
#  [0.00343449 0.00419249 0.00959301]
#  [0.00042421 0.02455212 0.00131682]
#  [0.00308617 0.00641819 0.01207209]
#  [0.0040395  0.00699599 0.00887206]
#  [0.00798408 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 19/100
#
# ***********************
#  2206
# Profit is  215322.29976799968
# Initial Capital is  60721.49902
# Current Capital is  276043.79878799967
# %ROI is  354.6063638795847
# % Buy and Hold= 185.79746976081816
# count 2095
# qtable [[0.00500679 0.00520547 0.01245755]
#  [0.00343449 0.00430738 0.00956278]
#  [0.00042421 0.02475618 0.00131682]
#  [0.00308617 0.00641819 0.01195179]
#  [0.00412244 0.00699599 0.0088503 ]
#  [0.00811552 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 20/100
#
# ***********************
#  2206
# Profit is  226201.33011499955
# Initial Capital is  60721.49902
# Current Capital is  286922.82913499954
# %ROI is  372.522638218294
# % Buy and Hold= 185.79746976081816
# count 2094
# qtable [[0.00504385 0.00550167 0.01249244]
#  [0.00350643 0.00430738 0.0095818 ]
#  [0.00042421 0.02492197 0.00131682]
#  [0.0031358  0.00641819 0.01192123]
#  [0.00423105 0.00695881 0.0088167 ]
#  [0.00823048 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 21/100
#
# ***********************
#  2206
# Profit is  217231.84414499957
# Initial Capital is  60721.49902
# Current Capital is  277953.34316499956
# %ROI is  357.7511221741238
# % Buy and Hold= 185.79746976081816
# count 2093
# qtable [[0.00505948 0.00507309 0.01246169]
#  [0.00350643 0.00464256 0.00948935]
#  [0.00042421 0.0250659  0.00131682]
#  [0.0031358  0.00641819 0.01195637]
#  [0.00437067 0.00695881 0.00885304]
#  [0.00833078 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 22/100
#
# ***********************
#  2206
# Profit is  260843.33288600092
# Initial Capital is  60721.49902
# Current Capital is  321564.8319060009
# %ROI is  429.57327650966954
# % Buy and Hold= 185.79746976081816
# count 2089
# qtable [[0.00519932 0.00535446 0.01250338]
#  [0.0035623  0.00464256 0.00956419]
#  [0.00042421 0.02518944 0.00131682]
#  [0.0031358  0.00641819 0.01196255]
#  [0.00437067 0.0072211  0.00883907]
#  [0.00842213 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 23/100
#
# ***********************
#  2206
# Profit is  261348.93646400032
# Initial Capital is  60721.49902
# Current Capital is  322070.4354840003
# %ROI is  430.40593641787257
# % Buy and Hold= 185.79746976081816
# count 2094
# qtable [[0.00521433 0.00538129 0.01252938]
#  [0.0036409  0.00474531 0.00962016]
#  [0.00042421 0.02529121 0.00131682]
#  [0.0031358  0.00787683 0.01219835]
#  [0.00437067 0.0072211  0.00886093]
#  [0.00849883 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 24/100
#
# ***********************
#  2206
# Profit is  252112.3778549998
# Initial Capital is  60721.49902
# Current Capital is  312833.8768749998
# %ROI is  415.1945882824152
# % Buy and Hold= 185.79746976081816
# count 2094
# qtable [[0.00552453 0.00555919 0.01256463]
#  [0.00370717 0.00494102 0.00963207]
#  [0.00042421 0.02537808 0.00131682]
#  [0.0031358  0.00787683 0.01198594]
#  [0.00437067 0.0072211  0.00885594]
#  [0.00856427 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 25/100
#
# ***********************
#  2206
# Profit is  231322.7278170003
# Initial Capital is  60721.49902
# Current Capital is  292044.2268370003
# %ROI is  380.956879442006
# % Buy and Hold= 185.79746976081816
# count 2087
# qtable [[0.00535667 0.00534561 0.01248366]
#  [0.00383515 0.00494102 0.00958721]
#  [0.00042421 0.0254479  0.00131682]
#  [0.0031358  0.00787683 0.0119637 ]
#  [0.00437067 0.0072211  0.00883566]
#  [0.00862068 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 26/100
#
# ***********************
#  2206
# Profit is  237819.58543200028
# Initial Capital is  60721.49902
# Current Capital is  298541.0844520003
# %ROI is  391.65631493002013
# % Buy and Hold= 185.79746976081816
# count 2091
# qtable [[0.00527585 0.00530094 0.01248429]
#  [0.00383515 0.00493676 0.00960688]
#  [0.00042421 0.02550617 0.00131682]
#  [0.0031358  0.00787683 0.01196314]
#  [0.00437067 0.0072211  0.00883003]
#  [0.0086691  0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 27/100
#
# ***********************
#  2206
# Profit is  233962.6900070007
# Initial Capital is  60721.49902
# Current Capital is  294684.1890270007
# %ROI is  385.3045359271183
# % Buy and Hold= 185.79746976081816
# count 2086
# qtable [[0.00521311 0.00548758 0.01268146]
#  [0.00383515 0.00522031 0.00973064]
#  [0.00042421 0.02555001 0.00131682]
#  [0.0031358  0.00786554 0.01193879]
#  [0.00437067 0.0072211  0.00882659]
#  [0.00871216 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 28/100
#
# ***********************
#  2206
# Profit is  216079.47050399962
# Initial Capital is  60721.49902
# Current Capital is  276800.9695239996
# %ROI is  355.85332047357554
# % Buy and Hold= 185.79746976081816
# count 2093
# qtable [[0.00512368 0.00519755 0.01250745]
#  [0.00388491 0.00522031 0.00959406]
#  [0.00042421 0.02559389 0.00131682]
#  [0.0031358  0.00786554 0.0119765 ]
#  [0.00439725 0.00719164 0.00882501]
#  [0.00875135 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 29/100
#
# ***********************
#  2206
# Profit is  233865.90904600063
# Initial Capital is  60721.49902
# Current Capital is  294587.4080660006
# %ROI is  385.145150927469
# % Buy and Hold= 185.79746976081816
# count 2095
# qtable [[0.00516939 0.00559994 0.01244927]
#  [0.00395294 0.00522031 0.00957551]
#  [0.00042421 0.02563179 0.00131682]
#  [0.0031358  0.00781757 0.01197509]
#  [0.00444169 0.00719164 0.00891193]
#  [0.00878274 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 30/100
#
# ***********************
#  2206
# Profit is  217961.7281939999
# Initial Capital is  60721.49902
# Current Capital is  278683.2272139999
# %ROI is  358.9531413284268
# % Buy and Hold= 185.79746976081816
# count 2094
# qtable [[0.00510999 0.00535872 0.01258944]
#  [0.00395294 0.00522031 0.00952698]
#  [0.00042421 0.0256611  0.00131682]
#  [0.00327738 0.00781757 0.01170407]
#  [0.00444169 0.00719164 0.00879496]
#  [0.00880952 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 31/100
#
# ***********************
#  2206
# Profit is  265861.14459800173
# Initial Capital is  60721.49902
# Current Capital is  326582.6436180017
# %ROI is  437.8369257821424
# % Buy and Hold= 185.79746976081816
# count 2089
# qtable [[0.00504641 0.00559719 0.01249418]
#  [0.00395294 0.00522031 0.00956669]
#  [0.00042421 0.02568237 0.00131682]
#  [0.00339129 0.00781757 0.01199887]
#  [0.00444169 0.00735734 0.00884824]
#  [0.00883203 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 32/100
#
# ***********************
#  2206
# Profit is  226264.88135899976
# Initial Capital is  60721.49902
# Current Capital is  286986.38037899975
# %ROI is  372.62729842106546
# % Buy and Hold= 185.79746976081816
# count 2092
# qtable [[0.00505375 0.00510572 0.01251705]
#  [0.00395294 0.00529262 0.00964857]
#  [0.00042421 0.02570466 0.00131682]
#  [0.00346383 0.00782764 0.01219429]
#  [0.00456249 0.00735734 0.00885035]
#  [0.0088519  0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 33/100
#
# ***********************
#  2206
# Profit is  218042.17993899947
# Initial Capital is  60721.49902
# Current Capital is  278763.67895899946
# %ROI is  359.0856343437476
# % Buy and Hold= 185.79746976081816
# count 2096
# qtable [[0.00507146 0.00506187 0.0124923 ]
#  [0.00398247 0.00529262 0.00960746]
#  [0.00042421 0.02572366 0.00131682]
#  [0.00346383 0.00782764 0.0119849 ]
#  [0.00456249 0.00735734 0.00884303]
#  [0.00886683 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 34/100
#
# ***********************
#  2206
# Profit is  241865.89591699973
# Initial Capital is  60721.49902
# Current Capital is  302587.3949369997
# %ROI is  398.32003461794596
# % Buy and Hold= 185.79746976081816
# count 2091
# qtable [[0.00507206 0.00556782 0.01258171]
#  [0.00398247 0.0054279  0.00955358]
#  [0.00042421 0.02574052 0.00131682]
#  [0.00346383 0.00782764 0.01198373]
#  [0.00467378 0.00735734 0.00885151]
#  [0.00888378 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 35/100
#
# ***********************
#  2206
# Profit is  225117.78947999963
# Initial Capital is  60721.49902
# Current Capital is  285839.2884999996
# %ROI is  370.7381950597958
# % Buy and Hold= 185.79746976081816
# count 2089
# qtable [[0.00523299 0.00516329 0.01260101]
#  [0.00398247 0.00587608 0.00961108]
#  [0.00042421 0.02575722 0.00131682]
#  [0.00354715 0.00782764 0.01201482]
#  [0.004777   0.00772231 0.00892949]
#  [0.0088989  0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 36/100
#
# ***********************
#  2206
# Profit is  238333.0483240002
# Initial Capital is  60721.49902
# Current Capital is  299054.5473440002
# %ROI is  392.501918052945
# % Buy and Hold= 185.79746976081816
# count 2092
# qtable [[0.00529802 0.0051664  0.01245642]
#  [0.00406374 0.00587608 0.00955482]
#  [0.0006064  0.02595004 0.00131682]
#  [0.00362064 0.00784597 0.01188797]
#  [0.004777   0.00772231 0.00881752]
#  [0.00891752 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 37/100
#
# ***********************
#  2206
# Profit is  244034.9024279997
# Initial Capital is  60721.49902
# Current Capital is  304756.4014479997
# %ROI is  401.8920915434273
# % Buy and Hold= 185.79746976081816
# count 2092
# qtable [[0.00518502 0.00535278 0.01247665]
#  [0.00412067 0.00587608 0.00964609]
#  [0.0006064  0.02592206 0.00131682]
#  [0.00362064 0.00784597 0.01193829]
#  [0.0049254  0.00772231 0.00853867]
#  [0.00892727 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 38/100
#
# ***********************
#  2206
# Profit is  237786.98196900036
# Initial Capital is  60721.49902
# Current Capital is  298508.48098900035
# %ROI is  391.6026214877861
# % Buy and Hold= 185.79746976081816
# count 2095
# qtable [[0.00536319 0.00560835 0.01223404]
#  [0.00412067 0.00592866 0.00963604]
#  [0.0006064  0.02590222 0.00131682]
#  [0.00362064 0.00784597 0.01198186]
#  [0.0049254  0.00811736 0.00884862]
#  [0.00893484 0.00058156 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 39/100
#
# ***********************
#  2206
# Profit is  238332.28688500007
# Initial Capital is  60721.49902
# Current Capital is  299053.78590500006
# %ROI is  392.500664067104
# % Buy and Hold= 185.79746976081816
# count 2096
# qtable [[0.00531271 0.00556739 0.01249253]
#  [0.004173   0.00598805 0.00968781]
#  [0.0006064  0.02588818 0.00131682]
#  [0.00362064 0.00784597 0.01200251]
#  [0.0049254  0.00857829 0.00891803]
#  [0.00873065 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 40/100
#
# ***********************
#  2206
# Profit is  205508.70417699998
# Initial Capital is  60721.49902
# Current Capital is  266230.20319699997
# %ROI is  338.4447147941967
# % Buy and Hold= 185.79746976081816
# count 2089
# qtable [[0.00511255 0.00510152 0.01247321]
#  [0.004173   0.00598805 0.00956811]
#  [0.0006064  0.02586922 0.00131682]
#  [0.00362064 0.00784597 0.01196368]
#  [0.0049254  0.00857829 0.00883325]
#  [0.00877232 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 41/100
#
# ***********************
#  2206
# Profit is  233053.30133300077
# Initial Capital is  60721.49902
# Current Capital is  293774.80035300076
# %ROI is  383.8068972181326
# % Buy and Hold= 185.79746976081816
# count 2078
# qtable [[0.00499745 0.0050963  0.01259473]
#  [0.00425363 0.00598805 0.00955768]
#  [0.0006064  0.02585275 0.00131682]
#  [0.00362064 0.00784597 0.01195521]
#  [0.00496461 0.00857829 0.00881497]
#  [0.00880398 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 42/100
#
# ***********************
#  2206
# Profit is  247770.39610299974
# Initial Capital is  60721.49902
# Current Capital is  308491.89512299973
# %ROI is  408.0439384762075
# % Buy and Hold= 185.79746976081816
# count 2097
# qtable [[0.00493117 0.00518228 0.01248881]
#  [0.00425363 0.00598805 0.00955846]
#  [0.0006064  0.02584251 0.00131682]
#  [0.00362064 0.00784597 0.01196366]
#  [0.00496461 0.0085692  0.00882276]
#  [0.00883227 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 43/100
#
# ***********************
#  2206
# Profit is  247821.3470449999
# Initial Capital is  60721.49902
# Current Capital is  308542.8460649999
# %ROI is  408.12784770575956
# % Buy and Hold= 185.79746976081816
# count 2094
# qtable [[0.00505455 0.00541195 0.01256938]
#  [0.00425363 0.00598301 0.00955758]
#  [0.0006064  0.02583559 0.00131682]
#  [0.00362064 0.00784597 0.01197586]
#  [0.00496461 0.00867584 0.0088329 ]
#  [0.00885645 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 44/100
#
# ***********************
#  2206
# Profit is  292400.9244250003
# Initial Capital is  60721.49902
# Current Capital is  353122.4234450003
# %ROI is  481.54431156037737
# % Buy and Hold= 185.79746976081816
# count 2095
# qtable [[0.00518824 0.00604855 0.01259176]
#  [0.0042954  0.00598301 0.00958771]
#  [0.0006064  0.0258309  0.00131682]
#  [0.00362064 0.00940209 0.01202604]
#  [0.00496461 0.00867584 0.00884735]
#  [0.00887644 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 45/100
#
# ***********************
#  2206
# Profit is  215012.05021099915
# Initial Capital is  60721.49902
# Current Capital is  275733.54923099914
# %ROI is  354.09542531250764
# % Buy and Hold= 185.79746976081816
# count 2094
# qtable [[0.00521492 0.00512521 0.01252517]
#  [0.0042954  0.00598301 0.00956805]
#  [0.0006064  0.02582917 0.00131682]
#  [0.00375129 0.00940209 0.01199959]
#  [0.00496461 0.00857139 0.00887365]
#  [0.00889416 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 46/100
#
# ***********************
#  2206
# Profit is  246110.95092499984
# Initial Capital is  60721.49902
# Current Capital is  306832.4499449998
# %ROI is  405.31105933985197
# % Buy and Hold= 185.79746976081816
# count 2093
# qtable [[0.00527417 0.00533938 0.01248588]
#  [0.0042954  0.00598301 0.00955921]
#  [0.0006064  0.02582466 0.00131682]
#  [0.00375129 0.00940209 0.01196801]
#  [0.00500263 0.00857139 0.0088215 ]
#  [0.00890574 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 47/100
#
# ***********************
#  2206
# Profit is  229816.06690399966
# Initial Capital is  60721.49902
# Current Capital is  290537.56592399965
# %ROI is  378.4756150837194
# % Buy and Hold= 185.79746976081816
# count 2090
# qtable [[0.0053322  0.00553549 0.01232057]
#  [0.0042954  0.00598301 0.00955747]
#  [0.0006064  0.02582216 0.00131682]
#  [0.00375129 0.00940209 0.01195916]
#  [0.00502359 0.00857139 0.00897141]
#  [0.00891609 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 48/100
#
# ***********************
#  2206
# Profit is  234020.58878400043
# Initial Capital is  60721.49902
# Current Capital is  294742.0878040004
# %ROI is  385.39988729020087
# % Buy and Hold= 185.79746976081816
# count 2082
# qtable [[0.00501723 0.00521324 0.01253491]
#  [0.0042954  0.00598301 0.00956782]
#  [0.0006064  0.02582609 0.00131682]
#  [0.00380827 0.00940209 0.0120036 ]
#  [0.00507884 0.00857139 0.00884391]
#  [0.00892828 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 49/100
#
# ***********************
#  2206
# Profit is  249819.57850900048
# Initial Capital is  60721.49902
# Current Capital is  310541.07752900047
# %ROI is  411.4186614970041
# % Buy and Hold= 185.79746976081816
# count 2096
# qtable [[0.00510553 0.00573751 0.01237955]
#  [0.0042954  0.00598301 0.0095501 ]
#  [0.0006064  0.02581746 0.00131682]
#  [0.00394474 0.00940209 0.01191858]
#  [0.00507884 0.00857139 0.00880593]
#  [0.00892842 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 50/100
#
# ***********************
#  2206
# Profit is  268141.71771700116
# Initial Capital is  60721.49902
# Current Capital is  328863.21673700114
# %ROI is  441.59271764467246
# % Buy and Hold= 185.79746976081816
# count 2088
# qtable [[0.00524612 0.00583595 0.01247123]
#  [0.0042954  0.0060348  0.00958274]
#  [0.0006064  0.02581329 0.00131682]
#  [0.00394474 0.00940209 0.01195793]
#  [0.00507884 0.00857139 0.00882724]
#  [0.00893239 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 51/100
#
# ***********************
#  2206
# Profit is  200387.40526199935
# Initial Capital is  60721.49902
# Current Capital is  261108.90428199933
# %ROI is  330.01063625915623
# % Buy and Hold= 185.79746976081816
# count 2086
# qtable [[0.00533695 0.00543974 0.01237832]
#  [0.0042954  0.00606926 0.0094971 ]
#  [0.0006064  0.02580847 0.00131682]
#  [0.0040613  0.00940209 0.01175379]
#  [0.00507884 0.00857139 0.00875028]
#  [0.00893399 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 52/100
#
# ***********************
#  2206
# Profit is  222024.41949200002
# Initial Capital is  60721.49902
# Current Capital is  282745.918512
# %ROI is  365.6438379738801
# % Buy and Hold= 185.79746976081816
# count 2088
# qtable [[0.00515531 0.00516078 0.01260557]
#  [0.00437415 0.00605789 0.0095333 ]
#  [0.0006064  0.02581029 0.00131682]
#  [0.0040613  0.00940209 0.01196474]
#  [0.00507225 0.00851046 0.00873204]
#  [0.00894315 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 53/100
#
# ***********************
#  2206
# Profit is  278037.7839039998
# Initial Capital is  60721.49902
# Current Capital is  338759.28292399977
# %ROI is  457.89018451672564
# % Buy and Hold= 185.79746976081816
# count 2095
# qtable [[0.00515421 0.00597424 0.0126219 ]
#  [0.00437415 0.00605789 0.00956397]
#  [0.0006064  0.02581246 0.00131682]
#  [0.0040613  0.00940209 0.01198471]
#  [0.00516506 0.00851046 0.00884204]
#  [0.00894759 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 54/100
#
# ***********************
#  2206
# Profit is  247818.04302199947
# Initial Capital is  60721.49902
# Current Capital is  308539.54204199946
# %ROI is  408.1224064319871
# % Buy and Hold= 185.79746976081816
# count 2094
# qtable [[0.00516449 0.00568779 0.01249248]
#  [0.00439578 0.00605789 0.00960375]
#  [0.0006064  0.02581255 0.00131682]
#  [0.00414483 0.00940209 0.01202218]
#  [0.00516506 0.00851046 0.0088387 ]
#  [0.00895007 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 55/100
#
# ***********************
#  2206
# Profit is  233195.39500200073
# Initial Capital is  60721.49902
# Current Capital is  293916.8940220007
# %ROI is  384.0409060474488
# % Buy and Hold= 185.79746976081816
# count 2087
# qtable [[0.00524372 0.00586989 0.0126087 ]
#  [0.00439578 0.00606493 0.00956519]
#  [0.0006064  0.02581332 0.00131682]
#  [0.0042502  0.00940209 0.01203275]
#  [0.00516506 0.00851046 0.00883935]
#  [0.00895243 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 56/100
#
# ***********************
#  2206
# Profit is  218808.27240899974
# Initial Capital is  60721.49902
# Current Capital is  279529.7714289997
# %ROI is  360.34728381282264
# % Buy and Hold= 185.79746976081816
# count 2092
# qtable [[0.0051771  0.00543857 0.01249534]
#  [0.00439578 0.00606493 0.0095613 ]
#  [0.0006064  0.02581453 0.00131682]
#  [0.0042502  0.00940209 0.01197477]
#  [0.0051535  0.00851046 0.00882787]
#  [0.00895608 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 57/100
#
# ***********************
#  2206
# Profit is  222762.41353699996
# Initial Capital is  60721.49902
# Current Capital is  283483.91255699995
# %ROI is  366.85921318185524
# % Buy and Hold= 185.79746976081816
# count 2089
# qtable [[0.00503956 0.0057113  0.01256451]
#  [0.00439578 0.00606493 0.0095732 ]
#  [0.0006064  0.02581449 0.00131682]
#  [0.0042502  0.00947432 0.01214306]
#  [0.0051535  0.00847583 0.00849547]
#  [0.00895741 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 58/100
#
# ***********************
#  2206
# Profit is  236504.3918810003
# Initial Capital is  60721.49902
# Current Capital is  297225.8909010003
# %ROI is  389.49037111732406
# % Buy and Hold= 185.79746976081816
# count 2094
# qtable [[0.00512025 0.00585587 0.01247433]
#  [0.00439578 0.00602305 0.00940822]
#  [0.0006064  0.02581381 0.00131682]
#  [0.0042502  0.00940668 0.01193345]
#  [0.0051535  0.00847583 0.00879749]
#  [0.00895359 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 59/100
#
# ***********************
#  2206
# Profit is  215844.80056899966
# Initial Capital is  60721.49902
# Current Capital is  276566.29958899965
# %ROI is  355.46685120192154
# % Buy and Hold= 185.79746976081816
# count 2088
# qtable [[0.00512021 0.00524981 0.01250197]
#  [0.00444997 0.00603985 0.00968002]
#  [0.0006064  0.02581531 0.00131682]
#  [0.00434444 0.00940668 0.01213691]
#  [0.0051535  0.00877739 0.00894402]
#  [0.00895393 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 60/100
#
# ***********************
#  2206
# Profit is  225615.55755900004
# Initial Capital is  60721.49902
# Current Capital is  286337.056579
# %ROI is  371.5579509733257
# % Buy and Hold= 185.79746976081816
# count 2091
# qtable [[0.00530285 0.00553495 0.01266074]
#  [0.0045007  0.00607571 0.00959419]
#  [0.0006064  0.02581971 0.00131682]
#  [0.00444311 0.00940668 0.01205954]
#  [0.0051535  0.00854902 0.0087222 ]
#  [0.00895933 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 61/100
#
# ***********************
#  2206
# Profit is  222093.0603539992
# Initial Capital is  60721.49902
# Current Capital is  282814.5593739992
# %ROI is  365.75688008105305
# % Buy and Hold= 185.79746976081816
# count 2092
# qtable [[0.00513625 0.00522144 0.01249377]
#  [0.00454214 0.00645304 0.00966189]
#  [0.0006064  0.02581918 0.00131682]
#  [0.00444311 0.00940668 0.01198957]
#  [0.0051535  0.00854902 0.00886429]
#  [0.00895871 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 62/100
#
# ***********************
#  2206
# Profit is  240837.75838299986
# Initial Capital is  60721.49902
# Current Capital is  301559.25740299985
# %ROI is  396.62683278565714
# % Buy and Hold= 185.79746976081816
# count 2094
# qtable [[0.00512287 0.00515545 0.01255664]
#  [0.00454214 0.00642358 0.00954908]
#  [0.0006064  0.02582046 0.00131682]
#  [0.00444311 0.00936753 0.01178139]
#  [0.00517338 0.00854902 0.00885203]
#  [0.00896199 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 63/100
#
# ***********************
#  2206
# Profit is  189945.31446899968
# Initial Capital is  60721.49902
# Current Capital is  250666.81348899967
# %ROI is  312.8139415768324
# % Buy and Hold= 185.79746976081816
# count 2084
# qtable [[0.00500895 0.00501998 0.01248364]
#  [0.00454214 0.00642358 0.00954864]
#  [0.0006064  0.02581709 0.00131682]
#  [0.00454669 0.00936753 0.01186731]
#  [0.00517885 0.00851966 0.00887925]
#  [0.00896398 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 64/100
#
# ***********************
#  2206
# Profit is  221968.58624199935
# Initial Capital is  60721.49902
# Current Capital is  282690.08526199934
# %ROI is  365.5518882511266
# % Buy and Hold= 185.79746976081816
# count 2093
# qtable [[0.00524721 0.0051444  0.01237284]
#  [0.00458048 0.00642358 0.00956633]
#  [0.0006064  0.02581465 0.00131682]
#  [0.00454669 0.00936753 0.01195654]
#  [0.00517885 0.00851966 0.00882411]
#  [0.00896307 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 65/100
#
# ***********************
#  2206
# Profit is  258688.37094400078
# Initial Capital is  60721.49902
# Current Capital is  319409.86996400077
# %ROI is  426.02434906752865
# % Buy and Hold= 185.79746976081816
# count 2095
# qtable [[0.00520262 0.00544002 0.0125188 ]
#  [0.00458048 0.00642358 0.00956234]
#  [0.0006064  0.02581702 0.00131682]
#  [0.00454669 0.00936753 0.0119781 ]
#  [0.00517885 0.00867315 0.00883047]
#  [0.00896606 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 66/100
#
# ***********************
#  2206
# Profit is  248198.10172399943
# Initial Capital is  60721.49902
# Current Capital is  308919.6007439994
# %ROI is  408.7483111084754
# % Buy and Hold= 185.79746976081816
# count 2089
# qtable [[0.00519623 0.00568524 0.01244216]
#  [0.00458048 0.00642358 0.00956825]
#  [0.0006064  0.02581681 0.00131682]
#  [0.00454669 0.00936753 0.01197649]
#  [0.00522793 0.00867315 0.00886902]
#  [0.00896552 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 67/100
#
# ***********************
#  2206
# Profit is  223096.5468269997
# Initial Capital is  60721.49902
# Current Capital is  283818.0458469997
# %ROI is  367.409484989028
# % Buy and Hold= 185.79746976081816
# count 2089
# qtable [[0.00535082 0.00518865 0.01244272]
#  [0.00458824 0.00642358 0.00952062]
#  [0.0006064  0.02582011 0.00131682]
#  [0.00463788 0.00936753 0.01204591]
#  [0.00528511 0.008623   0.00887752]
#  [0.00896682 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 68/100
#
# ***********************
#  2206
# Profit is  200140.09344199987
# Initial Capital is  60721.49902
# Current Capital is  260861.59246199986
# %ROI is  329.60334753277283
# % Buy and Hold= 185.79746976081816
# count 2088
# qtable [[0.00531435 0.00548947 0.01218362]
#  [0.00463351 0.00641561 0.00944701]
#  [0.0006064  0.02580281 0.00131682]
#  [0.0046757  0.00936753 0.01194045]
#  [0.00534435 0.00842338 0.00862433]
#  [0.00894514 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 69/100
#
# ***********************
#  2206
# Profit is  228439.7305800005
# Initial Capital is  60721.49902
# Current Capital is  289161.2296000005
# %ROI is  376.2089774904251
# % Buy and Hold= 185.79746976081816
# count 2091
# qtable [[0.00532851 0.00593125 0.01248552]
#  [0.00463351 0.00637805 0.0094694 ]
#  [0.0006064  0.02580088 0.00131682]
#  [0.0046757  0.00932739 0.01200172]
#  [0.00534435 0.00842338 0.00881082]
#  [0.00894346 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 70/100
#
# ***********************
#  2206
# Profit is  209693.71943899966
# Initial Capital is  60721.49902
# Current Capital is  270415.21845899965
# %ROI is  345.3368622700376
# % Buy and Hold= 185.79746976081816
# count 2088
# qtable [[0.00520761 0.00537903 0.01241376]
#  [0.00463351 0.00653433 0.00953911]
#  [0.0006064  0.02580037 0.00131682]
#  [0.00476231 0.00932739 0.01202013]
#  [0.00535621 0.0086721  0.00885998]
#  [0.00894315 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 71/100
#
# ***********************
#  2206
# Profit is  232613.2044200009
# Initial Capital is  60721.49902
# Current Capital is  293334.7034400009
# %ROI is  383.082117823515
# % Buy and Hold= 185.79746976081816
# count 2092
# qtable [[0.00519463 0.00543363 0.0125159 ]
#  [0.00463351 0.00653433 0.00956209]
#  [0.0006064  0.02580358 0.00131682]
#  [0.00480642 0.00932739 0.01197298]
#  [0.00545588 0.0086721  0.00883819]
#  [0.00895044 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 72/100
#
# ***********************
#  2206
# Profit is  262582.3310070008
# Initial Capital is  60721.49902
# Current Capital is  323303.8300270008
# %ROI is  432.4371684574411
# % Buy and Hold= 185.79746976081816
# count 2091
# qtable [[0.00530282 0.00553721 0.01250319]
#  [0.00463351 0.00653433 0.00959726]
#  [0.0006064  0.02581011 0.00131682]
#  [0.00480642 0.00932739 0.01201891]
#  [0.00550922 0.00887667 0.0090021 ]
#  [0.0089579  0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 73/100
#
# ***********************
#  2206
# Profit is  208089.09240599978
# Initial Capital is  60721.49902
# Current Capital is  268810.59142599977
# %ROI is  342.69426111740245
# % Buy and Hold= 185.79746976081816
# count 2093
# qtable [[0.00518057 0.00548277 0.01241676]
#  [0.00463351 0.00653433 0.00961713]
#  [0.0006064  0.0257984  0.00131682]
#  [0.00480642 0.00915174 0.01197192]
#  [0.00553309 0.0086274  0.00872556]
#  [0.00900023 0.00107323 0.00012541]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 74/100
#
# ***********************
#  2206
# Profit is  261841.561705001
# Initial Capital is  60721.49902
# Current Capital is  322563.060725001
# %ROI is  431.21722278094217
# % Buy and Hold= 185.79746976081816
# count 2095
# qtable [[0.0052119  0.00547809 0.01256206]
#  [0.00463351 0.00653433 0.00956896]
#  [0.0006064  0.02580089 0.00131682]
#  [0.00486334 0.00961768 0.01204712]
#  [0.00553309 0.00861302 0.00881432]
#  [0.00877807 0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 75/100
#
# ***********************
#  2206
# Profit is  234253.0732409999
# Initial Capital is  60721.49902
# Current Capital is  294974.5722609999
# %ROI is  385.78275737864
# % Buy and Hold= 185.79746976081816
# count 2096
# qtable [[0.00517172 0.00557431 0.01248964]
#  [0.00463351 0.00651116 0.00959571]
#  [0.0006064  0.02627847 0.00146726]
#  [0.00486334 0.00961768 0.01197124]
#  [0.00553309 0.00861302 0.00883465]
#  [0.00880915 0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 76/100
#
# ***********************
#  2206
# Profit is  246689.06899600005
# Initial Capital is  60721.49902
# Current Capital is  307410.56801600003
# %ROI is  406.2631406954354
# % Buy and Hold= 185.79746976081816
# count 2091
# qtable [[0.00513076 0.00595797 0.01246973]
#  [0.00463351 0.00651116 0.00956019]
#  [0.0006064  0.02619168 0.00146726]
#  [0.00486334 0.00962406 0.01196994]
#  [0.00553309 0.00849551 0.0088188 ]
#  [0.0088405  0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 77/100
#
# ***********************
#  2206
# Profit is  275154.5501640003
# Initial Capital is  60721.49902
# Current Capital is  335876.0491840003
# %ROI is  453.14189307706636
# % Buy and Hold= 185.79746976081816
# count 2096
# qtable [[0.0051779  0.00580885 0.01252428]
#  [0.00463351 0.00645628 0.00942908]
#  [0.0006064  0.02612786 0.00146726]
#  [0.00486334 0.00969071 0.011997  ]
#  [0.00560513 0.00870136 0.00888078]
#  [0.00887521 0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 78/100
#
# ***********************
#  2206
# Profit is  229735.02015300037
# Initial Capital is  60721.49902
# Current Capital is  290456.51917300036
# %ROI is  378.34214217493536
# % Buy and Hold= 185.79746976081816
# count 2092
# qtable [[0.00523144 0.005697   0.01250337]
#  [0.00463351 0.00645628 0.009543  ]
#  [0.0006064  0.02591379 0.00166725]
#  [0.00486334 0.00969071 0.01196166]
#  [0.00560513 0.00851006 0.00871359]
#  [0.00889814 0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 79/100
#
# ***********************
#  2206
# Profit is  249816.49218499975
# Initial Capital is  60721.49902
# Current Capital is  310537.99120499974
# %ROI is  411.41357874369504
# % Buy and Hold= 185.79746976081816
# count 2091
# qtable [[0.00516782 0.00590543 0.01256929]
#  [0.00466499 0.00645628 0.0095775 ]
#  [0.0006064  0.02589511 0.00166725]
#  [0.0048968  0.00969071 0.01202854]
#  [0.00559333 0.00835526 0.00886003]
#  [0.0089085  0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 80/100
#
# ***********************
#  2206
# Profit is  226654.78445999965
# Initial Capital is  60721.49902
# Current Capital is  287376.28347999963
# %ROI is  373.26941547563865
# % Buy and Hold= 185.79746976081816
# count 2094
# qtable [[0.00525879 0.00539341 0.01242871]
#  [0.00466499 0.00645628 0.00956783]
#  [0.0006064  0.02588148 0.00166725]
#  [0.0048968  0.00969071 0.01197401]
#  [0.00556632 0.00835526 0.00892211]
#  [0.00892119 0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 81/100
#
# ***********************
#  2206
# Profit is  240418.11573399964
# Initial Capital is  60721.49902
# Current Capital is  301139.61475399963
# %ROI is  395.9357387649677
# % Buy and Hold= 185.79746976081816
# count 2091
# qtable [[0.00520868 0.00540052 0.01251949]
#  [0.00468085 0.00645628 0.00951794]
#  [0.0006064  0.02587208 0.00166725]
#  [0.00498747 0.00969071 0.0120325 ]
#  [0.0055438  0.00835526 0.00877826]
#  [0.00893519 0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 82/100
#
# ***********************
#  2206
# Profit is  273529.57650900056
# Initial Capital is  60721.49902
# Current Capital is  334251.07552900055
# %ROI is  450.46578382214733
# % Buy and Hold= 185.79746976081816
# count 2088
# qtable [[0.00513697 0.00572953 0.01250064]
#  [0.00473251 0.00656536 0.00975514]
#  [0.0006064  0.02586153 0.00166725]
#  [0.00505897 0.00969071 0.01176631]
#  [0.00562229 0.00865149 0.00891623]
#  [0.00894077 0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 83/100
#
# ***********************
#  2206
# Profit is  223920.58172499953
# Initial Capital is  60721.49902
# Current Capital is  284642.0807449995
# %ROI is  368.7665577084093
# % Buy and Hold= 185.79746976081816
# count 2091
# qtable [[0.00507211 0.00565974 0.01229283]
#  [0.00476894 0.00656536 0.00956194]
#  [0.0006064  0.02584868 0.00166725]
#  [0.00505897 0.00969071 0.01194889]
#  [0.00561605 0.00865149 0.00892477]
#  [0.008945   0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 84/100
#
# ***********************
#  2206
# Profit is  220516.38029999996
# Initial Capital is  60721.49902
# Current Capital is  281237.87931999995
# %ROI is  363.1603037786796
# % Buy and Hold= 185.79746976081816
# count 2090
# qtable [[0.00508005 0.00518327 0.01249317]
#  [0.00476894 0.00656536 0.00956009]
#  [0.0006064  0.02584406 0.00166725]
#  [0.00519487 0.00969071 0.01201447]
#  [0.00563358 0.00865149 0.00882424]
#  [0.0089516  0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 85/100
#
# ***********************
#  2206
# Profit is  222466.21576700045
# Initial Capital is  60721.49902
# Current Capital is  283187.71478700044
# %ROI is  366.37141598517877
# % Buy and Hold= 185.79746976081816
# count 2094
# qtable [[0.00516628 0.00536927 0.01246152]
#  [0.00476894 0.00657858 0.00915965]
#  [0.0006064  0.02583589 0.00166725]
#  [0.00519487 0.00969071 0.0119442 ]
#  [0.00578052 0.00865149 0.00881692]
#  [0.00895213 0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 86/100
#
# ***********************
#  2206
# Profit is  227646.63875299972
# Initial Capital is  60721.49902
# Current Capital is  288368.1377729997
# %ROI is  374.90286377485364
# % Buy and Hold= 185.79746976081816
# count 2095
# qtable [[0.00513913 0.00515317 0.01245424]
#  [0.00476894 0.00657858 0.00951912]
#  [0.0006064  0.02582881 0.00166725]
#  [0.00519487 0.00969071 0.01192177]
#  [0.00585381 0.00853033 0.00879025]
#  [0.00895182 0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 87/100
#
# ***********************
#  2206
# Profit is  252412.86148599995
# Initial Capital is  60721.49902
# Current Capital is  313134.36050599994
# %ROI is  415.6894437056998
# % Buy and Hold= 185.79746976081816
# count 2095
# qtable [[0.00512544 0.00531668 0.01248726]
#  [0.00476894 0.00666445 0.00961801]
#  [0.0006064  0.02582557 0.00166725]
#  [0.00519487 0.00980034 0.01206402]
#  [0.00590992 0.00854521 0.00889374]
#  [0.00895268 0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 88/100
#
# ***********************
#  2206
# Profit is  226572.1898000004
# Initial Capital is  60721.49902
# Current Capital is  287293.6888200004
# %ROI is  373.13339337254126
# % Buy and Hold= 185.79746976081816
# count 2087
# qtable [[0.00485234 0.00529998 0.0125155 ]
#  [0.00484681 0.00666445 0.00916902]
#  [0.0006064  0.02582654 0.00166725]
#  [0.00519487 0.00980034 0.01197789]
#  [0.00590992 0.00854521 0.00883629]
#  [0.00895692 0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 89/100
#
# ***********************
#  2206
# Profit is  245695.77245200024
# Initial Capital is  60721.49902
# Current Capital is  306417.2714720002
# %ROI is  404.62731720617563
# % Buy and Hold= 185.79746976081816
# count 2093
# qtable [[0.0049591  0.00545873 0.01248602]
#  [0.00484681 0.00666445 0.00952404]
#  [0.0006064  0.02582224 0.00166725]
#  [0.00519487 0.00980034 0.01194025]
#  [0.00590992 0.00854521 0.00877863]
#  [0.00895657 0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 90/100
#
# ***********************
#  2206
# Profit is  245752.87305299938
# Initial Capital is  60721.49902
# Current Capital is  306474.37207299937
# %ROI is  404.72135408260436
# % Buy and Hold= 185.79746976081816
# count 2095
# qtable [[0.00506329 0.00566643 0.01248551]
#  [0.00486875 0.00662999 0.00958282]
#  [0.0006064  0.0258192  0.00166725]
#  [0.00519487 0.00980034 0.01196338]
#  [0.00590992 0.00854521 0.00882695]
#  [0.00895642 0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 91/100
#
# ***********************
#  2206
# Profit is  231420.4808540002
# Initial Capital is  60721.49902
# Current Capital is  292141.9798740002
# %ROI is  381.11786531781206
# % Buy and Hold= 185.79746976081816
# count 2093
# qtable [[0.00523176 0.00607814 0.01269446]
#  [0.00493609 0.00655154 0.00948914]
#  [0.0006064  0.02582138 0.00166725]
#  [0.00520228 0.00980034 0.01200661]
#  [0.00590992 0.00847592 0.00884039]
#  [0.00895666 0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 92/100
#
# ***********************
#  2206
# Profit is  218227.60223699955
# Initial Capital is  60721.49902
# Current Capital is  278949.10125699954
# %ROI is  359.3909994961115
# % Buy and Hold= 185.79746976081816
# count 2091
# qtable [[0.00539577 0.00581627 0.01230919]
#  [0.00497344 0.00652949 0.00953908]
#  [0.0006064  0.02581225 0.00166725]
#  [0.00520228 0.00964967 0.0119064 ]
#  [0.00590992 0.00847592 0.00878743]
#  [0.00895514 0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 93/100
#
# ***********************
#  2206
# Profit is  235610.50289400038
# Initial Capital is  60721.49902
# Current Capital is  296332.0019140004
# %ROI is  388.01825827191243
# % Buy and Hold= 185.79746976081816
# count 2089
# qtable [[0.00517868 0.00516909 0.01248651]
#  [0.00497344 0.00652949 0.00956831]
#  [0.0006064  0.02581087 0.00166725]
#  [0.00520228 0.00984611 0.01205194]
#  [0.00590992 0.00847592 0.00883016]
#  [0.00895523 0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 94/100
#
# ***********************
#  2206
# Profit is  253981.81494700018
# Initial Capital is  60721.49902
# Current Capital is  314703.31396700017
# %ROI is  418.27329536667975
# % Buy and Hold= 185.79746976081816
# count 2093
# qtable [[0.0051303  0.0055393  0.01247239]
#  [0.00499501 0.00659424 0.0096048 ]
#  [0.0006064  0.02581415 0.00166725]
#  [0.00520228 0.0097239  0.01198284]
#  [0.00598128 0.00837967 0.00880642]
#  [0.00895571 0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 95/100
#
# ***********************
#  2206
# Profit is  236199.19591400085
# Initial Capital is  60721.49902
# Current Capital is  296920.69493400084
# %ROI is  388.9877551214658
# % Buy and Hold= 185.79746976081816
# count 2091
# qtable [[0.00513832 0.00542284 0.01247052]
#  [0.00500777 0.00660074 0.00967965]
#  [0.0006064  0.02581017 0.00166725]
#  [0.00520228 0.0097239  0.01197027]
#  [0.00598128 0.00839817 0.00884365]
#  [0.0089539  0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 96/100
#
# ***********************
#  2206
# Profit is  287543.6199050004
# Initial Capital is  60721.49902
# Current Capital is  348265.11892500037
# %ROI is  473.5449956699708
# % Buy and Hold= 185.79746976081816
# count 2085
# qtable [[0.00538613 0.00588407 0.01277019]
#  [0.0050211  0.00682687 0.00970822]
#  [0.0006064  0.02581618 0.00166725]
#  [0.00520228 0.0097239  0.01202719]
#  [0.00601509 0.00860099 0.00894379]
#  [0.00896029 0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 97/100
#
# ***********************
#  2206
# Profit is  259303.74931100063
# Initial Capital is  60721.49902
# Current Capital is  320025.2483310006
# %ROI is  427.0377930320743
# % Buy and Hold= 185.79746976081816
# count 2093
# qtable [[0.00545952 0.00563771 0.0125255 ]
#  [0.0050211  0.00693265 0.00964183]
#  [0.0007795  0.02629609 0.00166725]
#  [0.00527762 0.00956709 0.01234771]
#  [0.00601509 0.00868961 0.00907802]
#  [0.00896371 0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 98/100
#
# ***********************
#  2206
# Profit is  223830.63848599995
# Initial Capital is  60721.49902
# Current Capital is  284552.13750599994
# %ROI is  368.6184335012485
# % Buy and Hold= 185.79746976081816
# count 2086
# qtable [[0.00514385 0.00534328 0.01255625]
#  [0.0050824  0.00695833 0.00949897]
#  [0.0007795  0.02622294 0.00166725]
#  [0.00527762 0.00949533 0.01202307]
#  [0.00604844 0.00860893 0.00883461]
#  [0.00898427 0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 99/100
#
# ***********************
#  2206
# Profit is  247762.26329299965
# Initial Capital is  60721.49902
# Current Capital is  308483.76231299964
# %ROI is  408.0305448509984
# % Buy and Hold= 185.79746976081816
# count 2093
# qtable [[0.00530542 0.00538097 0.01248005]
#  [0.0050824  0.00695833 0.00955136]
#  [0.0007795  0.02614797 0.00166725]
#  [0.00527762 0.00949533 0.01196049]
#  [0.0060579  0.00860893 0.00880835]
#  [0.00898872 0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 100/100
#
# ***********************
#  2206
# Profit is  255884.85369499988
# Initial Capital is  60721.49902
# Current Capital is  316606.35271499987
# %ROI is  421.4073397804596
# % Buy and Hold= 185.79746976081816
# count 2096
# qtable [[0.00534377 0.00539617 0.01250951]
#  [0.0050824  0.00703177 0.00960062]
#  [0.0007795  0.02609324 0.00166725]
#  [0.00529707 0.00949533 0.01199423]
#  [0.0060579  0.00860893 0.0088408 ]
#  [0.00899429 0.00107323 0.0018761 ]]
# epsilon 0.009998671593271896
# --------------------------------
# e=44,roi=481.54431156037737

# %%
agent.Q
# Out:
# matrix([[0.00534377, 0.00539617, 0.01250951],
#         [0.0050824 , 0.00703177, 0.00960062],
#         [0.0007795 , 0.02609324, 0.00166725],
#         [0.00529707, 0.00949533, 0.01199423],
#         [0.0060579 , 0.00860893, 0.0088408 ],
#         [0.00899429, 0.00107323, 0.0018761 ]])

# %%
# %matplotlib inline
fig = plt.figure()
ax=X.loc[data_length_start:data_length-2,'cash'].plot(grid="True",figsize=(10,5), title='Nifty')
ax.set_xlabel("Trading Days")
ax.set_ylabel("cash")
plt.show()

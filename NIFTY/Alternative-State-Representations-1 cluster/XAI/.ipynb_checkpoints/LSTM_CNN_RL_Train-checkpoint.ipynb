# %%
import numpy as np
import datetime
import pandas as pd
import random

# %%
#X=pd.read_csv('nifty.csv')
#len(X)

# %%
def data1():
    X=pd.read_csv('tempcnnlstmcluster.csv')
    X = X.iloc[60:]  # Keep rows from index 19 onwards (0-based index)
    # Ensure 'Open' and 'Close' are treated as numeric
    X['cashopen']=0
    X['cash']=0
    # Ensure columns have float dtype before assignment
    X['cashopen'] = X['cashopen'].astype(float)
    X['cash'] = X['cash'].astype(float)
    X['action']=""
    X['diff']=""
    X['quantity']=""
    return X

# %%
X=data1()

# %%
print(len(X))
# Out:
# 2830

# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure()
ax=X.loc[60:2153,'Close'].plot(grid="True",figsize=(10,5), title='Nifty')
ax.set_xlabel("Trading Days")
ax.set_ylabel("Close Price")
plt.show()
fig.savefig('nifty_close.png')

# %%
X.head()
# Out:
#     Unnamed: 0.1  Unnamed: 0        date        Close         High  \
# 60            60          60  18-06-2013  5813.600098  5863.399902
# 61            61          61  19-06-2013  5822.250000  5828.399902
# 62            62          62  20-06-2013  5655.899902  5755.000000
# 63            63          63  21-06-2013  5667.649902  5686.149902
# 64            64          64  24-06-2013  5590.250000  5640.000000
#
#             Low         Open  Volume  weekday  month  ...  cnnstate  state2d  \
# 60  5804.299805  5841.899902  117500     0.25      6  ...       0.0      0.0
# 61  5777.899902  5805.750000  115500     0.50      6  ...       2.0      2.0
# 62  5645.649902  5754.149902  198400     0.75      6  ...       0.0      0.0
# 63  5616.850098  5639.899902  182400     1.00      6  ...       2.0      2.0
# 64  5566.250000  5638.049805  193500     0.00      6  ...       1.0      4.0
#
#     state1d  state  Cluster  cashopen  cash  action  diff  quantity
# 60      0.0    0.0      7.0       0.0   0.0
# 61      0.0    1.0      1.0       0.0   0.0
# 62      0.0    0.0      7.0       0.0   0.0
# 63      2.0    2.0      3.0       0.0   0.0
# 64      5.0    5.0      0.0       0.0   0.0
#
# [5 rows x 38 columns]

# %%
X['Cluster'].value_counts()
# Out:
# Cluster
# 5.0    587
# 0.0    580
# 6.0    462
# 3.0    346
# 2.0    300
# 4.0    212
# 7.0    172
# 1.0    171
# Name: count, dtype: int64

# %%
#X.head()

# %%
def getState(t):
    t = int(t)
    return(X['Cluster'][t])

# %%
class Agent:
    def __init__(self):
        self.epsilon = 1.0
        self.gamma = 0.618
        self.epsilon_decay = 0.999
        self.epsilon_min = 0.01
        self.Q = np.matrix(np.zeros([8,3]))
        self.learning_rate=0.03
        
    def getAction(self,state):
        state = int(state)
        a=[1,0,2]
        if np.random.rand() <= self.epsilon:
            return random.choice(a)
        return np.argmax(self.Q[state,])  
    
    # Update Q(s,a):= Q(s,a) + lr [R(s,a) + gamma * max Q(s',a') - Q(s,a)]
    def update(self,state,action,reward,next_state,next_action):
        state = int(state)
        action = int(action)
        next_state = int(next_state)
        self.Q[state,action]= self.Q[state,action] + self.learning_rate * (reward + self.gamma * np.max(self.Q[next_state, :])
                                                                - self.Q[state,action])

# %%
episode_count=100
agent=Agent()
agent.Q
m1=0
m2=0
for e in range(1,episode_count+1):
    X=data1()
    
    data_length_start=60
    data_length=2153
    state = getState(data_length_start)
    action = agent.getAction(state)
    
  
    capital=X.loc[data_length_start,'Open']*10
    margin=X.loc[data_length_start,'Open']*10
    #X.loc[2,'cashopen']=margin 
    X.loc[2, 'cashopen'] = float(margin)
    brok_rate=0.0000
    #brok_rate=0.0
    
    print("Episod {}/{}".format(e,episode_count))
    count=0
    for t in range(data_length_start,data_length):
                
        reward=0                        
         
        if action == 1:
            X.loc[t,'cashopen']=float(margin)
            quantity=margin//X.loc[t,'Open']
            X.loc[t,'quantity']=quantity
            margin=margin%X.loc[t,'Open']
            tbrokerage=(X.loc[t,'Open']+X.loc[t,'Close'])*brok_rate
            tprofit=(X.loc[t,'Close']-X.loc[t,'Open']-tbrokerage)*quantity
            margin=margin+tprofit+X.loc[t,'Open']*quantity
            X.loc[t,'cash']=float(margin)         
            
            #print('Long: open price @',X.loc[t,'Open'],'Close price @',X.loc[t,'Close'], 'profit=',tprofit)
            X.loc[t,'action']="long"
            X.loc[t,'diff']=(X.loc[t,'Close']-X.loc[t,'Open']-tbrokerage)*quantity
            count=count+1
            reward= max((np.log(X.loc[t,'Close'])-np.log(X.loc[t,'Open']+tbrokerage)),0)
            
       
        elif action == 2:
            X.loc[t,'cashopen']=float(margin) 
            quantity=margin//X.loc[t,'Open']
            X.loc[t,'quantity']=(-quantity)
            margin=margin%X.loc[t,'Open']
            tbrokerage=(X.loc[t,'Open']+X.loc[t,'Close'])*brok_rate
            tprofit=(X.loc[t,'Open']-X.loc[t,'Close']-tbrokerage)*quantity
            #print('in Short')
            margin=margin+tprofit+X.loc[t,'Open']*quantity
            X.loc[t,'cash']=float(margin)         
            last_action='Short'
            #print('Short: Close price @',X.loc[t,'Close'],'Open price @',X.loc[t,'Open'], 'profit=',tprofit)
            X.loc[t,'action']="short"
            X.loc[t,'diff']=(X.loc[t,'Open']-X.loc[t,'Close']-tbrokerage)*quantity
            count=count+1
            reward= max((np.log(X.loc[t,'Open'])-np.log(X.loc[t,'Close']+tbrokerage)),0)
           
        else:
            X.loc[t,'cash']=margin
            X.loc[t,'action']="Hold"
            X.loc[t,'diff']=0
            reward=0                                  
              
        next_state=int(getState(t+1))
        next_action=agent.getAction(next_state)
        agent.update(state,action,reward,next_state,next_action)
        state=next_state
        action=next_action
        
        if t==data_length-1:
                print("\n***********************\n",t)
                print("Profit is ",(margin-capital))
                print("Initial Capital is ",capital)    
                print("Current Capital is ",margin)
                roi=((margin-capital)/capital)*100
                print("%ROI is ",roi)
                bnh=((X.loc[t,'Close']-X.loc[data_length_start,'Open'])/X.loc[data_length_start,'Open'])*100
                print("% Buy and Hold=",bnh)
                print("count",count)
                print("qtable",agent.Q)
                print("epsilon",agent.epsilon)
                print("--------------------------------")
                       
        if (agent.epsilon > agent.epsilon_min) and e>1:
                       agent.epsilon *= agent.epsilon_decay
                       
    
    m3=roi
    if m3>m2:
        m1=e
        m2=m3
    #To save model  
    if e%20==0:
        np.save('rl/Qtable'+ str(e)+str('.npy'), agent.Q)
        np.save('rl/epsilon'+ str(e)+str('.npy'), agent.epsilon)
        np.save('rl/gamma'+ str(e)+str('.npy'), agent.gamma)
        np.save('rl/learning_rate'+ str(e)+str('.npy'), agent.learning_rate)
        X.to_csv('csv1/AfterTrain'+str(e)+str('.csv'))
print("e={},roi={}".format(m1,m2))
# Out:
# Episod 1/100
#
# ***********************
#  2152
# Profit is  -7060.957852000043
# Initial Capital is  58418.99902
# Current Capital is  51358.04116799996
# %ROI is  -12.086749123487538
# % Buy and Hold= 197.06176194595128
# count 1350
# qtable [[0.00381958 0.00600937 0.00860556]
#  [0.00159317 0.00480174 0.00372117]
#  [0.00251235 0.00533793 0.00323   ]
#  [0.00322923 0.0044111  0.00612805]
#  [0.00250439 0.00327913 0.00505907]
#  [0.00406054 0.00579664 0.00809389]
#  [0.00333483 0.00784691 0.00635063]
#  [0.00149044 0.00449298 0.00526167]]
# epsilon 1.0
# --------------------------------
# Episod 2/100
#
# ***********************
#  2152
# Profit is  189043.593201
# Initial Capital is  58418.99902
# Current Capital is  247462.59222100003
# %ROI is  323.5995076469559
# % Buy and Hold= 197.06176194595128
# count 1776
# qtable [[0.00506783 0.00642223 0.01000086]
#  [0.00245846 0.0088951  0.00544563]
#  [0.00366801 0.00891962 0.00391205]
#  [0.00435105 0.00619586 0.01009041]
#  [0.00389294 0.00454736 0.01041393]
#  [0.00489383 0.00671268 0.01016372]
#  [0.00470684 0.00939946 0.00749313]
#  [0.00276634 0.00575635 0.01047038]]
# epsilon 0.12331087195805032
# --------------------------------
# Episod 3/100
#
# ***********************
#  2152
# Profit is  561735.8515640001
# Initial Capital is  58418.99902
# Current Capital is  620154.8505840001
# %ROI is  961.5636368087843
# % Buy and Hold= 197.06176194595128
# count 2057
# qtable [[0.0053576  0.00687272 0.01028564]
#  [0.00254701 0.00986491 0.0054547 ]
#  [0.00376948 0.00963965 0.00417275]
#  [0.00452157 0.00630128 0.01047582]
#  [0.00436391 0.00467386 0.01158851]
#  [0.00524711 0.00675836 0.0105889 ]
#  [0.00489074 0.01006046 0.00730644]
#  [0.00276634 0.00575635 0.01130384]]
# epsilon 0.01519036557191165
# --------------------------------
# Episod 4/100
#
# ***********************
#  2152
# Profit is  765096.3785550002
# Initial Capital is  58418.99902
# Current Capital is  823515.3775750002
# %ROI is  1309.6704691791554
# % Buy and Hold= 197.06176194595128
# count 2082
# qtable [[0.00547004 0.00704387 0.0103215 ]
#  [0.00270436 0.00997519 0.0055074 ]
#  [0.00376948 0.00973819 0.00425314]
#  [0.00472272 0.00630128 0.01056659]
#  [0.00436391 0.00467386 0.01169466]
#  [0.0053967  0.00703395 0.01065746]
#  [0.00500561 0.01014973 0.00730644]
#  [0.00276634 0.00575635 0.01145354]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 5/100
#
# ***********************
#  2152
# Profit is  658267.9848710002
# Initial Capital is  58418.99902
# Current Capital is  716686.9838910002
# %ROI is  1126.8046284833454
# % Buy and Hold= 197.06176194595128
# count 2088
# qtable [[0.00549665 0.00666944 0.01013262]
#  [0.00270436 0.01005106 0.0055074 ]
#  [0.00376948 0.0097345  0.00425314]
#  [0.00472272 0.00648785 0.01047069]
#  [0.00441825 0.005313   0.01165772]
#  [0.00543264 0.00707846 0.01055946]
#  [0.00508067 0.01012068 0.0072995 ]
#  [0.00286599 0.00571121 0.01134244]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 6/100
#
# ***********************
#  2152
# Profit is  946365.2233080008
# Initial Capital is  58418.99902
# Current Capital is  1004784.2223280008
# %ROI is  1619.9613810294977
# % Buy and Hold= 197.06176194595128
# count 2087
# qtable [[0.00547451 0.0067016  0.01059533]
#  [0.00270436 0.01011805 0.00553301]
#  [0.00376948 0.00983373 0.00439874]
#  [0.00473009 0.00651526 0.01083275]
#  [0.00454673 0.005313   0.01185818]
#  [0.00550119 0.00707846 0.01089757]
#  [0.00508067 0.01022356 0.00722321]
#  [0.00286599 0.00571121 0.01153204]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 7/100
#
# ***********************
#  2152
# Profit is  878817.977349
# Initial Capital is  58418.99902
# Current Capital is  937236.976369
# %ROI is  1504.3359045712727
# % Buy and Hold= 197.06176194595128
# count 2082
# qtable [[0.00550304 0.00666173 0.01051122]
#  [0.00270436 0.01015373 0.00553301]
#  [0.00381662 0.00991037 0.00452397]
#  [0.00479993 0.00650795 0.01074084]
#  [0.00456796 0.00533347 0.01185473]
#  [0.00552198 0.00703855 0.01084721]
#  [0.00509346 0.010333   0.00737217]
#  [0.00295579 0.00572933 0.01161817]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 8/100
#
# ***********************
#  2152
# Profit is  950390.886403
# Initial Capital is  58418.99902
# Current Capital is  1008809.885423
# %ROI is  1626.8523979290187
# % Buy and Hold= 197.06176194595128
# count 2087
# qtable [[0.00550304 0.00696459 0.01055026]
#  [0.00270436 0.0100052  0.00562121]
#  [0.00381662 0.00986668 0.00457819]
#  [0.00483262 0.00650795 0.01073587]
#  [0.00456796 0.00553193 0.01186289]
#  [0.00555492 0.0071807  0.01081186]
#  [0.00511562 0.01021007 0.00795592]
#  [0.00295579 0.00572933 0.01155657]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 9/100
#
# ***********************
#  2152
# Profit is  716227.5497010001
# Initial Capital is  58418.99902
# Current Capital is  774646.5487210001
# %ROI is  1226.018181954464
# % Buy and Hold= 197.06176194595128
# count 2091
# qtable [[0.00550304 0.00697129 0.01023107]
#  [0.00270436 0.01008638 0.00562121]
#  [0.00381662 0.00978534 0.00457819]
#  [0.00483262 0.00650795 0.01053533]
#  [0.00463408 0.00553193 0.01169724]
#  [0.00555492 0.00724099 0.01062969]
#  [0.0051529  0.01014614 0.00790428]
#  [0.00295579 0.00584665 0.01153869]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 10/100
#
# ***********************
#  2152
# Profit is  334013.029393001
# Initial Capital is  58418.99902
# Current Capital is  392432.028413001
# %ROI is  571.7541125253621
# % Buy and Hold= 197.06176194595128
# count 2085
# qtable [[0.00551601 0.00646284 0.00978828]
#  [0.00280276 0.00998521 0.00562121]
#  [0.00381662 0.00961731 0.00457819]
#  [0.00483262 0.00658117 0.01028416]
#  [0.00471459 0.00558429 0.01144124]
#  [0.00558122 0.00669673 0.01044051]
#  [0.0051529  0.00993142 0.00787798]
#  [0.00295579 0.00584665 0.01139275]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 11/100
#
# ***********************
#  2152
# Profit is  944141.7335830012
# Initial Capital is  58418.99902
# Current Capital is  1002560.7326030012
# %ROI is  1616.155273834408
# % Buy and Hold= 197.06176194595128
# count 2088
# qtable [[0.00551601 0.00644207 0.01051367]
#  [0.00292404 0.01020161 0.00562121]
#  [0.00381662 0.00985785 0.00464039]
#  [0.00495237 0.00658117 0.01061519]
#  [0.00471459 0.00558429 0.01183691]
#  [0.00558122 0.00691178 0.01086062]
#  [0.00517861 0.01022046 0.00782478]
#  [0.00295579 0.00584665 0.01153526]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 12/100
#
# ***********************
#  2152
# Profit is  1097806.7184170007
# Initial Capital is  58418.99902
# Current Capital is  1156225.7174370007
# %ROI is  1879.1946743920785
# % Buy and Hold= 197.06176194595128
# count 2085
# qtable [[0.0055734  0.00643709 0.01053433]
#  [0.00292404 0.0101469  0.00562121]
#  [0.00390744 0.00988505 0.00464039]
#  [0.00505235 0.00658117 0.01077939]
#  [0.00478481 0.00571266 0.01188843]
#  [0.00559872 0.00706262 0.01083778]
#  [0.00517982 0.01023544 0.00782478]
#  [0.00295579 0.00584029 0.01155066]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 13/100
#
# ***********************
#  2152
# Profit is  952607.3010209999
# Initial Capital is  58418.99902
# Current Capital is  1011026.3000409999
# %ROI is  1630.6463941548718
# % Buy and Hold= 197.06176194595128
# count 2090
# qtable [[0.0055734  0.00638965 0.01050685]
#  [0.00292404 0.01012255 0.00601921]
#  [0.00395735 0.0099116  0.00464039]
#  [0.00505235 0.00658117 0.01072968]
#  [0.00478481 0.00571266 0.01185106]
#  [0.00560429 0.00697091 0.01081294]
#  [0.00525742 0.01029208 0.00780912]
#  [0.00295579 0.00584029 0.01157017]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 14/100
#
# ***********************
#  2152
# Profit is  983288.2430510016
# Initial Capital is  58418.99902
# Current Capital is  1041707.2420710016
# %ROI is  1683.1651680891835
# % Buy and Hold= 197.06176194595128
# count 2082
# qtable [[0.00553968 0.00668711 0.01061604]
#  [0.00300135 0.01025498 0.00601921]
#  [0.00402645 0.00992896 0.00492602]
#  [0.00510474 0.00658117 0.01065897]
#  [0.00486659 0.00568894 0.01186277]
#  [0.00557251 0.00695132 0.01081284]
#  [0.00525742 0.01029997 0.00779502]
#  [0.00308592 0.00633251 0.0117037 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 15/100
#
# ***********************
#  2152
# Profit is  1006723.7997610017
# Initial Capital is  58418.99902
# Current Capital is  1065142.7987810017
# %ROI is  1723.2814951456894
# % Buy and Hold= 197.06176194595128
# count 2085
# qtable [[0.00557961 0.00665257 0.01056326]
#  [0.00300135 0.01021017 0.00638313]
#  [0.00402645 0.00988748 0.00492602]
#  [0.00510474 0.00665943 0.0107782 ]
#  [0.00486659 0.00568894 0.01188157]
#  [0.00567303 0.00726346 0.01085419]
#  [0.0053079  0.0101746  0.00805683]
#  [0.00308592 0.00633251 0.01158687]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 16/100
#
# ***********************
#  2152
# Profit is  980458.9314179989
# Initial Capital is  58418.99902
# Current Capital is  1038877.9304379988
# %ROI is  1678.3220319854067
# % Buy and Hold= 197.06176194595128
# count 2088
# qtable [[0.00563357 0.00665257 0.01057843]
#  [0.00300135 0.01015203 0.00638313]
#  [0.00402645 0.00988643 0.00492602]
#  [0.00514023 0.00692667 0.01078911]
#  [0.00487748 0.00568894 0.01187633]
#  [0.00567303 0.00714901 0.01084811]
#  [0.0053079  0.01024223 0.00805683]
#  [0.00318252 0.00633251 0.0115802 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 17/100
#
# ***********************
#  2152
# Profit is  984519.3402340005
# Initial Capital is  58418.99902
# Current Capital is  1042938.3392540005
# %ROI is  1685.2725256332205
# % Buy and Hold= 197.06176194595128
# count 2088
# qtable [[0.00563357 0.00665257 0.01052649]
#  [0.00300135 0.01027156 0.00722565]
#  [0.00410802 0.00993282 0.00500009]
#  [0.00514023 0.00692667 0.01074749]
#  [0.00487748 0.00568894 0.01186091]
#  [0.00567303 0.00705444 0.01083556]
#  [0.005429   0.01033312 0.00798967]
#  [0.00318252 0.00633251 0.01157187]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 18/100
#
# ***********************
#  2152
# Profit is  722988.4902309999
# Initial Capital is  58418.99902
# Current Capital is  781407.4892509999
# %ROI is  1237.5913698615095
# % Buy and Hold= 197.06176194595128
# count 2087
# qtable [[0.00559875 0.0069294  0.00985144]
#  [0.00310613 0.01008964 0.00722565]
#  [0.00410802 0.0097958  0.00500009]
#  [0.00514023 0.00692667 0.01053672]
#  [0.00487748 0.00568894 0.01169496]
#  [0.00576834 0.00704449 0.01069613]
#  [0.00544225 0.01021543 0.00824083]
#  [0.00318252 0.00633251 0.01150985]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 19/100
#
# ***********************
#  2152
# Profit is  900917.2715830011
# Initial Capital is  58418.99902
# Current Capital is  959336.2706030011
# %ROI is  1542.1648550920363
# % Buy and Hold= 197.06176194595128
# count 2088
# qtable [[0.00562015 0.0068748  0.01048578]
#  [0.00310613 0.01009696 0.00722565]
#  [0.00410802 0.00983716 0.00500009]
#  [0.00520439 0.00692667 0.01072034]
#  [0.00487748 0.00568894 0.01183151]
#  [0.00574173 0.00704449 0.01080006]
#  [0.00544225 0.01017121 0.00801965]
#  [0.00318252 0.00633251 0.01153432]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 20/100
#
# ***********************
#  2152
# Profit is  761876.073981001
# Initial Capital is  58418.99902
# Current Capital is  820295.073001001
# %ROI is  1304.158042352231
# % Buy and Hold= 197.06176194595128
# count 2084
# qtable [[0.00558697 0.00701858 0.01023662]
#  [0.00320035 0.01009345 0.00722565]
#  [0.00415217 0.00974499 0.00506167]
#  [0.0052271  0.00692667 0.01053669]
#  [0.0049495  0.00572078 0.01179442]
#  [0.00574778 0.00751296 0.01074276]
#  [0.00552766 0.01013932 0.00792929]
#  [0.00318252 0.00633251 0.01150789]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 21/100
#
# ***********************
#  2152
# Profit is  722244.5484710005
# Initial Capital is  58418.99902
# Current Capital is  780663.5474910005
# %ROI is  1236.3179112735857
# % Buy and Hold= 197.06176194595128
# count 2084
# qtable [[0.00560788 0.00697687 0.01034725]
#  [0.00320035 0.01009301 0.00720667]
#  [0.00418577 0.00976736 0.00506167]
#  [0.00525246 0.00692667 0.01059528]
#  [0.0049495  0.00572078 0.0117323 ]
#  [0.00579115 0.0074701  0.01069867]
#  [0.00552766 0.01016097 0.00798289]
#  [0.00318252 0.00633251 0.01149582]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 22/100
#
# ***********************
#  2152
# Profit is  613397.4363639993
# Initial Capital is  58418.99902
# Current Capital is  671816.4353839993
# %ROI is  1049.9964851400482
# % Buy and Hold= 197.06176194595128
# count 2089
# qtable [[0.00562433 0.00667972 0.01005117]
#  [0.00320035 0.01011124 0.00715045]
#  [0.00418577 0.00975528 0.00511228]
#  [0.00525246 0.006926   0.01045899]
#  [0.0049495  0.00572078 0.01162758]
#  [0.00582633 0.00757134 0.01054453]
#  [0.0055252  0.01010228 0.00800366]
#  [0.00318252 0.00633251 0.01148282]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 23/100
#
# ***********************
#  2152
# Profit is  962922.8477090019
# Initial Capital is  58418.99902
# Current Capital is  1021341.8467290018
# %ROI is  1648.3042569410354
# % Buy and Hold= 197.06176194595128
# count 2086
# qtable [[0.00562433 0.00661852 0.0105264 ]
#  [0.00320035 0.01013192 0.00715045]
#  [0.00422598 0.0099127  0.00518363]
#  [0.00526846 0.00686279 0.01076973]
#  [0.0049495  0.00572078 0.01186215]
#  [0.00586621 0.00757134 0.01083134]
#  [0.0055252  0.01023152 0.00800366]
#  [0.00318252 0.00633251 0.01155517]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 24/100
#
# ***********************
#  2152
# Profit is  888343.3102610015
# Initial Capital is  58418.99902
# Current Capital is  946762.3092810014
# %ROI is  1520.6411016335169
# % Buy and Hold= 197.06176194595128
# count 2086
# qtable [[0.00568147 0.00667143 0.01050705]
#  [0.00320035 0.01000327 0.00716879]
#  [0.00432148 0.00989832 0.00519663]
#  [0.00531198 0.00679113 0.01074226]
#  [0.0049495  0.00574697 0.01186075]
#  [0.00584728 0.00748219 0.01081663]
#  [0.00559818 0.01021892 0.00795909]
#  [0.00318252 0.00633251 0.01155635]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 25/100
#
# ***********************
#  2152
# Profit is  960527.5839470013
# Initial Capital is  58418.99902
# Current Capital is  1018946.5829670012
# %ROI is  1644.204111779047
# % Buy and Hold= 197.06176194595128
# count 2080
# qtable [[0.00572351 0.00667143 0.0105207 ]
#  [0.00320035 0.01015354 0.00716879]
#  [0.00436501 0.00991704 0.00519663]
#  [0.00534414 0.00679113 0.01074321]
#  [0.0049495  0.00574697 0.01186305]
#  [0.00585669 0.00737221 0.01082011]
#  [0.00565145 0.0102667  0.00810382]
#  [0.00345271 0.00633843 0.01158657]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 26/100
#
# ***********************
#  2152
# Profit is  921309.7805460001
# Initial Capital is  58418.99902
# Current Capital is  979728.7795660001
# %ROI is  1577.072178574278
# % Buy and Hold= 197.06176194595128
# count 2087
# qtable [[0.00573816 0.00667143 0.01051331]
#  [0.00329193 0.01013605 0.00716879]
#  [0.00441114 0.00988125 0.00519663]
#  [0.00534414 0.00679113 0.01073964]
#  [0.00504553 0.0058603  0.01183357]
#  [0.00585669 0.00735961 0.01082212]
#  [0.00569802 0.01029091 0.00813121]
#  [0.00345271 0.00633843 0.01156697]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 27/100
#
# ***********************
#  2152
# Profit is  920774.1855570019
# Initial Capital is  58418.99902
# Current Capital is  979193.1845770018
# %ROI is  1576.1553621310265
# % Buy and Hold= 197.06176194595128
# count 2085
# qtable [[0.0057612  0.00683573 0.01052059]
#  [0.00329193 0.01010627 0.00714156]
#  [0.00448337 0.00969467 0.00525563]
#  [0.00539412 0.00679746 0.01076026]
#  [0.00504553 0.00604346 0.01187061]
#  [0.00585227 0.00732805 0.01074336]
#  [0.00571504 0.01022771 0.00807523]
#  [0.00345271 0.00633843 0.01156586]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 28/100
#
# ***********************
#  2152
# Profit is  935539.596057001
# Initial Capital is  58418.99902
# Current Capital is  993958.595077001
# %ROI is  1601.4303766771404
# % Buy and Hold= 197.06176194595128
# count 2089
# qtable [[0.00577619 0.00680657 0.01047871]
#  [0.00329193 0.01010855 0.00714156]
#  [0.00448337 0.00982291 0.00531778]
#  [0.00542735 0.00713617 0.01069326]
#  [0.00504553 0.00604346 0.01182148]
#  [0.00585227 0.00723069 0.01076729]
#  [0.00575416 0.01019349 0.00796449]
#  [0.00345271 0.00756484 0.01163686]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 29/100
#
# ***********************
#  2152
# Profit is  742310.8626380012
# Initial Capital is  58418.99902
# Current Capital is  800729.8616580012
# %ROI is  1270.6668636754077
# % Buy and Hold= 197.06176194595128
# count 2080
# qtable [[0.00577176 0.00680645 0.01024798]
#  [0.00329193 0.01008705 0.00714156]
#  [0.00455352 0.00984178 0.00531778]
#  [0.00545266 0.00732296 0.01054297]
#  [0.00504553 0.0061702  0.01172006]
#  [0.00585686 0.00724389 0.01059649]
#  [0.00590318 0.01020353 0.00787995]
#  [0.00352127 0.00756484 0.01131098]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 30/100
#
# ***********************
#  2152
# Profit is  904490.8626349999
# Initial Capital is  58418.99902
# Current Capital is  962909.8616549999
# %ROI is  1548.282027778914
# % Buy and Hold= 197.06176194595128
# count 2086
# qtable [[0.00577275 0.00680645 0.01048108]
#  [0.00329193 0.01010787 0.00714156]
#  [0.00459641 0.00981703 0.00536043]
#  [0.00548973 0.00732296 0.01072108]
#  [0.00504553 0.0061702  0.0118337 ]
#  [0.00585686 0.00724389 0.01080013]
#  [0.00589976 0.01022945 0.00786457]
#  [0.0037031  0.00756484 0.01142627]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 31/100
#
# ***********************
#  2152
# Profit is  927183.3893430011
# Initial Capital is  58418.99902
# Current Capital is  985602.388363001
# %ROI is  1587.1264569692057
# % Buy and Hold= 197.06176194595128
# count 2086
# qtable [[0.00580245 0.00684111 0.010471  ]
#  [0.00329193 0.01013219 0.00714156]
#  [0.00459641 0.00988355 0.00536672]
#  [0.00554552 0.00732296 0.01074405]
#  [0.00504553 0.00616761 0.01185051]
#  [0.00584464 0.00724389 0.01082567]
#  [0.00591314 0.01034058 0.00773289]
#  [0.0037031  0.00756484 0.0115557 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 32/100
#
# ***********************
#  2152
# Profit is  919998.2652249999
# Initial Capital is  58418.99902
# Current Capital is  978417.2642449999
# %ROI is  1574.8271635226656
# % Buy and Hold= 197.06176194595128
# count 2091
# qtable [[0.00580245 0.00701323 0.010501  ]
#  [0.00329193 0.01014095 0.00714156]
#  [0.00459641 0.00988075 0.00536672]
#  [0.00556347 0.00732296 0.01072397]
#  [0.00504553 0.00616761 0.01184379]
#  [0.00584464 0.00714592 0.01072587]
#  [0.00592305 0.01023039 0.00760351]
#  [0.0037031  0.00756484 0.01157139]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 33/100
#
# ***********************
#  2152
# Profit is  669304.6004370004
# Initial Capital is  58418.99902
# Current Capital is  727723.5994570004
# %ROI is  1145.6967967011228
# % Buy and Hold= 197.06176194595128
# count 2086
# qtable [[0.00581054 0.00705872 0.01020341]
#  [0.00329193 0.01008415 0.00714156]
#  [0.00459641 0.00975634 0.00536672]
#  [0.00568558 0.00732296 0.01009431]
#  [0.00508033 0.00615256 0.01164199]
#  [0.00580202 0.0070799  0.01040021]
#  [0.00592886 0.01007323 0.00759407]
#  [0.0037031  0.00768417 0.01150995]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 34/100
#
# ***********************
#  2152
# Profit is  602959.2432519994
# Initial Capital is  58418.99902
# Current Capital is  661378.2422719994
# %ROI is  1032.1286796536408
# % Buy and Hold= 197.06176194595128
# count 2082
# qtable [[0.00591117 0.00661346 0.01006681]
#  [0.00329193 0.01008687 0.00747526]
#  [0.00459641 0.00974692 0.00551045]
#  [0.00569972 0.007503   0.01042683]
#  [0.00511096 0.00616207 0.01158283]
#  [0.00581119 0.00708061 0.01047512]
#  [0.00595958 0.01012387 0.00750297]
#  [0.0037031  0.00768417 0.01146473]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 35/100
#
# ***********************
#  2152
# Profit is  878176.1422980013
# Initial Capital is  58418.99902
# Current Capital is  936595.1413180013
# %ROI is  1503.2372293769597
# % Buy and Hold= 197.06176194595128
# count 2091
# qtable [[0.00591117 0.00661346 0.01050503]
#  [0.00329193 0.0101001  0.00747526]
#  [0.00459641 0.00984607 0.00551045]
#  [0.00569972 0.00749322 0.01072805]
#  [0.00511096 0.00616207 0.01183204]
#  [0.00580737 0.00710968 0.01081295]
#  [0.00602822 0.01020886 0.00746818]
#  [0.0037031  0.00768417 0.01152047]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 36/100
#
# ***********************
#  2152
# Profit is  915713.6747420008
# Initial Capital is  58418.99902
# Current Capital is  974132.6737620007
# %ROI is  1567.4929220004303
# % Buy and Hold= 197.06176194595128
# count 2085
# qtable [[0.00595833 0.00654656 0.01053148]
#  [0.00329193 0.01015012 0.00744985]
#  [0.00459641 0.00993844 0.00555119]
#  [0.00569972 0.00749322 0.01074877]
#  [0.00511096 0.00616207 0.01186158]
#  [0.0058419  0.00710968 0.01083286]
#  [0.00602376 0.01027352 0.00745761]
#  [0.0037031  0.00768417 0.01156039]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 37/100
#
# ***********************
#  2152
# Profit is  974492.7775040007
# Initial Capital is  58418.99902
# Current Capital is  1032911.7765240007
# %ROI is  1668.1093374612235
# % Buy and Hold= 197.06176194595128
# count 2088
# qtable [[0.00595698 0.00662883 0.01057754]
#  [0.00329193 0.01014898 0.00744985]
#  [0.00459641 0.00989334 0.00555119]
#  [0.00569972 0.00743    0.01076766]
#  [0.00511096 0.00616207 0.01187631]
#  [0.00580411 0.00710454 0.01092638]
#  [0.00606297 0.01030176 0.00745761]
#  [0.0037031  0.00768417 0.01156932]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 38/100
#
# ***********************
#  2152
# Profit is  915174.4387969986
# Initial Capital is  58418.99902
# Current Capital is  973593.4378169986
# %ROI is  1566.5698730710612
# % Buy and Hold= 197.06176194595128
# count 2088
# qtable [[0.00598663 0.00662135 0.0104548 ]
#  [0.00329193 0.01013949 0.00773594]
#  [0.00459641 0.00987176 0.00555119]
#  [0.00569972 0.00743    0.01066184]
#  [0.0051807  0.00616207 0.01177821]
#  [0.00586988 0.00722125 0.01082386]
#  [0.00608906 0.01029328 0.00743818]
#  [0.0037031  0.00768417 0.01155767]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 39/100
#
# ***********************
#  2152
# Profit is  849171.617481001
# Initial Capital is  58418.99902
# Current Capital is  907590.616501001
# %ROI is  1453.5880992933194
# % Buy and Hold= 197.06176194595128
# count 2085
# qtable [[0.00600582 0.00660532 0.01052984]
#  [0.00329193 0.01012101 0.00773594]
#  [0.00463523 0.00987897 0.00555119]
#  [0.00569972 0.00743    0.01075399]
#  [0.0051807  0.00619051 0.01195442]
#  [0.00589376 0.00722125 0.01086042]
#  [0.00618513 0.01029124 0.00738295]
#  [0.00378254 0.00768417 0.01157045]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 40/100
#
# ***********************
#  2152
# Profit is  848695.9613770003
# Initial Capital is  58418.99902
# Current Capital is  907114.9603970003
# %ROI is  1452.773884548151
# % Buy and Hold= 197.06176194595128
# count 2087
# qtable [[0.00595456 0.00671055 0.01041504]
#  [0.00329193 0.01012161 0.00773594]
#  [0.00463523 0.00986222 0.00555119]
#  [0.00569972 0.00743    0.01063631]
#  [0.0051807  0.00619051 0.01177591]
#  [0.00592691 0.00719971 0.01053559]
#  [0.00618262 0.0102116  0.00738295]
#  [0.00378254 0.00764667 0.01169466]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 41/100
#
# ***********************
#  2152
# Profit is  962355.179829001
# Initial Capital is  58418.99902
# Current Capital is  1020774.178849001
# %ROI is  1647.3325390247346
# % Buy and Hold= 197.06176194595128
# count 2089
# qtable [[0.00592579 0.00671055 0.01052831]
#  [0.00329193 0.01014488 0.00773594]
#  [0.00463523 0.0099005  0.00592411]
#  [0.00564368 0.00743    0.01075038]
#  [0.0051807  0.00619508 0.01186687]
#  [0.00592691 0.00706987 0.0108563 ]
#  [0.00622424 0.01023558 0.00753857]
#  [0.00378254 0.00782689 0.01159065]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 42/100
#
# ***********************
#  2152
# Profit is  916871.028283999
# Initial Capital is  58418.99902
# Current Capital is  975290.0273039989
# %ROI is  1569.474047253196
# % Buy and Hold= 197.06176194595128
# count 2084
# qtable [[0.00590833 0.00683818 0.01061532]
#  [0.00329193 0.01015889 0.00768044]
#  [0.00472147 0.00991368 0.00592411]
#  [0.00569147 0.00735895 0.01075884]
#  [0.0051807  0.00619508 0.01186622]
#  [0.00591746 0.0070257  0.01083627]
#  [0.00623309 0.01024159 0.00753857]
#  [0.00378254 0.00782689 0.01157716]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 43/100
#
# ***********************
#  2152
# Profit is  891621.5702640015
# Initial Capital is  58418.99902
# Current Capital is  950040.5692840015
# %ROI is  1526.2527349343163
# % Buy and Hold= 197.06176194595128
# count 2085
# qtable [[0.00587364 0.00684976 0.01052696]
#  [0.00329193 0.01023204 0.00760469]
#  [0.00474888 0.00994853 0.00600426]
#  [0.00574177 0.0072639  0.01065516]
#  [0.00521383 0.00619508 0.01196344]
#  [0.00593557 0.0070257  0.01078946]
#  [0.00627252 0.01021229 0.00753857]
#  [0.00378254 0.00782689 0.01156503]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 44/100
#
# ***********************
#  2152
# Profit is  913574.7364369995
# Initial Capital is  58418.99902
# Current Capital is  971993.7354569995
# %ROI is  1563.831547548826
# % Buy and Hold= 197.06176194595128
# count 2084
# qtable [[0.00585317 0.00681261 0.01049146]
#  [0.00344833 0.0099979  0.00760469]
#  [0.00479558 0.0098575  0.00600426]
#  [0.0057205  0.00721254 0.01075665]
#  [0.00521383 0.00633669 0.01195579]
#  [0.0059166  0.00697524 0.01081376]
#  [0.00632588 0.01012515 0.00750572]
#  [0.00378254 0.00782689 0.01156115]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 45/100
#
# ***********************
#  2152
# Profit is  567418.3986429997
# Initial Capital is  58418.99902
# Current Capital is  625837.3976629997
# %ROI is  971.2908611267741
# % Buy and Hold= 197.06176194595128
# count 2085
# qtable [[0.0059211  0.00659278 0.01003657]
#  [0.00344833 0.01003122 0.00760469]
#  [0.00487562 0.00969628 0.00615555]
#  [0.00569577 0.00721254 0.0104027 ]
#  [0.00521383 0.00636089 0.01156952]
#  [0.00589223 0.00697524 0.01049167]
#  [0.00631503 0.01003256 0.0074424 ]
#  [0.00378254 0.00778081 0.01139326]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 46/100
#
# ***********************
#  2152
# Profit is  870594.6478510005
# Initial Capital is  58418.99902
# Current Capital is  929013.6468710005
# %ROI is  1490.2594403456803
# % Buy and Hold= 197.06176194595128
# count 2083
# qtable [[0.00591156 0.00669875 0.01046595]
#  [0.00344833 0.01009408 0.00755163]
#  [0.00491844 0.00983649 0.00613588]
#  [0.00578611 0.00721254 0.01050556]
#  [0.00521383 0.00636089 0.01179407]
#  [0.00583919 0.00697524 0.01076422]
#  [0.00633851 0.01010417 0.00734877]
#  [0.00378254 0.00778081 0.01150823]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 47/100
#
# ***********************
#  2152
# Profit is  957586.435515001
# Initial Capital is  58418.99902
# Current Capital is  1016005.4345350009
# %ROI is  1639.1695365871763
# % Buy and Hold= 197.06176194595128
# count 2079
# qtable [[0.00592149 0.00668165 0.01052225]
#  [0.00371735 0.01014019 0.00755163]
#  [0.00491844 0.00987691 0.00613588]
#  [0.00581133 0.0072161  0.01074919]
#  [0.00525333 0.00641477 0.01192011]
#  [0.00593032 0.00712638 0.01085414]
#  [0.00633851 0.01023114 0.00734877]
#  [0.00386961 0.00778081 0.01158196]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 48/100
#
# ***********************
#  2152
# Profit is  843408.5018080005
# Initial Capital is  58418.99902
# Current Capital is  901827.5008280005
# %ROI is  1443.7229599214047
# % Buy and Hold= 197.06176194595128
# count 2087
# qtable [[0.0059105  0.00668165 0.01051049]
#  [0.00371735 0.01012773 0.00755163]
#  [0.00491844 0.00986407 0.00613588]
#  [0.00583834 0.00709405 0.01065858]
#  [0.0052916  0.00641477 0.01184377]
#  [0.00591194 0.00730078 0.01083638]
#  [0.00633851 0.01022103 0.00721992]
#  [0.00386961 0.00778081 0.01155036]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 49/100
#
# ***********************
#  2152
# Profit is  966727.1195359982
# Initial Capital is  58418.99902
# Current Capital is  1025146.1185559982
# %ROI is  1654.8163024926787
# % Buy and Hold= 197.06176194595128
# count 2085
# qtable [[0.00596125 0.00664929 0.01056012]
#  [0.00371735 0.01013723 0.00755163]
#  [0.00496191 0.00987557 0.00632422]
#  [0.00584907 0.0070818  0.01075887]
#  [0.0052916  0.00674283 0.0118754 ]
#  [0.00593662 0.00745086 0.01087949]
#  [0.00627085 0.01012429 0.00722421]
#  [0.00386961 0.00778081 0.01156615]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 50/100
#
# ***********************
#  2152
# Profit is  911013.4844400014
# Initial Capital is  58418.99902
# Current Capital is  969432.4834600014
# %ROI is  1559.4472683931335
# % Buy and Hold= 197.06176194595128
# count 2085
# qtable [[0.00596727 0.00686484 0.01053394]
#  [0.00371735 0.01012412 0.00755163]
#  [0.00498231 0.00987298 0.00632422]
#  [0.00583249 0.00717642 0.01079084]
#  [0.0052646  0.00682601 0.01182722]
#  [0.00594542 0.00732812 0.01078192]
#  [0.00627085 0.01022262 0.007479  ]
#  [0.00395471 0.00778081 0.01157597]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 51/100
#
# ***********************
#  2152
# Profit is  930261.8334310005
# Initial Capital is  58418.99902
# Current Capital is  988680.8324510005
# %ROI is  1592.3960510047789
# % Buy and Hold= 197.06176194595128
# count 2087
# qtable [[0.0059363  0.00686484 0.01049213]
#  [0.00371735 0.01013704 0.00755163]
#  [0.00498231 0.00986961 0.00634232]
#  [0.00589795 0.00717642 0.01044308]
#  [0.0052646  0.00678524 0.01179434]
#  [0.00594542 0.00727984 0.01079828]
#  [0.00627085 0.01022589 0.007479  ]
#  [0.00403777 0.00778081 0.01158719]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 52/100
#
# ***********************
#  2152
# Profit is  1001618.8925039999
# Initial Capital is  58418.99902
# Current Capital is  1060037.8915239999
# %ROI is  1714.5430584339372
# % Buy and Hold= 197.06176194595128
# count 2087
# qtable [[0.00592452 0.00684303 0.01051571]
#  [0.00387076 0.01024763 0.00755163]
#  [0.00498231 0.00988704 0.00634232]
#  [0.00591573 0.00717642 0.01074046]
#  [0.0052646  0.00678524 0.01185592]
#  [0.00594999 0.00741914 0.01082561]
#  [0.00622331 0.01024586 0.00763139]
#  [0.00403777 0.00778081 0.01157462]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 53/100
#
# ***********************
#  2152
# Profit is  625574.5446679997
# Initial Capital is  58418.99902
# Current Capital is  683993.5436879997
# %ROI is  1070.8409167603702
# % Buy and Hold= 197.06176194595128
# count 2082
# qtable [[0.00605949 0.00667072 0.01010087]
#  [0.00387076 0.01006185 0.00755163]
#  [0.00502527 0.00968965 0.00634232]
#  [0.00595151 0.00717642 0.0104558 ]
#  [0.0052646  0.00678524 0.01162108]
#  [0.00599211 0.00734775 0.01059957]
#  [0.00631808 0.01014516 0.00763139]
#  [0.00403777 0.00778081 0.01146316]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 54/100
#
# ***********************
#  2152
# Profit is  958242.6293160019
# Initial Capital is  58418.99902
# Current Capital is  1016661.6283360019
# %ROI is  1640.2927906860289
# % Buy and Hold= 197.06176194595128
# count 2086
# qtable [[0.00602064 0.00667072 0.01054763]
#  [0.00387076 0.01013768 0.00755163]
#  [0.00504106 0.00991238 0.00634232]
#  [0.00595151 0.00726222 0.01079696]
#  [0.00525325 0.00674509 0.01183332]
#  [0.005962   0.00727809 0.01091825]
#  [0.00631189 0.01040613 0.00776063]
#  [0.00403777 0.00771673 0.01153678]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 55/100
#
# ***********************
#  2152
# Profit is  921066.7270760004
# Initial Capital is  58418.99902
# Current Capital is  979485.7260960004
# %ROI is  1576.6561264780814
# % Buy and Hold= 197.06176194595128
# count 2079
# qtable [[0.00602515 0.00698145 0.010479  ]
#  [0.00387076 0.01015531 0.00755163]
#  [0.00508001 0.00992825 0.00645855]
#  [0.005982   0.00721819 0.01075485]
#  [0.00525325 0.0067481  0.01187037]
#  [0.00598114 0.00765384 0.01091444]
#  [0.00629922 0.0103311  0.00769459]
#  [0.00403777 0.00769074 0.01155925]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 56/100
#
# ***********************
#  2152
# Profit is  695188.5389310023
# Initial Capital is  58418.99902
# Current Capital is  753607.5379510022
# %ROI is  1190.0041948561998
# % Buy and Hold= 197.06176194595128
# count 2087
# qtable [[0.0060272  0.00690737 0.01023564]
#  [0.00387076 0.01009969 0.00755163]
#  [0.00508001 0.00979166 0.00645855]
#  [0.00601299 0.00719229 0.01057739]
#  [0.00525325 0.0067481  0.01168903]
#  [0.00598113 0.00739253 0.01065609]
#  [0.0063411  0.01022158 0.00773293]
#  [0.00403777 0.00769074 0.01150573]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 57/100
#
# ***********************
#  2152
# Profit is  663556.1139810006
# Initial Capital is  58418.99902
# Current Capital is  721975.1130010006
# %ROI is  1135.8566992115516
# % Buy and Hold= 197.06176194595128
# count 2085
# qtable [[0.0060272  0.00661461 0.01007125]
#  [0.00387076 0.01003705 0.00755163]
#  [0.00508001 0.00964356 0.00664426]
#  [0.0060086  0.00769708 0.01044312]
#  [0.00527525 0.00717478 0.01147529]
#  [0.0059877  0.00774652 0.01059525]
#  [0.00632466 0.01006469 0.00791308]
#  [0.00411955 0.00769074 0.01144803]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 58/100
#
# ***********************
#  2152
# Profit is  843330.6800240022
# Initial Capital is  58418.99902
# Current Capital is  901749.6790440022
# %ROI is  1443.5897467796121
# % Buy and Hold= 197.06176194595128
# count 2084
# qtable [[0.00600394 0.00661885 0.01050216]
#  [0.00387076 0.0100888  0.00755163]
#  [0.00513197 0.00991191 0.00663508]
#  [0.00599021 0.00765129 0.01072645]
#  [0.00532935 0.00717478 0.01181954]
#  [0.00592337 0.00744897 0.01082505]
#  [0.00642851 0.0102156  0.00792345]
#  [0.00411955 0.00769074 0.0115018 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 59/100
#
# ***********************
#  2152
# Profit is  909214.2769039999
# Initial Capital is  58418.99902
# Current Capital is  967633.2759239998
# %ROI is  1556.3674355199519
# % Buy and Hold= 197.06176194595128
# count 2091
# qtable [[0.00600708 0.00697047 0.01051178]
#  [0.00387076 0.01012512 0.00755163]
#  [0.00513197 0.009868   0.00663508]
#  [0.00599021 0.00754989 0.01072929]
#  [0.00532935 0.00718349 0.01190919]
#  [0.00592733 0.00743566 0.01082368]
#  [0.00642851 0.01022208 0.0079145 ]
#  [0.00411955 0.0076518  0.01154364]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 60/100
#
# ***********************
#  2152
# Profit is  887800.7803150022
# Initial Capital is  58418.99902
# Current Capital is  946219.7793350022
# %ROI is  1519.712414125856
# % Buy and Hold= 197.06176194595128
# count 2085
# qtable [[0.00595914 0.00700592 0.01048592]
#  [0.00387076 0.01011829 0.00752774]
#  [0.00513197 0.00984997 0.00663508]
#  [0.00599021 0.00754989 0.01071726]
#  [0.00532935 0.00718349 0.01183992]
#  [0.00594246 0.00741638 0.01080038]
#  [0.00643279 0.01020285 0.0079145 ]
#  [0.00422929 0.0076518  0.01148712]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 61/100
#
# ***********************
#  2152
# Profit is  957646.6851830004
# Initial Capital is  58418.99902
# Current Capital is  1016065.6842030004
# %ROI is  1639.2726702748637
# % Buy and Hold= 197.06176194595128
# count 2088
# qtable [[0.00595777 0.00704838 0.01054259]
#  [0.00394677 0.01025804 0.00752774]
#  [0.00513197 0.00988444 0.00662685]
#  [0.00595951 0.00754989 0.01077132]
#  [0.00532935 0.00717662 0.01187625]
#  [0.00592621 0.00740418 0.01084015]
#  [0.00638165 0.01024539 0.00783192]
#  [0.00422929 0.0076518  0.01156389]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 62/100
#
# ***********************
#  2152
# Profit is  710697.0142190014
# Initial Capital is  58418.99902
# Current Capital is  769116.0132390014
# %ROI is  1216.5511668142262
# % Buy and Hold= 197.06176194595128
# count 2084
# qtable [[0.00595777 0.00692365 0.01023608]
#  [0.00394677 0.01010515 0.00752774]
#  [0.00522105 0.00983159 0.00662685]
#  [0.00594915 0.00752815 0.01054237]
#  [0.00536649 0.00717662 0.01170004]
#  [0.00593322 0.00737684 0.01064907]
#  [0.00637695 0.01014924 0.00819856]
#  [0.00422929 0.0076518  0.01151728]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 63/100
#
# ***********************
#  2152
# Profit is  933789.4834109996
# Initial Capital is  58418.99902
# Current Capital is  992208.4824309996
# %ROI is  1598.4345830562977
# % Buy and Hold= 197.06176194595128
# count 2086
# qtable [[0.00595777 0.00687005 0.01052169]
#  [0.00403453 0.0102267  0.00781027]
#  [0.00522105 0.00987382 0.00662685]
#  [0.00592997 0.0074386  0.01074116]
#  [0.00536649 0.00717662 0.01185287]
#  [0.00599078 0.00737806 0.01082184]
#  [0.00635655 0.01025178 0.00804623]
#  [0.00429907 0.00761856 0.01165908]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 64/100
#
# ***********************
#  2152
# Profit is  965068.910014
# Initial Capital is  58418.99902
# Current Capital is  1023487.909034
# %ROI is  1651.9778260555345
# % Buy and Hold= 197.06176194595128
# count 2087
# qtable [[0.00600098 0.00687005 0.01057217]
#  [0.00403453 0.01015499 0.00781027]
#  [0.00522105 0.00988435 0.00662685]
#  [0.00591021 0.0074386  0.01076799]
#  [0.00536649 0.00717662 0.01187238]
#  [0.00599075 0.00751187 0.01075677]
#  [0.00645156 0.01022927 0.0081087 ]
#  [0.00429907 0.0075773  0.01159293]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 65/100
#
# ***********************
#  2152
# Profit is  986258.5630219996
# Initial Capital is  58418.99902
# Current Capital is  1044677.5620419995
# %ROI is  1688.249678301317
# % Buy and Hold= 197.06176194595128
# count 2085
# qtable [[0.00608375 0.00739815 0.01050703]
#  [0.0040851  0.01010562 0.00781027]
#  [0.00522105 0.00987418 0.00662685]
#  [0.00591021 0.00737851 0.01076453]
#  [0.00536649 0.00717662 0.01187826]
#  [0.0060283  0.00751187 0.01089576]
#  [0.00645156 0.01021145 0.00799188]
#  [0.00429907 0.0075773  0.01155802]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 66/100
#
# ***********************
#  2152
# Profit is  736593.7599050005
# Initial Capital is  58418.99902
# Current Capital is  795012.7589250004
# %ROI is  1260.8804879604738
# % Buy and Hold= 197.06176194595128
# count 2084
# qtable [[0.00610397 0.00731623 0.01032221]
#  [0.00415269 0.01021089 0.00781027]
#  [0.00525808 0.00981224 0.00666166]
#  [0.00586839 0.00737851 0.01058589]
#  [0.00540097 0.00728792 0.01193203]
#  [0.00604273 0.00751187 0.0107278 ]
#  [0.00645156 0.01014353 0.00793884]
#  [0.00436819 0.0075255  0.01158088]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 67/100
#
# ***********************
#  2152
# Profit is  369971.2275069993
# Initial Capital is  58418.99902
# Current Capital is  428390.22652699926
# %ROI is  633.3063450476753
# % Buy and Hold= 197.06176194595128
# count 2089
# qtable [[0.0061063  0.00648607 0.00989587]
#  [0.00415269 0.00999599 0.00781027]
#  [0.00525808 0.00956818 0.00662603]
#  [0.00586372 0.00735758 0.01029738]
#  [0.00540097 0.00728792 0.01146589]
#  [0.00605587 0.00727238 0.01040451]
#  [0.00645156 0.01000901 0.00791478]
#  [0.00436819 0.00755473 0.01142884]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 68/100
#
# ***********************
#  2152
# Profit is  975951.6893589988
# Initial Capital is  58418.99902
# Current Capital is  1034370.6883789988
# %ROI is  1670.6066617554975
# % Buy and Hold= 197.06176194595128
# count 2083
# qtable [[0.00617303 0.00648607 0.01053466]
#  [0.00415269 0.01010751 0.00781027]
#  [0.00525808 0.00985807 0.00662603]
#  [0.00591248 0.00733153 0.0107284 ]
#  [0.00540097 0.00728792 0.01183388]
#  [0.00608419 0.00746448 0.0108069 ]
#  [0.00640717 0.01022554 0.0081033 ]
#  [0.00436819 0.00755473 0.0115259 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 69/100
#
# ***********************
#  2152
# Profit is  860512.3523630005
# Initial Capital is  58418.99902
# Current Capital is  918931.3513830005
# %ROI is  1473.0008504055338
# % Buy and Hold= 197.06176194595128
# count 2085
# qtable [[0.00612448 0.00650049 0.01049789]
#  [0.00421568 0.0100724  0.00781027]
#  [0.00526923 0.0098374  0.00662603]
#  [0.00588243 0.00731683 0.01072043]
#  [0.00540097 0.00728792 0.01183383]
#  [0.00609081 0.00740224 0.01080056]
#  [0.00636519 0.01018127 0.00801365]
#  [0.00442846 0.007505   0.01137204]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 70/100
#
# ***********************
#  2152
# Profit is  1011662.2383940013
# Initial Capital is  58418.99902
# Current Capital is  1070081.2374140013
# %ROI is  1731.7349755473458
# % Buy and Hold= 197.06176194595128
# count 2088
# qtable [[0.00607506 0.00649011 0.01054034]
#  [0.00421568 0.01013248 0.00781027]
#  [0.00526923 0.00988153 0.00662603]
#  [0.00588243 0.00731683 0.01076149]
#  [0.00540097 0.00765327 0.01188684]
#  [0.00611931 0.00768385 0.01090272]
#  [0.00637449 0.01023801 0.00801365]
#  [0.00442846 0.007505   0.0115557 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 71/100
#
# ***********************
#  2152
# Profit is  936791.9742770016
# Initial Capital is  58418.99902
# Current Capital is  995210.9732970016
# %ROI is  1603.5741625019743
# % Buy and Hold= 197.06176194595128
# count 2087
# qtable [[0.00606981 0.00649011 0.01050067]
#  [0.00426456 0.01015671 0.00781027]
#  [0.00526804 0.0098885  0.00709678]
#  [0.00588243 0.00731683 0.01071064]
#  [0.00540097 0.00763238 0.01183613]
#  [0.00609947 0.007501   0.0107982 ]
#  [0.00637449 0.01023143 0.00789952]
#  [0.00442846 0.007505   0.01157105]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 72/100
#
# ***********************
#  2152
# Profit is  899829.3643690011
# Initial Capital is  58418.99902
# Current Capital is  958248.3633890011
# %ROI is  1540.3026061109683
# % Buy and Hold= 197.06176194595128
# count 2078
# qtable [[0.00605892 0.00649011 0.0105629 ]
#  [0.00426456 0.01012014 0.00781027]
#  [0.00536197 0.00985889 0.00709678]
#  [0.00592427 0.00730842 0.01075314]
#  [0.00544921 0.00760739 0.01163898]
#  [0.00610267 0.00743796 0.01081009]
#  [0.0063817  0.01021874 0.00789952]
#  [0.00449552 0.007505   0.0115465 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 73/100
#
# ***********************
#  2152
# Profit is  995037.7224060015
# Initial Capital is  58418.99902
# Current Capital is  1053456.7214260015
# %ROI is  1703.2775964979232
# % Buy and Hold= 197.06176194595128
# count 2086
# qtable [[0.00606286 0.00664358 0.01061632]
#  [0.00426456 0.01015053 0.00781027]
#  [0.00536197 0.0099014  0.00718946]
#  [0.00593726 0.00730842 0.01077087]
#  [0.00546894 0.00768521 0.01186554]
#  [0.00611899 0.00743796 0.01085739]
#  [0.00638104 0.01036236 0.00789952]
#  [0.00449552 0.00745705 0.0116019 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 74/100
#
# ***********************
#  2152
# Profit is  956682.7858860013
# Initial Capital is  58418.99902
# Current Capital is  1015101.7849060013
# %ROI is  1637.622694559482
# % Buy and Hold= 197.06176194595128
# count 2087
# qtable [[0.00607491 0.00664358 0.01056101]
#  [0.00429188 0.01017527 0.00781027]
#  [0.00536197 0.0098643  0.00713569]
#  [0.00590956 0.00755643 0.01079084]
#  [0.0054974  0.00768521 0.01186601]
#  [0.00612989 0.00753952 0.01071877]
#  [0.00638104 0.01023184 0.00812128]
#  [0.00449552 0.00745705 0.0115724 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 75/100
#
# ***********************
#  2152
# Profit is  878999.6067360003
# Initial Capital is  58418.99902
# Current Capital is  937418.6057560003
# %ROI is  1504.6468126492048
# % Buy and Hold= 197.06176194595128
# count 2090
# qtable [[0.00607491 0.00660463 0.01048356]
#  [0.00429188 0.01013654 0.00781027]
#  [0.00536197 0.00994878 0.00735985]
#  [0.00593577 0.00755643 0.01073303]
#  [0.0054974  0.00764669 0.01181329]
#  [0.0061127  0.00748061 0.01078236]
#  [0.00638104 0.01021745 0.00811138]
#  [0.00449552 0.00745705 0.01155522]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 76/100
#
# ***********************
#  2152
# Profit is  915855.5481100002
# Initial Capital is  58418.99902
# Current Capital is  974274.5471300002
# %ROI is  1567.7357768428265
# % Buy and Hold= 197.06176194595128
# count 2086
# qtable [[0.00607491 0.00675471 0.01052027]
#  [0.00429188 0.01010538 0.00781027]
#  [0.00541491 0.0098136  0.00733945]
#  [0.00595715 0.00787508 0.01085293]
#  [0.00554609 0.00764669 0.01184913]
#  [0.00610461 0.00736543 0.01082725]
#  [0.00637519 0.01020087 0.00799261]
#  [0.00449552 0.00745705 0.0115286 ]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 77/100
#
# ***********************
#  2152
# Profit is  909667.0531450004
# Initial Capital is  58418.99902
# Current Capital is  968086.0521650004
# %ROI is  1557.1424851589325
# % Buy and Hold= 197.06176194595128
# count 2085
# qtable [[0.00607491 0.00686416 0.01059486]
#  [0.00429188 0.01012993 0.00781027]
#  [0.00542334 0.00975386 0.00725413]
#  [0.00599617 0.00797855 0.01075801]
#  [0.00557834 0.00764669 0.01186968]
#  [0.00613998 0.00757679 0.01089905]
#  [0.00644987 0.01023461 0.00790522]
#  [0.00458264 0.00745705 0.01159899]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 78/100
#
# ***********************
#  2152
# Profit is  932756.3473330002
# Initial Capital is  58418.99902
# Current Capital is  991175.3463530001
# %ROI is  1596.6660897658771
# % Buy and Hold= 197.06176194595128
# count 2089
# qtable [[0.00611388 0.00687848 0.01050481]
#  [0.00429188 0.01012265 0.00781027]
#  [0.00542334 0.00985073 0.00725413]
#  [0.00601867 0.00797855 0.01073745]
#  [0.00557834 0.00764669 0.01185669]
#  [0.006201   0.0075964  0.01081523]
#  [0.00644987 0.01017133 0.00784228]
#  [0.00458264 0.00745705 0.01154919]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 79/100
#
# ***********************
#  2152
# Profit is  929856.8937080001
# Initial Capital is  58418.99902
# Current Capital is  988275.8927280001
# %ROI is  1591.702886572328
# % Buy and Hold= 197.06176194595128
# count 2082
# qtable [[0.00620171 0.00676915 0.01052065]
#  [0.00429188 0.01014971 0.00781027]
#  [0.00542334 0.00991344 0.00772882]
#  [0.00606089 0.00793398 0.01072037]
#  [0.00557834 0.00764669 0.01183973]
#  [0.00622828 0.00748366 0.01085273]
#  [0.00642531 0.01029965 0.00784228]
#  [0.00458264 0.00745705 0.01156473]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 80/100
#
# ***********************
#  2152
# Profit is  960943.2053760015
# Initial Capital is  58418.99902
# Current Capital is  1019362.2043960015
# %ROI is  1644.9155608554988
# % Buy and Hold= 197.06176194595128
# count 2088
# qtable [[0.00619876 0.00676915 0.01052573]
#  [0.00429188 0.01014848 0.00781027]
#  [0.00542334 0.00988135 0.00772882]
#  [0.00614717 0.00793398 0.01076668]
#  [0.00557834 0.00764669 0.01186676]
#  [0.00619438 0.00748447 0.01087133]
#  [0.00642531 0.01023516 0.00784228]
#  [0.00458264 0.00765544 0.01134401]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 81/100
#
# ***********************
#  2152
# Profit is  919713.7356190007
# Initial Capital is  58418.99902
# Current Capital is  978132.7346390007
# %ROI is  1574.340113743018
# % Buy and Hold= 197.06176194595128
# count 2085
# qtable [[0.00617213 0.00671528 0.0105229 ]
#  [0.00437384 0.01014066 0.00781027]
#  [0.00554842 0.00988914 0.00772882]
#  [0.00613332 0.00793398 0.01074801]
#  [0.00557834 0.00764669 0.01185673]
#  [0.00619438 0.0073682  0.01057151]
#  [0.00642703 0.01033653 0.00784228]
#  [0.00458264 0.00765544 0.01155976]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 82/100
#
# ***********************
#  2152
# Profit is  876138.3546170011
# Initial Capital is  58418.99902
# Current Capital is  934557.3536370011
# %ROI is  1499.7490017195455
# % Buy and Hold= 197.06176194595128
# count 2086
# qtable [[0.0061042  0.00678319 0.01049368]
#  [0.00437384 0.01011996 0.00828087]
#  [0.00558023 0.00978759 0.00772882]
#  [0.00613332 0.00772159 0.01065246]
#  [0.00565079 0.00764669 0.01188501]
#  [0.00621385 0.0073682  0.0107953 ]
#  [0.00642703 0.01021159 0.00784228]
#  [0.00458264 0.00765544 0.01154742]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 83/100
#
# ***********************
#  2152
# Profit is  1005637.1555380002
# Initial Capital is  58418.99902
# Current Capital is  1064056.1545580002
# %ROI is  1721.4214081171021
# % Buy and Hold= 197.06176194595128
# count 2088
# qtable [[0.00607587 0.00691282 0.01058501]
#  [0.00437384 0.01015717 0.00828087]
#  [0.00558023 0.00990006 0.00772882]
#  [0.00613332 0.00772159 0.01077523]
#  [0.00565079 0.00795777 0.01188985]
#  [0.00617786 0.0075452  0.01089696]
#  [0.00644181 0.01038167 0.00793604]
#  [0.0046501  0.00765544 0.01159421]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 84/100
#
# ***********************
#  2152
# Profit is  986948.5281339996
# Initial Capital is  58418.99902
# Current Capital is  1045367.5271539995
# %ROI is  1689.4307411808156
# % Buy and Hold= 197.06176194595128
# count 2083
# qtable [[0.00608146 0.00692642 0.01047833]
#  [0.00437384 0.01015541 0.00828087]
#  [0.00558023 0.0099053  0.00772882]
#  [0.00613332 0.00770911 0.01076537]
#  [0.00562241 0.00795777 0.01189202]
#  [0.006171   0.0075452  0.01082854]
#  [0.00644517 0.01026899 0.00814966]
#  [0.00467732 0.00765544 0.01164848]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 85/100
#
# ***********************
#  2152
# Profit is  934565.8766790008
# Initial Capital is  58418.99902
# Current Capital is  992984.8756990008
# %ROI is  1599.7635912232047
# % Buy and Hold= 197.06176194595128
# count 2086
# qtable [[0.00610925 0.00692642 0.01052024]
#  [0.00455056 0.01015107 0.00828087]
#  [0.00558023 0.00987327 0.00767002]
#  [0.00613332 0.00770911 0.01074837]
#  [0.00562241 0.00795777 0.0118645 ]
#  [0.00613597 0.00755744 0.01082745]
#  [0.00644452 0.01022104 0.00802901]
#  [0.00467732 0.00765544 0.01156602]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 86/100
#
# ***********************
#  2152
# Profit is  710009.3925420005
# Initial Capital is  58418.99902
# Current Capital is  768428.3915620005
# %ROI is  1215.3741153608703
# % Buy and Hold= 197.06176194595128
# count 2084
# qtable [[0.0061924  0.00701528 0.01024108]
#  [0.00455056 0.0100626  0.00828087]
#  [0.00558023 0.00974305 0.00767002]
#  [0.00613332 0.00768827 0.01052977]
#  [0.00565128 0.00795777 0.0118038 ]
#  [0.00617434 0.00751275 0.01062775]
#  [0.00643052 0.01005623 0.00795442]
#  [0.00467732 0.00765544 0.01147688]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 87/100
#
# ***********************
#  2152
# Profit is  709962.6768469998
# Initial Capital is  58418.99902
# Current Capital is  768381.6758669998
# %ROI is  1215.2941487476376
# % Buy and Hold= 197.06176194595128
# count 2084
# qtable [[0.00620686 0.0069799  0.0102306 ]
#  [0.00455056 0.01012805 0.00821707]
#  [0.00557933 0.00978    0.00767002]
#  [0.00611485 0.00768827 0.01050861]
#  [0.00564451 0.00809082 0.011463  ]
#  [0.00618615 0.00746403 0.01059568]
#  [0.00640682 0.01012653 0.00795442]
#  [0.00467732 0.00765544 0.01149116]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 88/100
#
# ***********************
#  2152
# Profit is  663470.0486029999
# Initial Capital is  58418.99902
# Current Capital is  721889.0476229999
# %ROI is  1135.7093749173243
# % Buy and Hold= 197.06176194595128
# count 2083
# qtable [[0.00618577 0.00696983 0.01017069]
#  [0.00455056 0.01007226 0.00821707]
#  [0.0055902  0.00977485 0.00764057]
#  [0.0061138  0.00779473 0.01048007]
#  [0.00566466 0.00805847 0.01163764]
#  [0.00617006 0.00742959 0.01048389]
#  [0.00640682 0.01012462 0.00795442]
#  [0.00467732 0.00794596 0.01151018]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 89/100
#
# ***********************
#  2152
# Profit is  719070.0239490013
# Initial Capital is  58418.99902
# Current Capital is  777489.0229690013
# %ROI is  1230.883849452512
# % Buy and Hold= 197.06176194595128
# count 2089
# qtable [[0.00621793 0.00692567 0.01008145]
#  [0.00455056 0.01006766 0.00821707]
#  [0.0055902  0.00976183 0.00764057]
#  [0.0061138  0.00779473 0.01049858]
#  [0.00566466 0.00810736 0.01166243]
#  [0.00617537 0.00735598 0.0105749 ]
#  [0.00640682 0.01010543 0.00787765]
#  [0.00467732 0.00790227 0.01155935]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 90/100
#
# ***********************
#  2152
# Profit is  969156.338527001
# Initial Capital is  58418.99902
# Current Capital is  1027575.337547001
# %ROI is  1658.9745712609797
# % Buy and Hold= 197.06176194595128
# count 2088
# qtable [[0.00621793 0.00687111 0.01051286]
#  [0.00455056 0.01017473 0.00851433]
#  [0.00560797 0.00986038 0.00760876]
#  [0.0061138  0.00792915 0.01076604]
#  [0.00566466 0.00819914 0.01183988]
#  [0.00617537 0.00749476 0.0108208 ]
#  [0.00639283 0.01018773 0.00787765]
#  [0.00467732 0.00790227 0.01155263]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 91/100
#
# ***********************
#  2152
# Profit is  991221.5945260006
# Initial Capital is  58418.99902
# Current Capital is  1049640.5935460005
# %ROI is  1696.7452560880947
# % Buy and Hold= 197.06176194595128
# count 2090
# qtable [[0.00621793 0.00692115 0.01055733]
#  [0.00455056 0.01016861 0.0084416 ]
#  [0.00560797 0.00989956 0.00760876]
#  [0.0061138  0.00792915 0.01075651]
#  [0.00564179 0.00819914 0.01188143]
#  [0.00616456 0.00752704 0.01084551]
#  [0.00642123 0.01030844 0.00790415]
#  [0.00467732 0.00790227 0.01157788]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 92/100
#
# ***********************
#  2152
# Profit is  550667.4374659992
# Initial Capital is  58418.99902
# Current Capital is  609086.4364859991
# %ROI is  942.6170367579831
# % Buy and Hold= 197.06176194595128
# count 2087
# qtable [[0.0061757  0.00661928 0.01002215]
#  [0.00464468 0.0100417  0.0084416 ]
#  [0.00560797 0.00972133 0.00757715]
#  [0.0061138  0.0079174  0.01040297]
#  [0.00566215 0.0081311  0.01145024]
#  [0.00617157 0.00741166 0.0104869 ]
#  [0.00641862 0.01006669 0.00790415]
#  [0.00467732 0.00790227 0.01147429]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 93/100
#
# ***********************
#  2152
# Profit is  963412.3179850018
# Initial Capital is  58418.99902
# Current Capital is  1021831.3170050018
# %ROI is  1649.14211839743
# % Buy and Hold= 197.06176194595128
# count 2089
# qtable [[0.00611859 0.00683475 0.01051395]
#  [0.00464468 0.0101177  0.0084416 ]
#  [0.00560797 0.00987866 0.00751646]
#  [0.00611424 0.00788575 0.01073036]
#  [0.00566215 0.0081311  0.0118389 ]
#  [0.00615407 0.00757724 0.01081395]
#  [0.00641862 0.01022094 0.00790415]
#  [0.00467732 0.00790227 0.01154238]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 94/100
#
# ***********************
#  2152
# Profit is  863922.5444970005
# Initial Capital is  58418.99902
# Current Capital is  922341.5435170005
# %ROI is  1478.8383214187438
# % Buy and Hold= 197.06176194595128
# count 2090
# qtable [[0.0061312  0.00679647 0.01049813]
#  [0.00464468 0.01013139 0.0084416 ]
#  [0.00560797 0.00987085 0.00751646]
#  [0.00611424 0.00780818 0.01083327]
#  [0.00566215 0.00808638 0.01136781]
#  [0.00616573 0.00758468 0.01085637]
#  [0.00639917 0.01022155 0.00790415]
#  [0.00467732 0.00790227 0.01156104]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 95/100
#
# ***********************
#  2152
# Profit is  986210.9212129994
# Initial Capital is  58418.99902
# Current Capital is  1044629.9202329994
# %ROI is  1688.1681263921787
# % Buy and Hold= 197.06176194595128
# count 2087
# qtable [[0.00612188 0.00678623 0.01054186]
#  [0.00464468 0.01014772 0.0084416 ]
#  [0.00560797 0.00989065 0.00751646]
#  [0.00608667 0.00770847 0.01077624]
#  [0.00566215 0.00836675 0.01187717]
#  [0.00616017 0.00760119 0.01090898]
#  [0.00634818 0.01023831 0.00790415]
#  [0.00473512 0.00790227 0.01158232]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 96/100
#
# ***********************
#  2152
# Profit is  924189.9231619994
# Initial Capital is  58418.99902
# Current Capital is  982608.9221819994
# %ROI is  1582.0023257255725
# % Buy and Hold= 197.06176194595128
# count 2088
# qtable [[0.00612188 0.0068469  0.01051969]
#  [0.00464468 0.01013976 0.0084416 ]
#  [0.00561145 0.00988634 0.00751646]
#  [0.00610668 0.00770847 0.01074702]
#  [0.00566215 0.00834275 0.01183921]
#  [0.00616436 0.00753682 0.01082815]
#  [0.00636029 0.01030462 0.00791282]
#  [0.00473512 0.00798987 0.01161351]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 97/100
#
# ***********************
#  2152
# Profit is  944059.0257120009
# Initial Capital is  58418.99902
# Current Capital is  1002478.0247320009
# %ROI is  1616.0136968262639
# % Buy and Hold= 197.06176194595128
# count 2087
# qtable [[0.00612188 0.00684341 0.01057035]
#  [0.00464468 0.01014779 0.00837851]
#  [0.00568277 0.00989932 0.00751646]
#  [0.00610699 0.00765658 0.01067931]
#  [0.00566215 0.00834275 0.01186258]
#  [0.00616436 0.00756611 0.01084061]
#  [0.00636029 0.01024676 0.00791282]
#  [0.00476936 0.00798987 0.01161337]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 98/100
#
# ***********************
#  2152
# Profit is  893607.6186300011
# Initial Capital is  58418.99902
# Current Capital is  952026.6176500011
# %ROI is  1529.6523966870272
# % Buy and Hold= 197.06176194595128
# count 2086
# qtable [[0.00610435 0.00684341 0.01046201]
#  [0.00464468 0.01014063 0.00837851]
#  [0.00568513 0.00988596 0.00751646]
#  [0.00613766 0.00759247 0.01067594]
#  [0.00566215 0.00834275 0.01181674]
#  [0.00613677 0.00784233 0.0108186 ]
#  [0.00634949 0.01021506 0.00791282]
#  [0.00476322 0.00793691 0.01155166]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 99/100
#
# ***********************
#  2152
# Profit is  828977.403443001
# Initial Capital is  58418.99902
# Current Capital is  887396.402463001
# %ROI is  1419.020211488384
# % Buy and Hold= 197.06176194595128
# count 2081
# qtable [[0.00603911 0.00683626 0.01043985]
#  [0.00464468 0.01008225 0.00837851]
#  [0.00568513 0.00979839 0.00751646]
#  [0.0060633  0.00754997 0.0106133 ]
#  [0.00566215 0.00826884 0.01186488]
#  [0.00609262 0.00754512 0.01075854]
#  [0.00641904 0.01008297 0.00790304]
#  [0.00476322 0.00793691 0.01150221]]
# epsilon 0.009998671593271896
# --------------------------------
# Episod 100/100
#
# ***********************
#  2152
# Profit is  955018.0053980014
# Initial Capital is  58418.99902
# Current Capital is  1013437.0044180014
# %ROI is  1634.7729701274868
# % Buy and Hold= 197.06176194595128
# count 2086
# qtable [[0.00605956 0.00679298 0.01049875]
#  [0.00467632 0.01010704 0.00837851]
#  [0.00570477 0.01002598 0.00778779]
#  [0.0061313  0.00754997 0.01077266]
#  [0.00570169 0.00826884 0.01184366]
#  [0.00609262 0.00749353 0.01080642]
#  [0.00641904 0.01022193 0.00790304]
#  [0.00476322 0.00793691 0.01155463]]
# epsilon 0.009998671593271896
# --------------------------------
# e=12,roi=1879.1946743920785

# %%
agent.Q

# %%
# %matplotlib inline
fig = plt.figure()
ax=X.loc[data_length_start:data_length-2,'cash'].plot(grid="True",figsize=(10,5), title='Nifty')
ax.set_xlabel("Trading Days")
ax.set_ylabel("cash")
plt.show()
